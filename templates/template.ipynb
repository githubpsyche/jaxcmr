# %% [markdown]
# # Template Notebook Title

# %% [markdown]
# Describe the analysis or model routine this notebook automates.

# %% [markdown]
# Summarize the motivation for collaborators and automated jobs. Explain how the configured parameters influence the outputs and note any dataset prerequisites that runners must satisfy.

# %%
import os
import pathlib
import warnings

# TODO: Import project utilities, e.g., from jaxcmr import analyses
warnings.filterwarnings("ignore")

# %%
run_tag = 'Example-Run'
data_name = 'ExampleDataset'
trial_query = "data['column'] == 1"
# TODO: Add more configuration parameters as needed

# %%
project_root = pathlib.Path('..').resolve()
data_path = project_root / 'data' / f'{data_name}.h5'
print(f'Loading data from {data_path}')
# TODO: Replace with domain-specific loading and preprocessing

# %%
# TODO: Add analysis, plotting, or export steps here

# %% [markdown]
# ## Notes
#
# - Document any downstream expectations or manual steps.
