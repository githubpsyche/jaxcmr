# %%
from jaxcmr.memorysearch import free_recall, trial_item_count, recall_by_item_index
from jaxcmr.evaluation import extract_objective_data
from jaxcmr.datasets import load_data, generate_trial_mask, load_parameters
from jaxcmr.analyses import single_pres_spc, single_pres_pfr, single_pres_crp
import numpy as np

import jax
from jax import numpy as jnp
jax.config.update('jax_platform_name', 'cpu')

from scipy.optimize import differential_evolution
import json
from tqdm import tqdm
import os

# %%
def fit_model_to_subject(
        data, loss_fn, model_create_fn, fixed_parameters, free_parameters, bounds, subject,  trial_count, model_name, 
        trial_mask, embeddings, ignore_first_recall=False, display=False):
    """Fit a model to a given subject in a dataset."""

    if trial_mask is None:
        trial_mask = jnp.ones(len(data['recalls']), dtype=np.bool_)

    # trials, list_lengths, presentations, pres_string_ids, has_repetitions = extract_objective_data(data, trial_mask)
    presentations = jnp.array(data['pres_itemnos'][trial_mask])
    trials = jax.vmap(recall_by_item_index)(
        presentations, jnp.array(data['recalls'][trial_mask]))

    base_parameters = fixed_parameters.copy()
    loss_fn = loss_fn(
        model_create_fn, 
        presentations, 
        trials
        )

    # with jax.disable_jit():
    @jax.jit
    def objective_function(x):
        for key_index, key in enumerate(free_parameters):
            base_parameters[key] = x[key_index]
        return loss_fn(base_parameters)

    # objective_function = generate_objective_function(
    #     data, model_init, fixed_parameters,free_parameters, 
    #     trial_mask, embeddings, ignore_first_recall, display=display)

    fit_result = differential_evolution(objective_function, bounds, disp=display, tol=.001)
    fitted_parameters = {
        'subject': int(subject), 'trial_count': int(trial_count),
        'likelihood': float(fit_result.fun), 'model': str(model_name), 'fixed': {}, 'free': {}
        }

    for key in fixed_parameters:
        fitted_parameters['fixed'][key] = float(fixed_parameters[key])
    for key_index, key in enumerate(free_parameters):
        fitted_parameters['fixed'][key] = float(fit_result.x[key_index])
    for key in free_parameters:
        fitted_parameters['free'][key] = list(free_parameters[key])

    return fitted_parameters

# %%
def fit_model_to_dataset(
        loss_fn, # loss function to use for fitting
        model_create_fn, # function to use for creating the model
        fit_fn, # function to use for fitting
        data_path, # path to the dataset
        parameter_path, # path to parameter dictionary specifying fixed and free parameters
        fit_by_subject=True, # whether to fit by subject
        ignore_first_recall=False, # whether to ignore the first recall in each list
        embedding_paths=None, # a list of paths to embedding files to pass to the model
        trial_query=None, # a query to select trials to fit
        model_name=None, # name of the model
        result_path=None, # path to JSONL for saving, retrieving results
        replace_results=False, # whether to replace existing results
        display=False, # whether to display fitting progress
        ):
    "Fit a model to a dataset based on the given parameters."

    # load data and parameters
    data = load_data(data_path)
    parameters = load_parameters(parameter_path)
    
    trial_mask = None
    if trial_query is not None:
        trial_mask = generate_trial_mask(data, trial_query)

    embeddings = None
    if embedding_paths is not None:
        embeddings = load_embeddings(embedding_paths)

    # This uses the old parameter format; maybe should be updated to use the new one
    fixed_parameters = parameters['fixed']
    free_parameters = parameters['free']
    bounds = np.zeros((len(free_parameters), 2))
    for key_index, key in enumerate(free_parameters):
        bounds[key_index, 0] = free_parameters[key][0]
        bounds[key_index, 1] = free_parameters[key][1]

    subject_fits = []
    already_fit = []
    subject_indices = np.unique(data['subject']) if fit_by_subject else [-1]

    # if we are replacing results, let's create a temporary file to write to
    if replace_results:
        result_path = result_path + '_tmp'
        if os.path.exists(result_path):
            os.remove(result_path)

    # load pre-computed results and identify subjects that have already been fit
    if (not replace_results) and (result_path is not None) and (os.path.exists(result_path)):
        with open(result_path, 'r') as f:
            for line in f:
                subject_fits.append(json.loads(line))
        already_fit = [subject_fit['subject'] for subject_fit in subject_fits]

    index_loop = tqdm(subject_indices)
    for subject in index_loop:

        if subject in already_fit:
            continue

        # need subject-specific trial mask if fitting by subject (index != -1)
        if subject >= 0:
            if trial_mask is None:
                trial_mask = np.ones(len(data['recalls']), dtype=bool)
            subject_specific_trial_mask = np.logical_and(trial_mask, (data['subject'] == subject).flatten())
        else:
            subject_specific_trial_mask = trial_mask.copy()

        # skip subjects with no trials to fit model to
        trial_count = np.sum(subject_specific_trial_mask)
        if trial_count == 0:
            continue

        if display:
            print("Fitting subject {} with {} trials".format(subject, trial_count))

        fitted_parameters = fit_fn(
            data, loss_fn, model_create_fn, fixed_parameters, free_parameters, bounds, subject, trial_count, model_name, 
            subject_specific_trial_mask, embeddings, ignore_first_recall, display)

        subject_fits.append(fitted_parameters)
        if result_path is not None:
            with open(result_path, 'a') as f:
                f.write(json.dumps(fitted_parameters) + '\n')

        index_loop.set_description("Last fit: {}".format(fitted_parameters['likelihood']))

    if len(subject_fits) == 0:
        raise ValueError('No subjects to fit.')

    # if we are replacing results, let's replace the old file with the new one
    if replace_results:
        if os.path.exists(result_path[:-4]):
            os.remove(result_path[:-4])
        os.rename(result_path, result_path[:-4])

    return subject_fits

# %% [markdown]
# # HealyKahana2014

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood # uniform_presentations_data_likelihood

model_name = 'base_Instance_CMR'
parameter_path = '../../data/base_cmr_parameters.json'

data_tag = 'HealyKahana2014'
trial_query = "data['listtype'] == -1"

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, uniform_presentations_data_likelihood

model_name = 'trace_Instance_CMR'
parameter_path = '../../data/instance_cmr_parameters.json'

data_tag = 'HealyKahana2014'
trial_query = "data['listtype'] == -1"

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

def loss(base_parameters, trials, list_length):
    model = InstanceCMR.create(list_length, list_length, base_parameters)
    return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    loss,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 657.2520141601562: 100%|██████████| 126/126 [36:18<00:00, 17.29s/it]

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, uniform_presentations_data_likelihood

model_name = 'dual_Instance_CMR'
parameter_path = '../../data/dual_cmr_parameters.json'

data_tag = 'HealyKahana2014'
trial_query = "data['listtype'] == -1"

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

def loss(base_parameters, trials, list_length):
    model = InstanceCMR.create(list_length, list_length, base_parameters)
    return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    loss,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      15     model = InstanceCMR.create(list_length, list_length, base_parameters)
#      16     return uniform_presentations_data_likelihood(model, trials)
# ---> 18 fit_model_to_dataset(
#      19     loss,
#      20     fit_model_to_subject,
#      21     data_path.format(data_tag), # path to the dataset
#      22     parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
#      23     fit_by_subject = True, # whether to fit by subject
#      24     ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
#      25     embedding_paths=None, # a list of paths to embedding files to pass to the model
#      26     trial_query=trial_query, # a query to select trials to fit
#      27     model_name=model_name, # name of the model
#      28     result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
#      29     replace_results=True, # whether to replace existing results
#      30     display=False, # whether to display fitting progress
#      31     );
#
# TypeError: fit_model_to_dataset() missing 1 required positional argument: 'parameter_path'

# %% [markdown]
# ## Murdock1962

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'BaseCMR'
parameter_path = '../../../../data/base_cmr_parameters.json'

data_tag = 'Murdock1962'
trial_query = 'data["subject"] > -1'

result_path = '../../../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    BaseCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]D:\projects\jaxcmr\venv\Lib\site-packages\beartype\_util\hint\pep\utilpeptest.py:311: BeartypeDecorHintPep585DeprecationWarning: PEP 484 type hint typing.Callable deprecated by PEP 585. This hint is scheduled for removal in the first Python version released after October 5th, 2025. To resolve this, import this hint from "beartype.typing" rather than "typing". For further commentary and alternatives, see also:
#     https://beartype.readthedocs.io/en/latest/api_roar/#pep-585-deprecations
#   warn(
# Last fit: 4737.943359375:  60%|██████    | 9/15 [34:48<23:12, 232.07s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 18
#      12 ignore_first_recall = False
#      14 # def loss(base_parameters, trials, list_length):
#      15 #     model = InstanceCMR.create(list_length, list_length, base_parameters)
#      16 #     return uniform_presentations_data_likelihood(model, trials)
# ---> 18 fit_model_to_dataset(
#      19     variable_presentations_data_likelihood,
#      20     BaseCMR.create,
#      21     fit_model_to_subject,
#      22     data_path.format(data_tag), # path to the dataset
#      23     parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
#      24     fit_by_subject = True, # whether to fit by subject
#      25     ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
#      26     embedding_paths=None, # a list of paths to embedding files to pass to the model
#      27     trial_query=trial_query, # a query to select trials to fit
#      28     model_name=model_name, # name of the model
#      29     result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
#      30     replace_results=True, # whether to replace existing results
#      31     display=False, # whether to display fitting progress
#      32     );
#
# Cell In[9], line 77, in fit_model_to_dataset(loss_fn, model_create_fn, fit_fn, data_path, parameter_path, fit_by_subject, ignore_first_recall, embedding_paths, trial_query, model_name, result_path, replace_results, display)
#      74 if display:
#      75     print("Fitting subject {} with {} trials".format(subject, trial_count))
# ---> 77 fitted_parameters = fit_fn(
#      78     data, loss_fn, model_create_fn, fixed_parameters, free_parameters, bounds, subject, trial_count, model_name,
#      79     subject_specific_trial_mask, embeddings, ignore_first_recall, display)
#      81 subject_fits.append(fitted_parameters)
#      82 if result_path is not None:
#
# Cell In[8], line 32, in fit_model_to_subject(data, loss_fn, model_create_fn, fixed_parameters, free_parameters, bounds, subject, trial_count, model_name, trial_mask, embeddings, ignore_first_recall, display)
#      26     return loss_fn(base_parameters)
#      28 # objective_function = generate_objective_function(
#      29 #     data, model_init, fixed_parameters,free_parameters,
#      30 #     trial_mask, embeddings, ignore_first_recall, display=display)
# ---> 32 fit_result = differential_evolution(objective_function, bounds, disp=display, tol=.001)
#      33 fitted_parameters = {
#      34     'subject': int(subject), 'trial_count': int(trial_count),
#      35     'likelihood': float(fit_result.fun), 'model': str(model_name), 'fixed': {}, 'free': {}
#      36     }
#      38 for key in fixed_parameters:
#
# File D:\projects\jaxcmr\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:402, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     385 # using a context manager means that any created Pool objects are
#     386 # cleared up.
#     387 with DifferentialEvolutionSolver(func, bounds, args=args,
#     388                                  strategy=strategy,
#     389                                  maxiter=maxiter,
#    (...)
#     400                                  integrality=integrality,
#     401                                  vectorized=vectorized) as solver:
# --> 402     ret = solver.solve()
#     404 return ret
#
# File D:\projects\jaxcmr\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:1022, in DifferentialEvolutionSolver.solve(self)
#    1019 for nit in range(1, self.maxiter + 1):
#    1020     # evolve the population by a generation
#    1021     try:
# -> 1022         next(self)
#    1023     except StopIteration:
#    1024         warning_flag = True
#
# File D:\projects\jaxcmr\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:1409, in DifferentialEvolutionSolver.__next__(self)
#    1407     feasible = True
#    1408     cv = np.atleast_2d([0.])
# -> 1409     energy = self.func(parameters)
#    1410     self._nfev += 1
#    1412 # compare trial and population member
#
# File D:\projects\jaxcmr\venv\Lib\site-packages\scipy\_lib\_util.py:360, in _FunctionWrapper.__call__(self, x)
#     359 def __call__(self, x):
# --> 360     return self.f(x, *self.args)
#
# KeyboardInterrupt:

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'base_Instance_CMR'
parameter_path = '../../../../data/base_cmr_parameters.json'

data_tag = 'Murdock1962'
trial_query = 'data["subject"] > -1'

result_path = '../../../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 1050.888671875: 100%|██████████| 15/15 [36:52<00:00, 147.51s/it]

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'trace_Instance_CMR'
parameter_path = '../../data/instance_cmr_parameters.json'

data_tag = 'Murdock1962'
trial_query = 'data["subject"] > -1'

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 1024.6253662109375: 100%|██████████| 15/15 [16:02<00:00, 64.17s/it]

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'dual_Instance_CMR'
parameter_path = '../../data/dual_cmr_parameters.json'

data_tag = 'Murdock1962'
trial_query = 'data["subject"] > -1'

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 1021.0206298828125: 100%|██████████| 15/15 [1:00:36<00:00, 242.47s/it]

# %% [markdown]
# ## Lohnas 2014

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'BaseCMR'
parameter_path = '../../../../data/base_cmr_parameters.json'

data_tag = 'LohnasKahana2014'
trial_query = 'data["subject"] > -1'

result_path = '../../../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    BaseCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 862.6221923828125: 100%|██████████| 35/35 [32:41<00:00, 56.06s/it]

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'base_Instance_CMR'
parameter_path = '../../data/base_cmr_parameters.json'

data_tag = 'LohnasKahana2014'
trial_query = 'data["subject"] > -1'

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# /home/gunnj/jaxcmr/.venv/lib/python3.10/site-packages/beartype/_util/hint/pep/utilpeptest.py:311: BeartypeDecorHintPep585DeprecationWarning: PEP 484 type hint typing.Callable deprecated by PEP 585. This hint is scheduled for removal in the first Python version released after October 5th, 2025. To resolve this, import this hint from "beartype.typing" rather than "typing". For further commentary and alternatives, see also:
#     https://beartype.readthedocs.io/en/latest/api_roar/#pep-585-deprecations
#   warn(
# Last fit: 1128.2474365234375:  20%|██        | 3/15 [09:27<36:16, 181.34s/it]/home/gunnj/jaxcmr/.venv/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# Last fit: 1061.6456298828125: 100%|██████████| 15/15 [43:34<00:00, 174.29s/it]

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'trace_Instance_CMR'
parameter_path = '../../data/instance_cmr_parameters.json'

data_tag = 'LohnasKahana2014'
trial_query = 'data["subject"] > -1'

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 1024.6253662109375: 100%|██████████| 15/15 [16:02<00:00, 64.17s/it]

# %%
from jaxcmr.memorysearch import BaseCMR, InstanceCMR, variable_presentations_data_likelihood

model_name = 'dual_Instance_CMR'
parameter_path = '../../data/dual_cmr_parameters.json'

data_tag = 'LohnasKahana2014'
trial_query = 'data["subject"] > -1'

result_path = '../../data/results/jax_{}_{}_{}.jsonl'
data_path = '../../data/{}.h5'

ignore_first_recall = False

# def loss(base_parameters, trials, list_length):
#     model = InstanceCMR.create(list_length, list_length, base_parameters)
#     return uniform_presentations_data_likelihood(model, trials)

fit_model_to_dataset(
    variable_presentations_data_likelihood,
    InstanceCMR.create,
    fit_model_to_subject,
    data_path.format(data_tag), # path to the dataset
    parameter_path, # path to Parameter object specifying fixed and free parameters for fitting
    fit_by_subject = True, # whether to fit by subject
    ignore_first_recall=ignore_first_recall, # whether to ignore the first recall in each list
    embedding_paths=None, # a list of paths to embedding files to pass to the model
    trial_query=trial_query, # a query to select trials to fit
    model_name=model_name, # name of the model
    result_path=result_path.format(model_name, data_tag, ignore_first_recall), # path to JSONL for saving, retrieving results
    replace_results=True, # whether to replace existing results
    display=False, # whether to display fitting progress
    );
# Out:
# Last fit: 1021.0206298828125: 100%|██████████| 15/15 [1:00:36<00:00, 242.47s/it]
