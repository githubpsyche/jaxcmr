# %%
from jaxcmr.models.LinearAssociativeMemory import initialize_mfc, initialize_mcf, associate
import jax.numpy as jnp
from jax import jit

item_count = 16
learning_rate = 0.1
items = jnp.eye(item_count, dtype=jnp.float32)

# %%
mfc = initialize_mfc(10, 0.1)
mcf = initialize_mcf(10, 0.1, 0.1)

items = jnp.eye(10)
contexts = jnp.eye(10, 12, 1)

mfc = associate(mfc, 0.1, items[0], contexts[0])
mcf = associate(mcf, 0.1, contexts[0], items[0])
