# %% [markdown]
# Serial repetition CRP curves for repeated-item transitions in serial recall.
#
# This notebook compares mixed (lag > 0) trials against a shuffled control
# (lag == 0) using RepeatedRecallsGordonRanschburg2021. Each plot shows
# first vs second presentation curves within a single dataset.

# %%
import os

import jax.numpy as jnp
import matplotlib.pyplot as plt

from jaxcmr.analyses.serialrepcrp import plot_rep_crp, subject_serial_rep_crp, test_serial_rep_crp_vs_control
from jaxcmr.helpers import find_project_root, generate_trial_mask, load_data
from jaxcmr.repetition import make_control_dataset

def save_figure(figure_dir, figure_str, suffix=None):
    plt.tight_layout()
    if not figure_str:
        plt.show()
        return
    os.makedirs(figure_dir, exist_ok=True)
    suffix_str = f"_{suffix}" if suffix else ""
    figure_path = os.path.join(figure_dir, f"{figure_str}{suffix_str}.png")
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()

# %%
allow_repeated_recalls = True
filter_repeated_recalls = False
data_path = "data/RepeatedRecallsGordonRanschburg2021.h5"
figure_dir = "results/figures"
figure_str = ""
ylim = None
base_data_name = "GordonRanschburg2021"
trial_query = "data['condition'] == 2"
mixed_trial_query = "jnp.logical_and(data['condition'] == 2, data['lag'] != 4)"
control_trial_query = "jnp.logical_and(data['condition'] == 2, data['lag'] == 4)"
control_shuffles = 10
control_seed = 0
min_lag = 2
max_lag = 3
size = 2

# %%
# Parameters
data_path = "projects/repfr/results/simulations/RepeatedRecallsKahanaJacobs2000_McfReinfPositionalCMRNoStop_rerun_best_of_1.h5"
figure_dir = "projects/repfr/results/figures/fitting"
figure_str = "RepeatedRecallsKahanaJacobs2000_McfReinfPositionalCMRNoStop_rerun_best_of_1_serialrepcrp.png"
mixed_trial_query = "jnp.logical_and(jnp.logical_and(data['recall_attempt'] == 1, data['recall_total'] > 0), data['repetitions'] == 1)"
control_trial_query = "jnp.logical_and(jnp.logical_and(data['recall_attempt'] == 1, data['recall_total'] > 0), data['repetitions'] == 0)"
control_shuffles = 1
trial_query = "jnp.logical_and(data['recall_attempt'] == 1, data['recall_total'] > 0)"

# %%
project_root = find_project_root()
figure_dir = os.path.join(project_root, figure_dir)
data_path = os.path.join(project_root, data_path)
data = load_data(data_path)
trial_mask = generate_trial_mask(data, trial_query)
mixed_mask = generate_trial_mask(data, mixed_trial_query) & trial_mask

control_dataset = make_control_dataset(
    data,
    mixed_query=mixed_trial_query,
    control_query=control_trial_query,
    n_shuffles=control_shuffles,
    remove_repeats=filter_repeated_recalls,
    seed=control_seed,
)
control_mask = jnp.ones((control_dataset["recalls"].shape[0],), dtype=bool)

# %%
plot_rep_crp(
    datasets=data,
    trial_masks=mixed_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
plt.title("Mixed Trials")
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="mixed")

plot_rep_crp(
    datasets=control_dataset,
    trial_masks=control_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
plt.title("Control (Shuffled) Trials")
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="control")

# %%
observed_crp = subject_serial_rep_crp(data, mixed_mask, min_lag, max_lag, size)
control_crp = subject_serial_rep_crp(control_dataset, control_mask, min_lag, max_lag, size)

results = test_serial_rep_crp_vs_control(observed_crp, control_crp, max_lag)
for label, result in results.items():
    print()
    print("=" * 60)
    print(f"Statistical Tests: {label}")
    print("=" * 60)
    print(result)
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\x90}Y9{\x99e\xee\xe1\x8c|\xe6\x01\xf4\x0f.\xd1\xde \x0ceikp\xafxO\x8f\x96\xe553\x13\x07W\xaf\x7f\xbd\xef\xb1\xf5J\x86\x8a\xed\x1a6~\xb3\t\x9a\x00*::\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\x9a\x9a\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xca\xca\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\xca\xca\x00\x01\x00\x11\xec\x04\xc0\xc7\xe8\x902hD)i{gU\x0fL\xaa\x9b\x9440;\x9b\xb0#e\t\xd2\xdcF\x7f\xd54\xdce\xcf\xd4']
# Bad pipe message: %s [b',\x13nb\x053\xee\xf3\x17\xd3"Q]\xe5J\x000\xa8\xad\x14^\xff\xe8^\xf8\x07\x16\xa5\x12\x1c\x1a\xc1JT\xe6#\x15\x94\x93\x087\xa0F\x84\x1d9\xf0\xa6\x80Q\t\x1c\xf7\xbc\x169\xc9\xad\x91\xa7\xf8\xcchAu\x99\xc2\xe7\x97#\xa2G\xc8DBXu/\x0fd\x9e\ngR]\xfcq\xe9\xf8\xbb\xc0\xf3_\x8e[\x9e\xd203P\xfb\xb1:\x94\xb2\xdb\x90\x85\xb7JK8\x16\xcde\xda\x890\xf1\xcf\xa9K|\xd9t\x00\xdd\x83%^\x0b\x8d5az\xa2\xe8\xbc\xd7A\xc5\xfc2\x15\x9eU `T\x8d\x97i^[\x0b\x8f\xcd@\x90\xb8t\n\xbd\x85Oz\xb04``W\x98\n\x82\x03\x012T\xfa5\xe6\xdc\x176\xb2A,8I\x8a6\xbb\xb0\xa2\'}W\xcc\x15\xe4\x7f\xe1\xf5\xaf\xaaZB\x1f\xb8"\x1a\xa2e\xd4\xa2\x1a\x9e\x13\x96']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\xa8\xf0 \x97\xc3A4\xe6\xa4\t\x82<\xa1&\x99]\x13\x11\xc6\xca\xd7-\xb2\xa7\xb2\xfd6\x0e|\xba\xb3\xa0\xc93J4\x18A0{\xda\xca?\xde\x89\xbf\xc3u*\xa8\xe0\x9f\xe1\x89|\xe8d\xac6\xb3\xa1\xa7\xa4\x01\x7f\x15)\xb5yq\xe4', b'n%\x06cq\x00M\xd8/\x06\x01\xbc?0\x08.*\x03\xf8ho\r\x86\x9a\xee\x16$\xfa\x86;\xecV\xccL\xf7\xbf\x1d\x8a\xc1\x1br\xb8\xd6\xb0\xb3\x9bH\xa3z\xd7\x1f\x1f\x1c\xafp(3/5\xa0\x86\x17\xcbSh\x12\x85 m\xf6\xf9\xbe\xdb\x94\x9f\xf1\xd8`g\xc0\x02\x853Wr"\x15\xb1w\x1f\xe2\xbbo\x8b\x16}\xc83j\x89\xb1\xbcJ\xd7#\x8b\xc6\x1agTq\xe5th]\x95_\x80\xba\xbcAH\x01\xdf\x8aF \x93\x01F\xe3\x19\xcdf\n\x8f\xc9\x8b\xa7*[\x9a8\x1c}\xb7\xca\xcb\xd8\xc2\x16\xfbpa']
# Bad pipe message: %s [b'\x81*\xc8S;\x8cQ\xd3\x94\xddj\x93\x90\x14.q\xf9\xaf\x93\x1a\xc4\xee\x12[+\x03[\x07E\xb0\xd5\x88V\xfe\xb1\x80\x82f\x85\x16\xe3\xa5\x0fjh\xb8\xbcGA\xday\xf7\x93:\xcauS\xe5\xe0\x1b:aHl\xc5\x86<\x8c\x10\x12\x98qEX\x9d\xfd\x93\xa4HF\x15\xf4\x0b\x19\t\x89\xb4\xcc\xb8\x85\xa3!{\xd4\xe3\x94\xb1DJ\xc1JEn7\xb1\xa4B\x16\xe9 M\x88P\xa8fs\xbf\xa2\xfaO\xba\xdc(\xec\x86\x92^\x13\xba\xfdd8\x06";\xac\x11\x8c\xf3\x98\x8e\xcdhR&lkt\xd5\x8f\xc1\x11\x03\xf5\xca\x12\xab#@A\x80{\xb9\x80\xcfn\xc5\xb5\xa7g\xb7WU<\xe3\xe6|"\xdbw&\xdcH\x99"j\xc8E\xceI\xa5\x927r\x86\xe43\rn']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\xd6\xba\xdb\xcdzA\xf8C\xe6\x16-i\xd8\xc8k]\xd9~ \x8b9\xb5\x90+\xa2\xa5\xe9Er\xac \xa9qi\xc3\xde$U\xc0fxe\x1bYg\xaez\x84\xd2\xdf\x81\x00,JJ\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\xca\xca\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\x8a\x8a\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\xbf\xc8vn\xb1\x99L\x1a\xc10JDW\xd5\t \x01:\xf5R\xc0\xbd\x03\x00\xb36Hg0\x8a\xd5\xa7\xc8\xbc \xa2\xfd\xd3H\xfb\x1a\x0f\x0e0\xbb\x0e\xb7w\x91H\x8f\x80\xdbUE\xca\x1d\xb5\x93v0\xc7\xc9\xbc\x9c\x8e\x9d\xb3/\xbe\x93\xc2]\xab[\x1dUA\xcd\x031\x9d\xc7nfk\xc21+^\xd9\x1b\xa0\x10\x8c\xb4|\xa6x\x8f\xd8lE\xdc{0\x03-N\x88U\xfcf,\x02\x11\xb3\x7f\x8ct\xc8\xb4\xa6\xfb@k\xc2\x14s\x9b\x86P\x8dW\x95\xf9P\x9f\x91\xba\x9eq:-\xa7']
# Bad pipe message: %s [b'\xcf\x16\x86\xe3{Sr\xb8L=\x06e\xc8\xa91\xa7\xe5rBV i`\xcf\xc9\xc6\x17\x81\x837{\xb6\x91\xca\x12d\xf0\x1b\x81\x05\xa8Gy\xb3\x1b\xa8\x8ag\x9a+(\xe2\x88g=B3#+c\xe1\xd8\xbcb\xab\x1b[w\x057\xaa~)<\xb9\xcd@\x7f\xae\xd0\x96\xb3(d\xf8\x97*8\x93\xb1\xff\xca\xb2\xcc\x18@\xbd\xac\xc9\xd62p\xed\xf4\xadG\xe1\x02\xaa\x01N\xe32\x04\xde\x16\x1b:[@\xd3@h:Y\x122\xe8\xc7\x1a\xb9I\xa1Ch\xd6\x82n\xf3\xf5\xaa6\x99x\x93\xd1F\'\xc0\xcf\x16{\xa9p\xe4a\x82W\xbf\xeb\x19ea\x0cU\xb0\x185\x94"\x0b\x06\x86&\xdc\xbb"\xc6\xe7\xa26(\x9at\x90t\x8fL\x1c\x14\x06\xc4\xbcx\xa0\x85c', b'\xba\x81\xe3\x94f\xd6\x9bzlsYh\xa8/\xd6\xb2}\x9b7\x19a\xc5\x17\x9c\x92\x97\x16\xe6J\x82z\tN\x99\xc2\xa5\xd8r!\xb2\x0c\xfe\xca\xc9f\xf0%2\xbbm\xbf\xf6<\xa3R\xbd#%p4\x84t\xd5;\x13$R\x87\xaf\xb7(\xb9\x80!\xa8\xe6\x84\x9d\x04\xd0\x1be\xa2\x9c\x81s\x8f\xf7\xb5jao\x93\xe4\x82\xaa,\x8f\xc4f \xf3\x03>\xfe,\x15(C\xa1\xf8b\x03\xa8\xe3\x81\x05l`\x17 \x9f\xef\x96G\x12\xad\t(>\xb7\xce\x18[\xa4\xdc\x032\x08F\x15K\xd0\x8e\xe0\x8e\x0f\x1c0s\xfb\x0f\xea\xf4\xb2\x85\xe5jXf\xf7\xdc\x96\xf6\xac"\xc5\x94\xba>!%\xde\xd7s\x08\xf0f\xd0\xf5\xcb\x0e`\x00\x1d\x00 \xb7h\xe8f3N\x1c?  \xa1n\x97\xe4B']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ============================================================
# Statistical Tests: First Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#     1 |   -1.141     0.2689 |     90.0     0.8596 |    -0.0027
#     2 |    0.944     0.3576 |     74.0     0.4180 |     0.0010
#     3 |    2.616     0.0175 |     39.0     0.0230 |     0.0017
#
# ============================================================
# Statistical Tests: Second Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#     1 |   -3.552     0.0023 |      0.0     0.0000 |    -0.0083
#     2 |    1.930     0.0696 |     46.0     0.0494 |     0.0015
#     3 |    3.458     0.0028 |      6.0     0.0001 |     0.0016
