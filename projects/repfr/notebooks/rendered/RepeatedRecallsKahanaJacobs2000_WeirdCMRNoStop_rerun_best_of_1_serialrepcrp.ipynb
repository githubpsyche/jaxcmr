# %% [markdown]
# Serial repetition CRP curves for repeated-item transitions in serial recall.
#
# This notebook compares mixed (lag > 0) trials against a shuffled control
# (lag == 0) using RepeatedRecallsGordonRanschburg2021. Each plot shows
# first vs second presentation curves within a single dataset.

# %%
import os

import jax.numpy as jnp
import matplotlib.pyplot as plt

from jaxcmr.analyses.serialrepcrp import plot_rep_crp, subject_serial_rep_crp, test_serial_rep_crp_vs_control
from jaxcmr.helpers import find_project_root, generate_trial_mask, load_data
from jaxcmr.repetition import make_control_dataset

def save_figure(figure_dir, figure_str, suffix=None):
    plt.tight_layout()
    if not figure_str:
        plt.show()
        return
    os.makedirs(figure_dir, exist_ok=True)
    suffix_str = f"_{suffix}" if suffix else ""
    figure_path = os.path.join(figure_dir, f"{figure_str}{suffix_str}.png")
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()

# %%
allow_repeated_recalls = True
filter_repeated_recalls = False
data_path = "data/RepeatedRecallsGordonRanschburg2021.h5"
figure_dir = "results/figures"
figure_str = ""
ylim = None
base_data_name = "GordonRanschburg2021"
trial_query = "data['condition'] == 2"
mixed_trial_query = "jnp.logical_and(data['condition'] == 2, data['lag'] != 4)"
control_trial_query = "jnp.logical_and(data['condition'] == 2, data['lag'] == 4)"
control_shuffles = 10
control_seed = 0
min_lag = 2
max_lag = 3
size = 2

# %%
# Parameters
data_path = "projects/repfr/results/simulations/RepeatedRecallsKahanaJacobs2000_WeirdCMRNoStop_rerun_best_of_1.h5"
figure_dir = "projects/repfr/results/figures/fitting"
figure_str = "RepeatedRecallsKahanaJacobs2000_WeirdCMRNoStop_rerun_best_of_1_serialrepcrp.png"
mixed_trial_query = "jnp.logical_and(jnp.logical_and(data['recall_attempt'] == 1, data['recall_total'] > 0), data['repetitions'] == 1)"
control_trial_query = "jnp.logical_and(jnp.logical_and(data['recall_attempt'] == 1, data['recall_total'] > 0), data['repetitions'] == 0)"
control_shuffles = 1
trial_query = "jnp.logical_and(data['recall_attempt'] == 1, data['recall_total'] > 0)"

# %%
project_root = find_project_root()
figure_dir = os.path.join(project_root, figure_dir)
data_path = os.path.join(project_root, data_path)
data = load_data(data_path)
trial_mask = generate_trial_mask(data, trial_query)
mixed_mask = generate_trial_mask(data, mixed_trial_query) & trial_mask

control_dataset = make_control_dataset(
    data,
    mixed_query=mixed_trial_query,
    control_query=control_trial_query,
    n_shuffles=control_shuffles,
    remove_repeats=filter_repeated_recalls,
    seed=control_seed,
)
control_mask = jnp.ones((control_dataset["recalls"].shape[0],), dtype=bool)

# %%
plot_rep_crp(
    datasets=data,
    trial_masks=mixed_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
plt.title("Mixed Trials")
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="mixed")

plot_rep_crp(
    datasets=control_dataset,
    trial_masks=control_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
plt.title("Control (Shuffled) Trials")
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="control")
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\x01\xa4\x9d\x0c\xa1zp"9\x14\x81(\xce\xca\xde\x89\xea> S\xf3\xe1%\x19Q\xdf\x83\xc6\xb1\x18\xbf\x1a\xb8\x9b\xf7c\xc6\xd1\xde\xb6\xa4Q\x1e\xdd\xa8\x1fq\xab\x98\xbf\x03\x00*\x8a\x8a\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n']
# Bad pipe message: %s [b'\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\xea\xea\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0cjj\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xedjj\x00\x01\x00\x11\xec\x04\xc0\tj[t%N\xf43\x13\xf07t]j\x9e\xba\xc7\xbb\xc2bUv\xe7\xc4Ge\x12\xe87\xc4z\x18N\xc1W\x89\x91d\x07%\xa8\xc9\xd3\x85%k\xcc\xb3\x01X_i\xd0w<\xa2B\xd8,A', b"\x13\xb5\x90\x13\xe2\xf5\x1b\x88D~\xd7&\xa9\xf5\xd6\x84\x0036~\x80\x84\xe6\xb1!\xa8\xf9\xba\x99w+\x81%\x1dtz\xa8\x90KV\xb51V\x8a8\xa4\xf0\xa7\\6\xaa\xcex\x85\x8f\x18Z#b\x1c_\xdb)\x8bE\xf9\x10Sv\\\xe5HJl\xdcv&\x96\x1e\xbc\xa0\xc8\xef\xf8\xaa#\x03\x03/\x80*\xacd\xbdFHat\x161\x0e\xcc\xb4=\xa4\xcd\x92l\xa5\x1d\xb7\x11\xb2\xd2\x08\x05\xe3<CCX\xc1i\x9a\xa4U'\xbd\xe1\xc88\xa4X\x90@\xc2\x03\xe0?+\xb1\x1d\xbbW\x13\xc5Ysl\x97b\xcf\xe3\xba\x94tM\xf1V6\x967K\xb8\xd4t\x8e\x989\xf9d\x1e\x1a\xe0\x8a", b'I\xa6\x8c']
# Bad pipe message: %s [b"\x93\\\x1e\x95\xaf~\xd6\xb5\xees_\x90t\x93\xd1\x06\x06\xac\xf7f\xf4\xd8O\n\x90\x80\x1fgw?\xb4\xa7\xbf<\xc8;\x88\x91\xd9\x8aD\xc5\xb0\x8e\x18\x95,\x88&\xa6\xe5\x83_=\x91Po\xe1\x97\xa9\x869$%\x87\x8f\xac\xa4\xcf#Ff\xe4S\xff\xd0C+Q3\xbd\xc7\xcf\xc3HZR\x17\xb7\xd7'`\x9c", b'W\xe7VFi\x9bLT\xb9\xec\xdb\xbf,\x19;\xf8\xf1\xc8\x7f&\x95\xd2UQ\x0cB\x9ee\xd1^\x05BX\xe8[}\x1a\xe50G\x9b\x9e\xd7\xf1\xc1\xbfQO[\x07\x00A\xb2R\x9a\xa3+\x9c\x05o3\xb1\nW\x04iH\x189U\x88Xj)\x81\xd8\xe4\xb8n\x1bF\xc7\x136\xc0\xa7;\xb9\xd0\xc4J\x93jn\xcct\nL\x82\xb3\xb8\xa4\x8233\xcb`\xbf\xfau;\xff9\x95\xcd\xe5\x00d\x18Sb\xccs.\xc5\x87\xa7\x0cr\xe8\xe0\x9a\x0f\x18!\x18`-u\x92@@+\x907\x15@Gzg\xad']
# Bad pipe message: %s [b'\xa6(\xc4;"\x9d\x1c\x1e\xd6\xe8U0_\x9a\x01\x8a#\x1a \x13\xea\xb9|,\xfe\x8e\xd6\xd5\xd7P\xaev\x95\xc4\xca)\xfcpj>\xd0\xc0\x8c\x86\x87\xca\xfb\xcfY\xa1c\x00,\n\n\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05njj\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\x1a\x1a\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\x1a\x1a\x00\x01\x00\x11\xec\x04\xc0\xfbd:\xd4\x0bo\xefZ\xccr\x94%\x13h\xafL\xf675\xb8\x07<\xd6\xc0v\xab\x8f\xb7\x8c\xc1\xa6%:\xfc \x18\xa0L\xa1']
# Bad pipe message: %s [b'+\xd9?B\xb9\x08\x0f w\x9fV\rz\xb2\xceX\xda)\xed[\x89\xff\xc6W\xaf\xccLn\xb5\x1a[\x91P\xdc;\x8a\xd4<\x1eb\xf8\xb8\xb0\xe7T\xc7q\x0c\x9a\xdaE\x96C;\xab<\x1b\xe6\xe0\n\x97\xda\xca\x94\xf6$\x80\xc0"\x96u\x03\x87\x83\xc6\xc1r\x9e\x14\x95\xa1\xb7"\x95P\xdc\x89\r,A\x1bLh:\x1c\x1d\x82`$_\xb1\xc1\xc7\xfa3\xab\xa9?\xb2\xe1oy1\x81\xcb\xe3_\x9ew\x9f4\x9c\xca\x9d[t\x97\xe4\x95\x1fd\xb9l\x89Hl\xac\\\xebKJS\xf3#\xe5eK\x0b\xd4\x7f\xd7[W\xb8\xd9wE\xd7\x8f\xe48,\xbb,-KTb\xf7+4iVT\xfe\xf0L']
# Bad pipe message: %s [b"\xc9\x89D\xc1\xddp\x9f\x95\xc0\xab0\x10]\xc1(\x15\xa4\xe0U\xf3D!.\x87\x0bz\x97X\x9f\xb3\x02\x1cVO\x86#\xbe\x9d\xb4\xc0\xfb\x82\x13\xc90\x07\xd8\xc1\xbdyf\x94~S\xbe\xdf\xc8-[u\x9dU\xf0\xa6\xfeA\x11\xf0\x18\x92\xcd\xc1}\x06\xd1\x1c\xccw'\x8ec;\xe0S\x17\x1b\x04\x8c\xe0\x01\x85\xf8\xf4\xc9\x13B\x86\xd2\xb6PwG\x17\xde\x853\xba\x84\xc3D\xd0\x9d\xb1V\x0b\xcd\xa8:4\x84Z\xc3j\xb6 \x00\x99\x15\xb2\x84\x03\x17T\xf0\xd2\xa0\x11\x1a\xa3\xf5\xeb{/\x1c$s\xa7h\x1c;S\xee|h\xa3G\xa4Vc\xc6\x1d\xec\xcd\x19\xa7\x17\x7f\xb4D\xb2\xc5\xaf\x84%T\xbb\x0c|\x9e\x94\x94\xd2h\x84\xa5\xa6\x81t[FOW\xba\xd3s0J4\x0f \xe8\n\x11J5\xd8\x94:\xb3\xe1uQ\xf9"]
# Bad pipe message: %s [b'\x82\t\xcb\x86\xc4fu^\x08\xaf\xa2s\x93\x9b\x1b]\xd8\xa9\x7f\xc3ko\x94\xeb\x8e\xbaB\x90\xf5\x82\xc9\xd7\x99!L\xd9WM@\xa8\x7f\xf2\x99\x1e\xf7V\xc9\xb6\x1dUDO\xed,\xba>\xe8\x01\x10x\x13\xbeF\xb3\\\x04\xb2\x14G\\\x0b\x9c(\xdb\xd7D\xa6\xe3k\x8b\xd4\xb9\x99\xd5x\xbd\\\x14\x02bk\xe9\x01']
# Bad pipe message: %s [b'\xc1\xbd\xd9\xd5<\x1b\x9cf+\x14\xa8\x9b"1\xa6\x85\x89']
# Bad pipe message: %s [b'\xa93\xbf\xe4[9\x02U\xe8\xec\xb2^\x13;\xe7\tM\xce\x0c\x82\x11\xa3\x84Q\xc2\x8d\x83v\x1e\xdf;8\xef\xd0p\x86!\x19w\xc7\x91\x0fE{\xf0\xa5u\x7f\xaa\x96\x8f \xac\xa4\x96{\x0e&\xccU\xe6\xa1-\x9a3\xd7\x03\xaf~a\xba\xb2\xe3', b'I\x00\xdf\x8cP,L\x08P\xfb"\xcd\xd0tO\x00\xcf\xbb\xe5\x08\x1d\xd9\x0c\xc7\x88?\x0b\x8aJ\xc3\x1bb\xbcU\xc6|\xf6\x85tt\x806&t>\xb0\xa8\xac\xc8\x08\r\x8cA\xdbpn\xd8<G\x8f\xbcf`\x05\xa2\x88\x17\x88UF\x05I\xdatl\xbbpN5.\xab\xd9\x85\x90l\x8c\xa6,\xca\\\x18\xa2,\xea\x9aA\x94\x11\xf9\xa5\xb0\xf8\xf2\xc4\'\xc81>\x89m\x02:\x89\x14\xf2(\x99P.\x99\xa7']
# Bad pipe message: %s [b"\x14^'x\x82\xc9\xb3D\xd9\x18\xbe\xb4m\x90\x87u\xe8\x00\xac\x08\\$\xe43\xc0\xcdj\xcdY\xfb\xbdu\x11u\x93\xeb\x18M\xcbppuW\xd7g\x123\xb2\x7f\xd2R\x9bD\xaaL\xeeEL\xd9$u)\xe1~\xc4Yv\xdd\x17\xb4^\xa1\x9e{q\xc3\xc8\xe9Eur\xb4\xf1\x8bt\x13%>\xca\x19{\x85!\x00\x9f\xbc\x0beH\x1c_\xec(\xa9\x0c\x80\xdcFQ\x9c\x98I\x00\xa4\xb5\xb6@\x11\x94"]
# Bad pipe message: %s [b"\xccj\r&\x81\xa7\x84`\xd3$v\xbc19L\xd3\x18\x03\xdb\xbc\x0f[-\tq\xbe\xb1f\xc8Z\xd2;\xa0tl\xed$\xb8\xd1\xb8\xac\xc9\xa7B\x04\x95x\xef\xd1\x95M\xf3\xa5\x91\xf9\xcc\x17\xb0w\xa2\xf8\x8a\xdf3E\xdf9\xc4\x9f\xf0C\\\xf0v\x9a\xba\xce\x81\x05M\xe4,Z1`\x95830\xb9\xd8\x9c\x98\xd7\x81\x9ej*\xa6'\xb2u\x86"]
# Bad pipe message: %s [b'\x8a\xe0\xad\xae\xb4!m\x85\xb5^\xc7Y\x13\x85\xb2*5\xbf0\xc9\x95\xc3\x8c\x17\xdf,\x19HK\xcd\xa9g\xc5\xea\x04X\x9bJ\x04[\xd1\xb6n\x8a\xb5a2-?8NK2<j\xeax\x11\x910W\xcc\xc5S8F&\xc5\x11\x83y\x1f{kl?$T\xee\xb0\\S,R\xff+:"\xd5S\xe7|\xc50\xdc\x8f\xa9\x88dF\xa5>\x87q\x05\x01\xbb0\xca\xe1\x83\xbf\x07\x0e]\x99\xa8\x9flA\x82\xe6S%\x1b\x04k\xb4\xce\x1d\xeb\xc2\x98\t\x9f\x08\x95\xbbd\xe8\xb9\x19\x89P\x99g', b'\xf7\xc6:y=^\xa4>rhiE(9RI\x157\x82\x1eA\xc7\x18\xe6\xa9', b'\xc7\x03\x9e\xb9\xb3t\x94c\xf8\x1b\x13cR,-Pm\xfd\x87\xb5\xe0\x93\xa5q\x83\x9b[3\x12\xb9lP]\xb0M\xd6\xe5i\xe8hSx|@\xa2\xe9\x18\xb5g\x85\x01\x1cZ\xb5\xc5\x1d\x91\xe4[\xa7\xc2;\xd4\xd6F\xfd)T\x9ai\x97&6\x07\x07\'\xa3\x8b\x96(\xe7\xa9n\xe2\x1c\xb7\x15\x1b\x86|b\x92\xf9\xd55\xe9\xdc\x9a\xef\x88\x7f\xb4\xfb\xad\xda$\x1f\xf4\xb6\x977\xf6\xb4b\x19\x8bY\xfc\x88\x89"\xc0JT\x92\x93\x18]w\xf7\xa3\xdf', b'rdh\xe0\x851c\xb5\x8d\xf1A\x04\xb80\x91\xe9\x02W\xf0\x83@A\x93\x83\xf6\x17py\x86\x08\xd0\xb1*<\xd5U!\xf5]\x9f\xc1\x0e\xee\x9aG[\xe7\x11\xe4\\{a\x05R\xce\x05\xa9\xb8Fb;\x96\x10\xf1[\xaer\tH\x08\xd8!8\xdb\xa6o\\S\xf9\x08:\xab\xe9\x08QL\x1d>1\x84\xccl?l\xf2\x0b4`\x80\xe9bCfV\x9a\xbd\xd50\x07\xec\xc2\\y\x12\xf7e\xcd9\x93\x84', b'q>\xa8\x05\xed\x97\x1d\xd6C\xcbx\xab\xc5\xff*#|\xb6\xa0L\xcc\x9c;;\r\xbb\x89y\xf9\xc6k6\xfb\x145\xc8\n\x80\xda\x02\x11\xea\xb3\xdc\xa1\xb9\xd0\'\x82\xa1U;\xa0t\x97n) \x8fu =\x88<\xcc\x18\x11\x8dJ\xb4\xd2\x05\x91_h\xb3\xe0\x00\x1b6\xe3\x17Y\x0bj\x87V\toI\xaf\x85\xe0Z}\x9b\xb142$\xc5\xd6\xb2\x9f\xc1D!\x86\x8d\xf35\xb2f\xa2\xa7\xe1\xa9\x91\x89\x9c\xa7\x9d\xcc\x99\x96\xdcNl,\x8cw\xd7ls@"\xab\x08\xb2l\xa43|4`\x10\xc0\x95b\xbb\xa4#\xec@KX2\xa24Q\xb7\xf8H\xdf\t"F\xa7~:Le)Z\x83\xa7bn\xbe\xac\xc7\x1a\x87\x06GKB*\xd3A\x18z\x979tf\xd9\xd2\x06\xd6\x86VdtM\x05h[e3w\x860d\xc2\xcbe\ni\x08\x7fP']
# Bad pipe message: %s [b'\x93}j\xd09r\xfcvd%\x8f\x10\x8b\x1d\x13:B\xf5\x04\x80?\x02l\rGFAyD\xf1F\x08\xa9\xe3Qp\x88\xa7\xdc\x13\x8f"Y\x99Ts*N\xd1\x10\xc3rM$&\x97\x1f\xf4\x82\xcff\x93']

# %%
observed_crp = subject_serial_rep_crp(data, mixed_mask, min_lag, max_lag, size)
control_crp = subject_serial_rep_crp(control_dataset, control_mask, min_lag, max_lag, size)

results = test_serial_rep_crp_vs_control(observed_crp, control_crp, max_lag)
for label, result in results.items():
    print()
    print("=" * 60)
    print(f"Statistical Tests: {label}")
    print("=" * 60)
    print(result)
# Out:
# ============================================================
# Statistical Tests: First Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#     1 |  -10.538     0.0000 |      0.0     0.0000 |    -0.1624
#     2 |  -10.226     0.0000 |      0.0     0.0000 |    -0.0110
#     3 |   -4.063     0.0007 |     15.0     0.0005 |    -0.0033
#
# ============================================================
# Statistical Tests: Second Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#     1 |   10.709     0.0000 |      0.0     0.0000 |     0.1693
#     2 |    9.691     0.0000 |      0.0     0.0000 |     0.0182
#     3 |    6.494     0.0000 |      1.0     0.0000 |     0.0035
