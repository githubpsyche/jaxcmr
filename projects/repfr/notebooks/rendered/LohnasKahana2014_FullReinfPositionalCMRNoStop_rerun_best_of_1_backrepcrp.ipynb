# %% [markdown]
# Measure how often recalls move from a newly revisited repeated item to the neighbours of its earlier presentation. The `min_lag` filter enforces spaced repetitions, and the resulting curve highlights backward spread relative to the full forward/backward profile charted in `repcrp`.
#
# Adjust `control_trial_query` to define alternative control populations.
#
# Modify `min_lag` if you need to tighten or relax the spacing filter.

# %%
import os

import matplotlib.pyplot as plt

from jaxcmr.analyses.backrepcrp import (
    plot_back_rep_crp,
    subject_back_rep_crp,
    test_back_rep_crp_vs_control,
    test_first_second_bias,
)
from jaxcmr.helpers import find_project_root, generate_trial_mask, load_data
from jaxcmr.repetition import make_control_dataset
def save_figure(figure_dir, figure_str, suffix=None):
    plt.tight_layout()
    if not figure_str:
        plt.show()
        return
    os.makedirs(figure_dir, exist_ok=True)
    suffix_str = f"_{suffix}" if suffix else ""
    figure_path = os.path.join(figure_dir, f"{figure_str}{suffix_str}.png")
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()

# %%
data_path = "data/LohnasKahana2014.h5"
figure_dir = "results/figures"
figure_str = ""
ylim = None
mixed_trial_query = "data['list_type'] > 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 10
min_lag = 4
max_lag = 5
size = 2

# %%
# Parameters
data_path = "projects/repfr/results/simulations/LohnasKahana2014_FullReinfPositionalCMRNoStop_rerun_best_of_1.h5"
figure_dir = "projects/repfr/results/figures/fitting"
figure_str = "LohnasKahana2014_FullReinfPositionalCMRNoStop_rerun_best_of_1_backrepcrp.png"
mixed_trial_query = "data['list_type'] > 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 1
ylim = [0.05, 0.32]

# %%
project_root = find_project_root()
figure_dir = os.path.join(project_root, figure_dir)
data_path = os.path.join(project_root, data_path)
data = load_data(data_path)
trial_mask = generate_trial_mask(data, mixed_trial_query)
control_dataset = make_control_dataset(data, mixed_trial_query, control_trial_query, control_shuffles)
control_mask = generate_trial_mask(control_dataset, mixed_trial_query)

# %%
plot_back_rep_crp(
    datasets=data,
    trial_masks=trial_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="mixed")
plot_back_rep_crp(
    datasets=control_dataset,
    trial_masks=control_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="control")
# Out:
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\xf1\xfe\xdf|1\xec\x89\xdc\xfc\xa9\xc4\x1f\x1e_\nt\x80\x13 :p\x92\xd4\xb3!\x02\xe6\xf1\xa5WVtv*\x02\t\x15V\x05~\xe5\x91\xbf\xfa\xa0k\xf7\x16\xe2\xfc\xd0\x00*\x9a\x9a\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\xba\xba\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0cJJ\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05', b'\x05\x08']
# Bad pipe message: %s [b'\x01\x08\x06\x06', b'']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x00\x003\x04\xef\x04\xedJJ\x00\x01\x00\x11\xec\x04\xc06']
# Bad pipe message: %s [b'\x0eB\xa3N\xdaz\xc9\xaa\x8a\x1aJ\x91\x82\x03\xb7\xb6\x16\x97\xa8\x05F\xefS\xc9\x9az\xb0\xa7k\xcd8\xfa@\xfdp\x9c/\xcad', b'\x89\xb1xI\\z9\x1b\xa1+\xf8\xd5j0\xf0\x92&\xf4\n\x89\xa1+\x07\xebz\x81\x99\x845\xd3\x0b\xa2a']
# Bad pipe message: %s [b"\x85\x01U\x92\x16\x0f _\x9bH\xa6\x97\xb5\x05\xa2\x075\xc7\xc3\xc03c\n\xdaA\xafhw\xc9K\x03{^\x8aR\xedJ\xab\xeb\xbb/\xfaPGD\xc4[\x88\xd6U\xc8\xd6\x16\x1a\xcb!\x93\xa5\xae%\xa4V\x13\x06N\\\x16\x06\xbb\xf0\x8f\xa4,\xbd\xd787\xd3\x00\x0e\x97\xc2'\x12,t\xab\xe3(\xf5\xa3\x11\\\xf7\x05\xdb1\r\xe8\x18B_\xa5\x8a\xaf\xb8G\x90+\x83l\xa5(\x8b[rh\xd35! \x96\xe0%Q\x90\x95\xcc\xb5\xd4l^\x1cI\xd1\xc53\xc2\x80\x0e!g\x9bT\xa7x,k%F\xa9a\xe7\xec)\x8c\x90`\xc6\xb6\x86\x84\xa0\xb7\xa3\xd0J\x9d\xc7\x1b?\\\x1d!\x81\xcf\xfc\x06\xd0\xbe\xa5\x96\xc2x\xbc\xcc<\x01\xf9\x80\xc0P%r\ne\xb8\x98"]
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b"\r[1YPM\xa6u\xa9\xd1\x13A{\x85N\xd6\xd5\xb0\x14\xb7\xb5\xcdwTo\xe8\x0b\x99PTUs\x82~z\xa8\xd4i\x9fn'\x97\x96e\xcd\x9a\x89/Y\xf6\x1d#\xc9\\\xe0\xa8O\xc9i m\\\x8d\xda\xa8\x06i\x8b[\xd0\xbb\x93\xdaxh\xcd\xe1}\xf9\x13\xba4WE\xb3\x11'Q7N\xb4\xf6n\xd1s\x89w\xf7f)\xdaq\xa5\xc3\xa1\x18\x82+\xa3\xf9\xbb<R\x1eLf=;\x06\xc8~!w\xb7\x87E.\xc2A\xb6\xc2\x86\x96X~\xdb\xb1\x0f\x86\xa8vw\x97\x96\xbb\x12)\xf5\x04\x1bQ\xe9M\xf9\x80?\xd9$'e\xcbt\xa1"]
# Bad pipe message: %s [b'\xfa\xb9\xbaw\xb8\x14\x98XB\x98\xf1\x9d^\xc6`\xe7\x82\x0clrY\xcfbla\x06\x15\xd6\x01X"#\xb9\xb6\x87\x10\x81\xd2\x0c\xdb\xc2@\xb1\xc2\xc4\xa0h4\x11u\x8d\x87\x03\xae\x00\xd9\xa9\x07W\xc7\xdc)\x96\xd4p', b'+e\xea\xf2ar(\xac\x0f\xf2;\xe0IU\xb1\xe7D\xa50\x85\x0b\xb9\x02vs3b%\x96\xf5\xe0\x8f\xb0\x02,F\xa0\xbc\xf3\x80\xcaA(\x0b\x86\xea\xba\xacQ\x80}q!Ai\x81\x16\xac\xc2\xe3\x80^A\xf48c\xa3b\xab\xdb\xae\x0c\\X\x90\xbb\xa3\xb5\xa5\x9f9F_\xe2WdC\x19\x11^\x10R\x0c\xe0\xa4\xb8\xac\x1b\xed\x0b']
# Bad pipe message: %s [b'\xb2V\x8e\x99\xa93\x0c\\?\xf8.\x17!e\xc5\xca\xc8\xd8\xb1\x11T\xaaN\xeb\x9b,\x02\x1a8\xc6#q\x16\x13>kR\x9ds\t|\xe0BG\xae`2\xf9\x1cq\x805\x13K\xd4ij\xa2\xc8\xf9\x96\xc0\xe7`\x01#\xfb.H\x00\x9d%\xca\x85\xbfD\xb5\x06w\x984;h\x1e\xd70\xd1\x9c\x9c\x91\xc3QWd\xa9ulT\xd0\xe0f\x19\x0c\x1b(\x86}\x7fV\xa5\x8e|\x1d>\x06E\x08\x9aP\x9dj\x82/;\xc6)\x93!P\xf6L:\xc6"\xd3\xf2/c{\x1a\x8c\xc0\xac\x07R\xb5\'4,pL\xa6O\xe4\x00\xfeEL\x1b9*\xc3\x86\x81\xfd2;%C\xc4%\x92\x81~\xa7\x9f\x8a', b"zg\x16\xf7\xd8a\x0e'6\xb6\xd57[\xf8w\x00\x135\xd8W\x1d\xb6z\xbbj#\x0cs\xc3/Y$\xcdO+Q\xa9\xb0W\xa4\x95\xcd\xb0x\x06\xc1\x89Q\x80\xbb\xb7iwv\xbf\xea%7U!\xb6\x90\x9f", b'\x95\xf9\xd0\xac\x1bT\xb5\xc8\xa6"m\xa8e.\x14\x11\x88\x12\x16\xfe\xfc7\xe9\x80\xa1\xfc\x12#\x80\x94^M\x97\r\x89%\xc6P`2\x95\xd7\x86\x0b\xc74i\xc7\x84uk\x93Z\x95\x14\xbfU~\xa8\xf3\x8a\xcf$\xc3Mt<\x10\xda\xceVh\x97\xa8\x07\xa7\xf864\xecq\x92\x8b\xb0\x87w\x86\x9bNI\x8c\xaa`\x05\xfa\xb3\xcc\xe8z\x96\xdc\xe0N\x9bu\xcd\xe3\xaa\x1bu\\j\x9b\x0c\x84\xee\xbc']
# Bad pipe message: %s [b'\x93ho\xb4HQe,g<hU\xf4\xc6\xf8\xfc\x059\x17\x01\xbc\x91^DR\x87\xa8\xd7YMY\x02\x95\xe7\xa6\x96\x9bCm3\x1d\xe2\xa4}\x8b\x1b^\x04\x12@\xb7\x8b\x9f\xcc\xb2\x871\xd4\xcc;\xd0\x8fni?\xfc,\x12\xa4\xe5S\xfa\n4\xb1\xba\xa4\x08\xc9O\xb3\xa3\x7f\x0e7\x19\xa7sl\x05X\x16\xeb\xc8\x9ae\x04ZU\xb0"\x18\xac\x8e\x06\x1a|\x7f[\x15@\x90\x01\'A\x8b\x1d\xb8\x84o\x96\x88c\x04', b"\x92.\xc9i\x94\xa8\x93\n\xa5\x08o)\xebP\xd1\xe1\xc1X9RxTj\xcc\xb9Mk6'c\x05\t\x98k\xcf&Qw\x10\xf1\x8f,\xd2P\xfa\x07\xc2\xa6\xd9%\xa6$\x972=]\xbd\xea\x12\xab\xf1"]
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)

# %%
observed_crp = subject_back_rep_crp(data, trial_mask, min_lag, max_lag, size)
control_crp = subject_back_rep_crp(control_dataset, control_mask, min_lag, max_lag, size)

results = test_back_rep_crp_vs_control(observed_crp, control_crp, max_lag)
for label, result in results.items():
    print(f"\n{'='*60}")
    print(f"Statistical Tests: {label}")
    print(f"{'='*60}")
    print(result)
# Out:
# ============================================================
# Statistical Tests: First Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    3.249     0.0026 |    136.0     0.0027 |     0.0066
#    -4 |    4.324     0.0001 |     99.0     0.0002 |     0.0095
#    -3 |    5.945     0.0000 |     31.0     0.0000 |     0.0119
#    -2 |    6.478     0.0000 |     42.0     0.0000 |     0.0161
#    -1 |    4.777     0.0000 |     57.0     0.0000 |     0.0224
#     0 |      nan        nan |      nan        nan |        nan
#     1 |    1.482     0.1475 |    260.0     0.3766 |     0.0065
#     2 |    1.713     0.0959 |    264.0     0.4128 |     0.0042
#     3 |    3.099     0.0039 |    152.0     0.0067 |     0.0052
#     4 |    4.166     0.0002 |    102.0     0.0003 |     0.0061
#     5 |    4.166     0.0002 |     98.0     0.0002 |     0.0049
#
# ============================================================
# Statistical Tests: Second Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    4.543     0.0001 |     88.0     0.0001 |     0.0065
#    -4 |    4.303     0.0001 |     82.0     0.0000 |     0.0081
#    -3 |    4.212     0.0002 |     98.0     0.0002 |     0.0072
#    -2 |    0.671     0.5067 |    296.0     0.7647 |     0.0014
#    -1 |   -2.863     0.0071 |    158.0     0.0091 |    -0.0057
#     0 |      nan        nan |      nan        nan |        nan
#     1 |    6.221     0.0000 |     35.0     0.0000 |     0.0183
#     2 |    6.420     0.0000 |     23.0     0.0000 |     0.0176
#     3 |    5.748     0.0000 |     49.0     0.0000 |     0.0159
#     4 |    5.458     0.0000 |     59.0     0.0000 |     0.0138
#     5 |    4.682     0.0000 |     62.0     0.0000 |     0.0113
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:476: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_col, ctrl_col, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:487: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff)

# %%
bias_result = test_first_second_bias(observed_crp, control_crp, max_lag)
print(f"\n{'='*70}")
print("Test: First-Second Bias (Observed) vs First-Second Bias (Control)")
print(f"{'='*70}")
print("H0: The preference for first-presentation neighbors over second-presentation")
print("    neighbors is the same in observed data as in the shuffled control.")
print()
print(bias_result)
# Out:
# ======================================================================
# Test: First-Second Bias (Observed) vs First-Second Bias (Control)
# ======================================================================
# H0: The preference for first-presentation neighbors over second-presentation
#     neighbors is the same in observed data as in the shuffled control.
#
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    0.042     0.9665 |    313.0     0.9806 |     0.0001
#    -4 |    0.726     0.4727 |    272.0     0.4911 |     0.0015
#    -3 |    2.030     0.0502 |    211.0     0.0902 |     0.0047
#    -2 |    4.495     0.0001 |     88.0     0.0001 |     0.0147
#    -1 |    5.349     0.0000 |     39.0     0.0000 |     0.0282
#     0 |      nan        nan |      nan        nan |        nan
#     1 |   -3.294     0.0023 |    129.0     0.0017 |    -0.0118
#     2 |   -4.636     0.0001 |     83.0     0.0001 |    -0.0135
#     3 |   -3.940     0.0004 |    115.0     0.0007 |    -0.0108
#     4 |   -3.257     0.0026 |    147.0     0.0051 |    -0.0078
#     5 |   -2.481     0.0182 |    174.0     0.0200 |    -0.0064
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:545: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_d, ctrl_d, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:556: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff_of_diff)
