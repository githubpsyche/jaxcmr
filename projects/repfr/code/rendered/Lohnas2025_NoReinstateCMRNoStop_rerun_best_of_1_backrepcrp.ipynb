# %% [markdown]
# Measure how often recalls move from a newly revisited repeated item to the neighbours of its earlier presentation. The `min_lag` filter enforces spaced repetitions, and the resulting curve highlights backward spread relative to the full forward/backward profile charted in `repcrp`.
#
# Adjust `control_trial_query` to define alternative control populations.
#
# Modify `min_lag` if you need to tighten or relax the spacing filter.

# %%
import os

import matplotlib.pyplot as plt

from jaxcmr.analyses.cleanbackrepcrp import (
    plot_back_rep_crp,
    subject_back_rep_crp,
    test_back_rep_crp_vs_control,
    test_first_second_bias,
)
from jaxcmr.helpers import find_project_root, generate_trial_mask, load_data
from jaxcmr.repetition import make_control_dataset
def save_figure(figure_dir, figure_str, suffix=None):
    plt.tight_layout()
    if not figure_str:
        plt.show()
        return
    os.makedirs(figure_dir, exist_ok=True)
    suffix_str = f"_{suffix}" if suffix else ""
    figure_path = os.path.join(figure_dir, f"{figure_str}{suffix_str}.png")
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()

# %%
data_path = "data/LohnasKahana2014.h5"
figure_dir = "results/figures"
figure_str = ""
ylim = None
mixed_trial_query = "data['list_type'] > 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 10
min_lag = 4
max_lag = 5
size = 2

# %%
# Parameters
data_path = "projects/repfr/results/simulations/Lohnas2025_NoReinstateCMRNoStop_rerun_best_of_1.h5"
figure_dir = "projects/repfr/results/figures/fitting"
figure_str = "Lohnas2025_NoReinstateCMRNoStop_rerun_best_of_1_backrepcrp.png"
mixed_trial_query = "data['list_type'] == 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 1
ylim = [0.05, 0.32]

# %%
project_root = find_project_root()
figure_dir = os.path.join(project_root, figure_dir)
data_path = os.path.join(project_root, data_path)
data = load_data(data_path)
trial_mask = generate_trial_mask(data, mixed_trial_query)
control_dataset = make_control_dataset(data, mixed_trial_query, control_trial_query, control_shuffles)
control_mask = generate_trial_mask(control_dataset, mixed_trial_query)

# %%
plot_back_rep_crp(
    datasets=data,
    trial_masks=trial_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="mixed")
plot_back_rep_crp(
    datasets=control_dataset,
    trial_masks=control_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="control")
# Out:
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)

# %%
observed_crp = subject_back_rep_crp(data, trial_mask, min_lag, max_lag, size)
control_crp = subject_back_rep_crp(control_dataset, control_mask, min_lag, max_lag, size)

results = test_back_rep_crp_vs_control(observed_crp, control_crp, max_lag)
for label, result in results.items():
    print(f"\n{'='*60}")
    print(f"Statistical Tests: {label}")
    print(f"{'='*60}")
    print(result)
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'/\xb4g\x07J\x80\x93\xa0\x9d\xfdb\xb94\xf9a\x9bsj \x0fCM\xab\xdf\xac\xe7*\xf5P]\xf2\xd6\xd8k\xdd\xb5\xf8\xe8\xa15-J\x06\x8f\x9c\xeb\xac\xcd\x0f\xca\x91\x00*ZZ\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n**\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\x1a\x1a\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\x1a\x1a\x00\x01\x00\x11\xec\x04\xc0\xc3\xa1\xb5L\xdc\xa0\xaa\x19Xk\x15$\x1f\xa9Ln\xa8\xa1\xd5J\xc9\x00\xc3D\xd9\xfc\xa8\x8aL\xba\xbct[\x0eAR\x96\xa4Zf']
# Bad pipe message: %s [b'\x1e\x1anD\xab\x9ft\x06\xb6=\x90\xabGD\xc6f\xeb\xb0\xd1\xb2\xa8\x19\nG\x06g\x90\xf7\x08\x8c1iS\xe5\xd2\x08s\x1c\x97\xde\x07\x8a\xbb&4\xd1\xf0r\x06\xc1.\xe0v\xc8F\xe6\xb2~6\xc3\xd5\x07Cq\xd2\x01X\x02ZFC\r\xcdC\x93\x94\xdc\x83n(\xb2<k\x99x\xbaT\xcf\x96A\xe2j-\xfc\x93\xc0\xbf*\xaba\xaa70d]\x8e\x92\xc5J\xb3\x8b\xa0\x08!\xe1\x1c9\x83\xeb\xc4\xc2\xb4)\xf6B\x94\xb1\xeb\x1e\x0e\xa0\x88\xe1rSg\xb9Y\r`,P\xfa\xb0\n\x8a1\xff\xc2\xab\x9a\xca\x873\xc8\xbb\x9b\x85\xc2\x0b\x95pY\xd8\xc2\xe7\xf9\xaa1\x11\xad\xa2\x94?\x0e)9\xd2\x13N\x1e)\x0b\x87s\x12\x96\x8aI.\x03[\xf95\x0c\x05F8\x8f\xb9F"8\x19B1\xab']
# Bad pipe message: %s [b'\x01!\x9d\xf0\x9f_\xabTB\xe5,\xa9\x8e\xba<\x1edo \x00\x07\xc5\x05q\x9f,\xeb\xfc\x18\n<?\x95\x96\xf4\xe4HN\xc4\xf5\x89\xec,\xf8\x12:\x1f\t\xc3\xf6 \x00,\x9a\x9a\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\xca\xca\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\n\n\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00']
# Bad pipe message: %s [b'vIPL\xaeR)\x1eB\xbe"\xa5J\xa5\xfc\x82\x82("*\x81.\x96s2wf,\xdf,_\xd2\xd4{kT\xaa>\x01\x1a\xa1F\x1a \x059b\x13\x93\xe0\xe3\xafKkj\x95p\x9f\xa8\x13\xc1\x81!h\x06\xe0\x8a\xf7\xc1n2\xe4\xc1J`V\x894\x0fD\x19\x03\xf7ko\x15\x19\x94\xdc\xf9\x0f\xb7h\xcfw\x97(\xb3\xf8G\r\xe5(\xc74}mW\x97\xe9\xb2vJ0\xaea\xc8\'\x00\xb5\xc8T#~\xf1{\xb1\x0e3\xa9K\x1c\x92Y\xe6\xc0!\x04\\\x98\xd25\xfdd\xad\x81\x05\xb1\x89\x88}I\xd8\xcb\xfb\x18@\x97\x91.\xee\x07T~|AB\xa5\x1b\'F(u\x8c\x06 H\x00\x15h\xa5\xed\x99|\x8b8f\x10\x9a\x9d\xe8&\x97\x0f|4Z\xd1\xa3\x07\x88\x9f\x80\xd8+2\xc9\x01n\x87\x07\xa8\x847\xc6!c\xe5\xfc\x97#\xb5p\xd2\x19\xb7']
# Bad pipe message: %s ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [b'\xb4xLh\xf7\x03\xc1\xcf&r\xa7#,O\xe5\xae\xd6\xc5\xaa\xb8\x04\xc0)\xe2\x9c\xff\xd6$:\t\x81+\x94\x11\xfb\xf8\x96A\x98\xaf\x06,\x84\x88r{\xc1a=\xf2\xb3P\xfdr{\xac\xa3\xaf\x92\xe3}\xc4\xc4\xc4\xfc\xd8d\rT\xcd(\xe2\x9f\x96V\x9c\t\x125\xb9Q\x82Q\xfa\xa7\xacrx3\xec\x075\xf8vJx\x1d\xa2\x15\x9f\x822$\x97\x05\x1d\xb11\x1c\xb6\x9b\x94`|T\xcd<U\xf0Q']
# Bad pipe message: %sERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
#  [b'\x808\x87 \x9f\xfc$\x04M\xba\x0evi\x1eUl\x931\xd5\x1f\xb3\xe9<\xcf\xc4Q\x00\xa9>\x0b\xf0\xc5L\xe8ZQ\xe5\xab<J\x8d\xdb\xc82\x1b;e\xfd6>\xaf\x93_\xe1J\x155\x14\x83\xbf\xba\x07vlg\xbd\x05\xa4\x80\xf5\x1d\x89\xb8\x9d=\x93\x06\xd8*\xcb\xce\x95\x814\x07N\xc0\x19\x12\xe0A\x84L', b"\xe9\xf8\x9b\xfazL\xe9\xe5?H\x11\x00\xaa\xc9-\x99Ao\xbb{\xba\xaa1\x7fYPf\x03\xba&\xe3\xe0^\xf1)W\xf6\xa7\xad\xe1\x95;\xb2F\xcfZ<i\xe9,'>!\xb8\xc5a\r\x1fs\xcb\x9a\xdb\xaf#\xe0s\xde\x06\xc5y16&\xfa\xcaG\x00h$<\xbf/e\x865\x13\x9d\xf3x\x9f\xdd\xe2\xbf0\x81]\xb1\x9c\x98\xa1\xb3\xc3\xebpRo6\xb2\xc5\x87\xca\xd0\x8b[f\xcc|l\x90\xc5-\xb2\x9e"]
# Bad pipe message: %s [b"\x99\x8fhA\xdc;\\\xd1\x1a\xb5)Y\xa2\x82[U5\xa8\xce\xc7vN\xc3\xd1\xae\xf8i\x0cO\xbbg\xc7\x92\x03\x01\xd9M\xe4\x00\xb8\xa1l\x80\\+-60F\xae\x10\xb6\x89'm\x10WL\t\xd9=d\xd9|\xed\x17\x90:3Q6\xcc\xb1\x8e\xb4H\xe9\xb9\xb6\xd9\xd2A\xef:\x07\xbc\xbb0\xfb\xcc\x91\xc6\xdcc\xaf\xb9 "]ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
#
# Bad pipe message: %s [b'\x83\xa2A\x01g\x02\x8cHr$ u\x9c\x8b\x9bnBy\xaf\x1c\xcan\x1d\xd1|b\xc3N\xcfz\xc0\xbf\xd7\x8f\x83&\xb1\x8e\xd2\x88XLwN\x96g\xc8\x157\n\xb1-\xa3\x9a3$X\rD\x12(6L\x08\xef\xea\xac\x99P\x19\x9e)0\x06\xc9\xaf\xd5\xda\xb1\x83;\xc7\xca\xc0X\x86\xfa\x99I\x08\xb3\xee\xb5o\xde\xb4\x8b[\x04Vd\xd9@^2\x12\x1e2C\xb7\xec\x10\xd7\x07H\xa6\x06f\x08x\x11\xfe"U\x02\xe6\xa98\x80.\xea\x83\xa7\xf1\x145C\x97\xc5\xe0K\x94\xee\x16\xa6\'C\xcc\x8cx', b'4\x9d8\xc5\xae\xde\xca\xadeY', b'\xd87_\x10\xaan\xf6+Hh\x8e\xeb\x02\xc2\xe7\xb13S\x82\xcb,q\x98\xf7{^\xa9\x98T\xfde\xcd\xcc[\x0b^\xf6']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'q\x12\rk\xce\xd4\x00ug9\x00cy.Y\xe7f\xd4\xbb\xba\x1bR\xb9\x88\xb4\x0b\xd0\xf4\x99\xccab\xa6\xdd\xf5\xb8\x8b\xde\x0fGY\xfe\x91\x90\xf6I\x8d7G\x15\xb6\xf6\xe2\xab\x85\x15`{\xbcp\x0cX\xa6h\xf9\xfa\xfe\x9b\x88]\x93M\xc8X\xc0c\xe2\xf3\x18\xd5\xc9o\xac\xe8\xf61j\xd1\x97\xb2']
# ============================================================
# Statistical Tests: First Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    1.802     0.0725 |  23898.0     0.0133 |     0.0051
#    -4 |    0.528     0.5975 |  26318.0     0.2278 |     0.0011
#    -3 |    1.807     0.0716 |  23677.0     0.0073 |     0.0042
#    -2 |    3.877     0.0001 |  21054.0     0.0000 |     0.0083
#    -1 |    7.793     0.0000 |  15230.0     0.0000 |     0.0247
#     0 |      nan        nan |      nan        nan |        nan
#     1 |    3.251     0.0013 |  21622.0     0.0002 |     0.0083
#     2 |    0.305     0.7603 |  27906.0     0.7499 |     0.0006
#     3 |   -0.809     0.4190 |  28463.0     0.9940 |    -0.0016
#     4 |   -0.653     0.5141 |  28447.0     0.9869 |    -0.0013
#     5 |    2.455     0.0146 |  22424.0     0.0007 |     0.0079
#
# ============================================================
# Statistical Tests: Second Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |      nan        nan |      nan        nan |        nan
#    -4 |      nan        nan |      nan        nan |        nan
#    -3 |      nan        nan |      nan        nan |        nan
#    -2 |      nan        nan |      nan        nan |        nan
#    -1 |      nan        nan |      nan        nan |        nan
#     0 |      nan        nan |      nan        nan |        nan
#     1 |      nan        nan |      nan        nan |        nan
#     2 |      nan        nan |      nan        nan |        nan
#     3 |      nan        nan |      nan        nan |        nan
#     4 |      nan        nan |      nan        nan |        nan
#     5 |      nan        nan |      nan        nan |        nan
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:476: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_col, ctrl_col, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:487: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff)

# %%
bias_result = test_first_second_bias(observed_crp, control_crp, max_lag)
print(f"\n{'='*70}")
print("Test: First-Second Bias (Observed) vs First-Second Bias (Control)")
print(f"{'='*70}")
print("H0: The preference for first-presentation neighbors over second-presentation")
print("    neighbors is the same in observed data as in the shuffled control.")
print()
print(bias_result)
# Out:
# ======================================================================
# Test: First-Second Bias (Observed) vs First-Second Bias (Control)
# ======================================================================
# H0: The preference for first-presentation neighbors over second-presentation
#     neighbors is the same in observed data as in the shuffled control.
#
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |      nan        nan |      nan        nan |        nan
#    -4 |      nan        nan |      nan        nan |        nan
#    -3 |      nan        nan |      nan        nan |        nan
#    -2 |      nan        nan |      nan        nan |        nan
#    -1 |      nan        nan |      nan        nan |        nan
#     0 |      nan        nan |      nan        nan |        nan
#     1 |      nan        nan |      nan        nan |        nan
#     2 |      nan        nan |      nan        nan |        nan
#     3 |      nan        nan |      nan        nan |        nan
#     4 |      nan        nan |      nan        nan |        nan
#     5 |      nan        nan |      nan        nan |        nan
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:545: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_d, ctrl_d, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/backrepcrp.py:556: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff_of_diff)
