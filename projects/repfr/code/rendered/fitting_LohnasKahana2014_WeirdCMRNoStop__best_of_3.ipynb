# %% [markdown]
# Use this notebook to orchestrate a single model fit, simulate from the fitted parameters, and generate benchmark diagnostics.

# %%
# import jax
# jax.config.update("jax_disable_jit", True)
# jax.config.update("jax_debug_nans", True)

import inspect
import json
import os
import warnings
from pathlib import Path
from typing import Any, Mapping, Sequence, cast, Type

import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, display
from jax import random
from matplotlib import rcParams  # type: ignore

from jaxcmr import repetition
from jaxcmr.helpers import (
    find_project_root,
    generate_trial_mask,
    import_from_string,
    load_data,
    save_dict_to_hdf5,
)
from jaxcmr.simulation import simulate_h5_from_h5
from jaxcmr.summarize import summarize_parameters

warnings.filterwarnings("ignore")

# %% [markdown]
# Parameter Setup

# %%
# Run configuration
base_run_tag = "fixed_term"
experiment_count = 200
max_subjects = 0

# Data parameters
base_data_tag = "HealeyKahana2014"
data_tag = "HealeyKahana2014"
data_path = "data/HealeyKahana2014.h5"
embedding_path = ""#"data/peers-all-mpnet-base-v2.npy"
emotion_feature_path = ""#"data/emotion_features_7col.npy"
feature_column = 6
concat_features = False
trial_query = "data['listtype'] == -1" 
target_directory = "results/"

# algorithm selection
model_name = "WeirdCMRNoStop"
make_factory_path = "jaxcmr.models.cmr.make_factory"
# model_name = "MultiplicativeIsolatedArousalSimpleECMRNoStop"
# make_factory_path = "jaxcmr.models.simple_ecmr.make_factory"
component_paths = {
    "mfc_create_fn": "jaxcmr.components.linear_memory.init_mfc",
    "mcf_create_fn": "jaxcmr.components.linear_memory.init_mcf",
    "context_create_fn": "jaxcmr.components.context.init",
    "termination_policy_create_fn": "jaxcmr.components.termination.NoStopTermination",
}

sim_alg_path = "jaxcmr.simulation.simulate_study_free_recall_and_forced_stop"
loss_fn_path = "jaxcmr.loss.transform_sequence_likelihood.ExcludeTerminationLikelihoodFnGenerator"
fit_alg_path = "jaxcmr.fitting.ScipyDE"
parameters = {
    "fixed": {
        "allow_repeated_recalls": False,
        "learn_after_context_update": False,
    },
    "free": {
        "encoding_drift_rate": [2.220446049250313e-16, 0.9999999999999998],
        "start_drift_rate": [2.220446049250313e-16, 0.9999999999999998],
        "recall_drift_rate": [2.220446049250313e-16, 0.9999999999999998],
        "shared_support": [2.220446049250313e-16, 99.9999999999999998],
        "item_support": [2.220446049250313e-16, 99.9999999999999998],
        "learning_rate": [2.220446049250313e-16, 0.9999999999999998],
        "primacy_scale": [2.220446049250313e-16, 99.9999999999999998],
        "primacy_decay": [2.220446049250313e-16, 99.9999999999999998],
        "choice_sensitivity": [2.220446049250313e-16, 99.9999999999999998],
        # "emotion_attention": [2.220446049250313e-16, 9.9999999999999998],
        # "emotion_scale": [2.220446049250313e-16, 9.9999999999999998],
        # "lpp_scale": [2.220446049250313e-16, 9.9999999999999998],
        # "delay_drift_rate": [2.220446049250313e-16, 0.9999999999999998],
    },
}

# Flow toggles
filter_repeated_recalls = True
handle_elis = False
redo_fits = True
redo_sims = True
redo_figures = True

# hyperparameters
seed = 0
relative_tolerance = 0.001
popsize = 15
num_steps = 1000
cross_rate = 0.9
diff_w = 0.85
best_of = 3

# analysis configuration
comparison_analysis_configs = [
    #     {"target": "jaxcmr.analyses.cat_spc.plot_cat_spc", "figure_suffix": "cat_spc_negative", "kwargs": {"category_field": "condition", "category_values": [1]}},
    # {"target": "jaxcmr.analyses.cat_spc.plot_cat_spc", "figure_suffix": "cat_spc_neutral",  "kwargs": {"category_field": "condition", "category_values": [2]}},
    {
        "target": "jaxcmr.analyses.nth_item_recall.plot_conditional_nth_item_recall_curve",
        "kwargs": {"query_study_position": 1},
    },
    {
        "target": "jaxcmr.analyses.nth_item_recall.plot_conditional_nth_item_recall_curve"
    },
    # {"target": "jaxcmr.analyses.distcrp.plot_dist_crp"},
    {"target": "jaxcmr.analyses.nth_item_recall.plot_simple_nth_item_recall_curve"},
    {"target": "jaxcmr.analyses.spc.plot_spc"},
    {"target": "jaxcmr.analyses.crp.plot_crp"},
    {"target": "jaxcmr.analyses.pnr.plot_pnr"},
    {"target": "jaxcmr.analyses.termination_probability.plot_termination_probability"},
]

single_analysis_configs = [
    # {"target": "jaxcmr.analyses.cat_spc.plot_cat_spc", "kwargs": {"category_field": "condition", "category_values": [1, 2], "labels": ["Negative", "Neutral"]}},
]

# %%
# Parameters
redo_fits = True
redo_sims = True
redo_figures = True
handle_elis = False
filter_repeated_recalls = False
base_run_tag = ""
experiment_count = 200
max_subjects = 0
base_data_tag = "LohnasKahana2014"
data_tag = "LohnasKahana2014"
data_path = "data/LohnasKahana2014.h5"
trial_query = "data['list_type'] > 0"
target_directory = "projects/repfr/results/"
component_paths = {"mfc_create_fn": "jaxcmr.components.linear_memory.init_mfc", "mcf_create_fn": "jaxcmr.components.linear_memory.init_mcf", "context_create_fn": "jaxcmr.components.context.init", "termination_policy_create_fn": "jaxcmr.components.termination.NoStopTermination"}
sim_alg_path = "jaxcmr.simulation.simulate_study_free_recall_and_forced_stop"
loss_fn_path = "jaxcmr.loss.set_permutation_likelihood.MemorySearchLikelihoodFnGenerator"
fit_alg_path = "jaxcmr.fitting.ScipyDE"
seed = 0
relative_tolerance = 0.001
popsize = 15
num_steps = 1000
cross_rate = 0.9
diff_w = 0.85
best_of = 3
comparison_analysis_configs = [{"target": "jaxcmr.analyses.spc.plot_spc", "figure_suffix": "spc"}, {"target": "jaxcmr.analyses.crp.plot_crp", "figure_suffix": "crp"}, {"target": "jaxcmr.analyses.pnr.plot_pnr", "figure_suffix": "pnr"}, {"target": "jaxcmr.analyses.repneighborcrp.plot_repneighborcrp_i2j", "figure_suffix": "epneighborcrp_i2j"}, {"target": "jaxcmr.analyses.repneighborcrp.plot_repneighborcrp_j2i", "figure_suffix": "repneighborcrp_j2i"}, {"target": "jaxcmr.analyses.repneighborcrp.plot_repneighborcrp_both", "figure_suffix": "repneighborcrp_both"}, {"target": "jaxcmr.analyses.rpl.plot_rpl", "figure_suffix": "rpl"}, {"target": "jaxcmr.analyses.rpl.plot_full_rpl", "figure_suffix": "full_rpl"}]
single_analysis_configs = [{"target": "jaxcmr.analyses.repcrp.plot_rep_crp", "figure_suffix": "repcrp"}, {"target": "jaxcmr.analyses.backrepcrp.plot_back_rep_crp", "figure_suffix": "backrepcrp"}]
model_name = "WeirdCMRNoStop"
make_factory_path = "jaxcmr.models.cmr.make_factory"
parameters = {"fixed": {"allow_repeated_recalls": False, "learn_after_context_update": False}, "free": {"encoding_drift_rate": [2.220446049250313e-16, 0.9999999999999998], "start_drift_rate": [2.220446049250313e-16, 0.9999999999999998], "recall_drift_rate": [2.220446049250313e-16, 0.9999999999999998], "shared_support": [2.220446049250313e-16, 100.0], "item_support": [2.220446049250313e-16, 100.0], "learning_rate": [2.220446049250313e-16, 0.9999999999999998], "primacy_scale": [2.220446049250313e-16, 100.0], "primacy_decay": [2.220446049250313e-16, 100.0], "choice_sensitivity": [2.220446049250313e-16, 100.0]}}

# %%
# derive run tag
from jaxcmr.typing import FittingAlgorithm, LossFnGenerator, TrialSimulator


run_tag = f"{base_run_tag}_best_of_{best_of}"
if max_subjects:
    run_tag += f"_nsubs_{max_subjects}"

# set up rng
rng = random.PRNGKey(seed)

# add subdirectories for each product type: json, figures, h5
product_dirs = {}
for product, subdir in {"fits": "fits", "figures": "figures/fitting", "simulations": "simulations"}.items():
    product_dir = os.path.join(target_directory, subdir)
    product_dirs[product] = product_dir
    if not os.path.exists(product_dir):
        os.makedirs(product_dir)

# load data
project_root = Path(find_project_root())
data = load_data(os.path.join(project_root, data_path), max_subjects)
trial_mask = generate_trial_mask(data, trial_query)

# load feature blocks
semantic_features = None
if embedding_path:
    semantic_features = np.load(project_root / embedding_path).astype(np.float32)

categorical_column = None
if emotion_feature_path:
    emotion_features = np.load(project_root / emotion_feature_path).astype(np.float32)
    categorical_column = emotion_features[:, feature_column : feature_column + 1]

modeling_features = semantic_features
if concat_features:
    modeling_features = np.concatenate([categorical_column, semantic_features], axis=1)  # type: ignore

# import analyses
comparison_analyses = []
for config in comparison_analysis_configs:
    analysis_fn = import_from_string(config["target"])
    figure_suffix = config.get("figure_suffix")
    if figure_suffix is None:
        name = getattr(analysis_fn, "__name__", "analysis")
        figure_suffix = name[5:] if name.startswith("plot_") else name
    labels = tuple(cast(Sequence[str], config.get("labels", ("Model", "Data"))))
    contrast_name = config.get("contrast_name", "Source")
    extra_kwargs = dict(cast(Mapping[str, Any], config.get("kwargs", {})))

    analysis_name = analysis_fn.__name__
    if "dist_" in analysis_name and semantic_features is not None:
        extra_kwargs.setdefault("features", semantic_features)
    elif "cat_" in analysis_name and categorical_column is not None:
        extra_kwargs.setdefault("features", categorical_column)

    comparison_analyses.append(
        {
            'target': analysis_fn,
            'figure_suffix': str(figure_suffix),
            'labels': labels,
            'contrast_name': str(contrast_name),
            'kwargs': extra_kwargs,
            'ylim': config.get('ylim', None),
            'color_cycle': config.get('color_cycle', None)
        }
    )


single_analyses = []
for config in single_analysis_configs:
    analysis_fn = import_from_string(config["target"])
    figure_suffix = config.get("figure_suffix")
    if figure_suffix is None:
        name = getattr(analysis_fn, "__name__", "analysis")
        figure_suffix = name[5:] if name.startswith("plot_") else name
    labels = tuple(cast(Sequence[str], config.get("labels", ("Model",))))
    contrast_name = config.get("contrast_name", "Source")
    extra_kwargs = dict(cast(Mapping[str, Any], config.get("kwargs", {})))

    analysis_name = analysis_fn.__name__
    if "dist_" in analysis_name and semantic_features is not None:
        extra_kwargs.setdefault("features", semantic_features)
    elif "cat_" in analysis_name and categorical_column is not None:
        extra_kwargs.setdefault("features", categorical_column)

    single_analyses.append(
        {
            'target': analysis_fn,
            'figure_suffix': str(figure_suffix),
            'labels': labels,
            'contrast_name': str(contrast_name),
            'kwargs': extra_kwargs,
            'ylim': config.get('ylim', None),
            'color_cycle': config.get('color_cycle', None)
        }
    )

# configure model factory
make_factory = import_from_string(make_factory_path)
model_factory = make_factory(
    **{key: import_from_string(path) for key, path in component_paths.items()}
)

# import fitting and simulation functions
fitting_algorithm: Type[FittingAlgorithm] = import_from_string(fit_alg_path)
loss_fn_generator: Type[LossFnGenerator] = import_from_string(loss_fn_path)
simulate_trial_fn: TrialSimulator = import_from_string(sim_alg_path)

# derive list of query parameters from keys of `parameters`
query_parameters = list(parameters["free"].keys())

# make sure repeatedrecalls is in either both data_tag or data_path, or is in neither
if "repeatedrecalls" in data_tag.lower() or "repeatedrecalls" in data_path.lower():
    if (
        "repeatedrecalls" not in data_tag.lower()
        and "repeatedrecalls" not in data_path.lower()
    ):
        raise ValueError(
            "If 'repeatedrecalls' is in data_tag or data_path, it must be in both."
        )

# %% [markdown]
# Fit model.

# %%
fit_path = Path(product_dirs["fits"]) / f"{data_tag}_{model_name}_{run_tag}.json"
metadata = {
    "run_tag": run_tag,
    "data_tag": data_tag,
    "data_query": trial_query,
    "model": model_name,
    "name": f"{data_tag}_{model_name}_{run_tag}",
    "components": component_paths,
    "fit_algorithm": fit_alg_path,
    "loss_function": loss_fn_path,
    "model_factory": make_factory_path,
    "embedding_path": embedding_path,
    "emotion_feature_path": emotion_feature_path,
    "feature_column": str(feature_column),
    "concat_features": str(concat_features),
}

if fit_path.exists() and not redo_fits:
    with fit_path.open() as handle:
        results = json.load(handle)
    if "subject" not in results["fits"]:
        results["fits"]["subject"] = results.get("subject", [])
    results |= metadata

else:
    fitter = fitting_algorithm(
        data,
        modeling_features,
        parameters["fixed"],
        model_factory,
        loss_fn_generator,
        hyperparams={
            "num_steps": num_steps,
            "pop_size": popsize,
            "relative_tolerance": relative_tolerance,
            "cross_over_rate": cross_rate,
            "diff_w": diff_w,
            "progress_bar": True,
            "display_iterations": False,
            "best_of": best_of,
            "bounds": parameters["free"],
        },
    )

    results = fitter.fit(trial_mask) | metadata
    with fit_path.open("w") as handle:
        json.dump(results, handle, indent=4)

print(
    summarize_parameters([results], query_parameters, include_std=True, include_ci=True)
)
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]Bad pipe message: %s [b'\x8f\xd7\x04~]\x827\xb4\x8b\xc33\xd3\x7f9\xbe\xd7\x8c= 4\xf8\x8f\x15y@\x8ftpY\xc4\xcaX\xfd\x06[5\xb9PA\x9aol\xde1)\xca\x16$\x1bA\xb1\x00*::\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\xfa\xfa\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c**\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00', b'\x0e\x00\x0c\x02h2\x08http/1.1']
# Bad pipe message: %s [b'\xbegC\xc9\xe4\xc8\xa1\xd5\xcc/\x1bY\x00\x96\x13\xaf\xcd\x94 \xb8\x13\x0c?\x87=\xc1\xcc\xab\xebbbl\xdf<"\xc8\xab\x8a\x0b\x0e\x8a\n\xa5\xf3\xb1R\xa5\xdedl]\x00,ZZ\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\x9a\x9a\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xba\xba\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00']
# Bad pipe message: %s [b'\x05\x01\x00\x00']
# Bad pipe message: %s [b'\xc7.\xe7\x99\x83\x0b\x87\x1b~&\xc6\xd6g\xda\x98\x8b\xfcR s\x82\xb0\xff\x15\xc6\xd4\xc1N\x15\xa6O\xd7\x9fL\x11\xf0\xde\xb9\xca\xd9\xc4\x8c\xa6\x84\x1a\xe6\xfe\x0b,\x95\xee\x00*ZZ\x13\x02\x13\x03\x13\x01']
# Bad pipe message: %s [b'\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\x1a\x1a\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\x9a\x9a\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\x9a\x9a\x00\x01\x00\x11\xec\x04\xc0/\xbaZ/\x16o\xedq\xa8:\xb42\x9fU_l\x055\xb9XS\x88#\xba\xf9\x00\xbf\x00\xbbR*\xe4\x11\xb5\xa6\x90\x16k\n\t`LS6\x82\xfa']
# Bad pipe message: %s [b'BB&oRZ\x8d\xc5\x11F\xd7\xa4\x122\xa8U\xa3j\xe9\xd7U\xe8!,\xf0\x11\xcc\xb7;\xaa\x15\xa6`\xa8\xb2G\x9c\x13\x90\xd2\xec7\x043\x0c\xd1L\x8b\xf8\xf5\x88\xc9U\xb5\xa1\x96=G\xf1\xa3\xe6\x99@\xb4\xb3\xcef\xa8\x8f\x17\xea>L5\x08A\xb8\xadX\x900,17\x94\xf1\x92]\x8c\x14v@\xa4\x0b9\xcb?\xdc<\xe3q\x17\x05"H^\xb60\x8a\x96\x11t\xe9\x97\xed\xf3\xc4g\xdbv_\x87/t\xa1L\x01\xa8\x019fW\x02', b'E\xc8\xc4\xb1u\x9d6|w*\xfa\x9a|ZH\x90U\xb1+\xda\x88\xc3\xa0\xa4L\x92)R\xd6`\xca4\x8c0\xa2M\x17y\xbfzlA\x13\x0c"\xc5\x88 \x18\x86\xcfO\xf8\xc0\x8f\xa1a\xd8e\x19[\x92\xa4\xc3\xe5\xaf\x9cQ\xc0\x14\x8a\xbf\x86\xba\x18\xc8\xd1b\x13\x95\x16\xe2\x1b5r\xe3\x1b\x19qe\xbe\xb0e\x1f(N\xab\x82;\xf2 Zt\xa4\x04v\xf5\xaa\x9b\x1al\xda4\x8b\xf4PC\xe47\x00c\xe2?\r$\xab\x1e\x17\x04\xfc\xe4\x80\xfe\xca\x17\xf5\x83\x8d\'\x16\xba\xbd\x99n\r\x81zHSK\xaf\x069z\xbc2\xaaY?#\xe1\x1ak\x11\x9c\xbbd\x1an8\xbc\x8d\xa4]])\x89PB\xce\xa83']
# Bad pipe message: %s [b'\xbcK\xb1D\x96\xa2\xcc\xb8\x13\xe2~3\td\xed3\x9c\x89\xa8J\x85\x12\x14\x00\x19\x06\t\x1b{\xf3\x964\xb6\x99&\xdf\xd1\xa1@lR\x96w\x03Sp\xab\xc6\xf7u\x06\x95\x0f\xb0\xd6Igg?=RX\xbdJO\x97\xe4?\x83zV\xcb\xbb4\xfd\xf8\xc1o\x03J\xb7\x1cm\xaf\xc8\t\xbcP4\xed\xe3;;\xc2\x12\xdeW\x98~E0\xd4\\\x05\xadX\xbe"\xac\xa3\xe2\'\xba\xea\xd7\x91"wU\xecJEQ)\x07\xefu\x1d\x9b|\x99\xe38n\xbfz\x00\xd8ceDy:\xebR\r\x11\xd0\x87;\x99jA\x83\xb7\xc3K%']
# Bad pipe message: %s [b'\x84>i\x97\xcf\x90\xcc\x10\xe8a\xc1\t\xb8b8\x06\xe3\xc4\x8b\x86\xc4\x07$\xd1\x84\x89\x08\x8d@ \xb9C5K', b'>\x16p\x85(\xe7KH\xa6\xb8P\xd1S)\xa8\x0b\xebg\x1bXJ\x1a\x8d\xac$\x1c\xdb\xbd\x92\xb0\xb6/\x0b+\xea\x99\\\x12\x15\r\xfa\xc2e\x7f8v\x01\xeb3\xecY\xa4\xf4\x07".U\x85[5/\xabs\x18\xfd\xc5\x9a\xfa\xf9\xccs,T\xa8<\x10\xac\x90=\xd0\xa5\x8b\xc8H"0\x80\x15\xcc\x82\xc2\x8c']
# Bad pipe message: %s [b'/\x96\xc7\x84U\xc4\x1d\xa1\x88\r\xdc(\xe3\xe8"\xf7Z\x86\xeb\'\x05\xf9\xa8\xa51\xa7T%0\x1e\xaaQU\xbbW~\xfa\xb9\x97\x8f\x02\x04\xd9d?\x02P(\x8d\xd9\xbf\xb5%#\x90\xf4\x18[\xa2\x02hE>\xd4', b'\x8f\xd3|\xcaH\x11\xe8\xd1\x8c\xfb\x988\xcf%9\x15\xe9\x93\x99\xd9\x85\xaf\xc4\xbb\x00\x8a\x83%\nJ%\x16\r\xaat\x8fl\x04\'\xbd\xf9d:I\x97\x18\xdc=9\x99\\.\x86\x9a\xf1u\x7f\xa0\xdb0\xb6\xe3,\xf0\x008\x9f4\xbf\x05\xc4\x9c\xeb\xd4\x13N\xd3!\x92h{\xd3Y\x85=\x96d\xee\x01\\\xb8\xf6\xb3th\x13\x8fdz\xac\xfc\xac\xc9\x972\xa59O\x98\x05g\x17K\xa2\x11\xea\xbec\x89ec\xf9!\x00\xac\xa8T\x8bPi\xc9X\x80\xd8=}z\xb0v\x96&\xd0\xb2\x051\xc1\xa0cPN?\x80"^\xf8\xb4\x05\xe0\xa2\xee\t\xc1A\xd50\x1a\xa4\xb2\x89Le']
# Bad pipe message: %s [b')\xef2\x90\xbe\xb2,"']
# Bad pipe message: %s [b'\xa5\\\x1c\x146&\t\xd7i)\xecxg\xc8:\xd5\xa2\\XH&Q\xb2\x91\x02\x0c\x93\x95\xd8T\x8c\xbb\xb1\xbb\x01\x06(\x0c\nD\xd5\x893\xdc\xb4\xcbe<L\xb6\x9cK\x01@\xce\xf7l\x0fzh\xa1,!\x08\xb8\xbc|\xfbQ0w~\x81\x07z\x99\xe6\x93\x80\xea\xa2F\xc6\xbb\xbdpP9\xe8\xc3\x8a*\x02\xac\xe7L\x86D,\x08\x99;\xc2\xf7\xa4"\xa8\x86\x9d\x816\t\xb9G\xef\x0bS\x05[\xa1\xa23\xb5\xb5\x8a\xb2)\x98QWxH\x12\xfa\x03\x11X\x84Hrg?\xa5\xcei5\xcb&dZ\x82\x85\x11\xd8\xf8\xa9\x80u\x84\x8a\xeb@\xe0Ik\x04\xa5}gS\xc1l\xb4P\xab\x88_\x01\xdb\x80$L w\x98\xc7\xfd\xe1eW<\xbe6\xa2)\x7f\x10U\x80\xb3\xcfrwk\xd0urSP\x99\x93:9\xee', b"\x16\x9b\xa6\xff\x86\xb4/\xe2\x8b*\xaaH\x11;f?gH\xde\xf4b\xfaL\x1a\xc4\xf0\xa4&%k\xde%\x1a~\x15\x94U\x8c(\x86 <\xbf\x83\xf1\xfdO\xca\xe5\x8c\x1a\x08\xac\x0e\xce~t8}\xfa\xdcld\x95(8\x1d\x15\x93\xdbuc\xc9\xb8\xba\x07\x1e\xdd\xad\xbb\xa3\n\xd2\xe9\x1a\xd0\xf3\xe4$\xc6i\xb9\x14\x18\x00\x1d\x00 \xcf\xdc\x9f\xa6h;\x15\x16\x80\xb9\x0e\xa4\xd2 ]\xa9\xfb\xed\xa4\x9c\xaf\xadk]/'\x99*`=\x19f"]
# Bad pipe message: %s [b'\x1cL\xc8\x04\x88yh.\x1e\xd0\xa5A\\\xaf\xd1\xc5\x88= \xfcmA\x8an\xe9\xbc\xf5J\x00)\xe82\x8a\xbc\xd5\xa8k\xe4v+\xd6\xd3$\x8a\x12\xf5\xa7\x8a\x1d\xef\x0b\x00,::\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05nJJ\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0cJJ\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00']
# Bad pipe message: %s [b'\xe8\xb7\x8dS>\x99\x89~\xd2\xd2\xa99\xe8']
# Bad pipe message: %s [b'=\tP\xe1+\x9a\xa4h\xbebw\xabH\x87\xacW\xc8P \xc4\x85\x97\xcbR\xe1\xf8\xeeC\xaa \x9c\x1d\x11.\xdf=\x1f\xa5\x97\xf7\xaeR\x95m\x90\xa5z\xc3?\x1f\xa6\x00,\x8a\x8a\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05nzz\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0cJJ\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01']
# Bad pipe message: %s [b'}r\xcd (\x95;t', b"d\xcb\x89\x99KN\x1b\tGe/z\xc9\x86\x9aD\xc1\xfb\x87\x8fx\x90\xcaj'\x89\x00*jj\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\x8a\x8a\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xca\xca\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\xca\xca\x00\x01\x00\x11\xec\x04\xc0\x06\xcc\x86\x8a\xd8\xcbwSikjv\xd1\x86p\xcb\xa0\x8d\xad\xc6\x81\xcb\x12\x9e\xab\x01\x9eR\xe9\x0fw\x18\xa5&CW:\x8c;\x04\xc4\xb3\x88e"]
# Bad pipe message: %s [b'\x08\x05\x08\x05', b'\x08\x06\x06\x01', b'\x00', b'\x00\x003\x04\xef\x04\xedJJ\x00\x01\x00\x11\xec\x04\xc0\xb6']
# Bad pipe message: %s [b'\xb5\xbf\xd4S\xad\xf0s\t\xd7\xb3\xc89{\x11\xcf\xaagM92\xe9\xbc\t\xf1\xca5\x8b\xf4>\xa3\xd2\x15_\xe3&9\xac\x1f\xf1,m\xcc\x92\xb3\xf7+]\x1c{q@\xc2\xcf\xec\xe1\x97!8I\r a\xf8H|\xe5\x03b\x94\x1b(\t\xa2\xae\xeb0\xb8Z%X$\xf6\xc0u5(\x95\xba\x19\xa3']
# Bad pipe message: %s [b'W\xf9aA\xc6\x04\xa3\xebM\xe1\xacd\x11!i\x83p\x82\xd6\x1ba\xb4\xe1\x10\xb0\xf4\x8c\x96\xf5\x06Z\xd0\x80\xfbh\x95H"\x00\x80k~\x01\xe1\xb5\x00\xcdlP\xeb\xb6n\x16\xc6\n\xdaG\xa393I\xf98F \rl\x83f\\\x99\n\xee"\x00\xee\xa1\x1ef\x10Y\xba2\x18o\x00EC\x07\xc9D\xfa\x8c\xb4\nh\x05\t \xed@@B\x91\x15\xb6\xc2\x11\x81\xe9\x95\x1ciB\x896\xba\xb18R}\xfav\xcat\x00\xd1Kw\xbc\x93\xa0\xb3F7\x1c@\x18$\x13\x8c\xf5s\x93F\xab\x94\x8e\xca\x82*3cZ\xaa\x16\xd6"Y\x05\xfbv\x8au\x9b\x84\xd1m\xd4\x1b\xa7\x98H\xab\x8a0\x07\xf2\x81\xa5\xa5\x0b\x8c^\xa73\x1dA\x00.B\xb9]\x18\xc8w\xb9\x19=X\x92\xf9<.s\xaaQ']
# Bad pipe message: %s [b'Dqs\x9a"\x04', b'\xc23\xb4^oPJ']
# Bad pipe message: %s [b'\xb31']
# Bad pipe message: %s [b'KJ\x1c\xad\xddE\xc7\x84|m\xeeX*\xf67;\xed {g\x93$\xd1\x93_w\xc7#\xc3y\xa8\xb7\x0c[W`~J\xb0=\xa0&5k\x06n+\x80;\t\x11d\x0c\x91i\xb5x\xc5P\xc1\x02^kkV\x10a\xab&\x18G\xb2\xa6N<\xb9X\xd6q/\xb5\x03\x87*\xbb\x18\xb8\xc0$\xe9\x85\x18j8\xcf\xd8\x15\xda\xc4?\xbaF\x89:\'{T\x93>~h\x07\xbe\xa4iL\xf7\x99\x9cC\xcb\xbedF.\xd5[)\x9c-gvwN6\xb1"c\x1c\xc9J\x9f_\xb0%v\xd1\x1f\xbeEg\xb6x\x8f_u\nI\xe8\x98\xde|\x89\xcd\xf1\xb5\x94#t\x11 D\xe7\x1buS5r\x1aL\x99\xfck\x10"R\xc1\xb3\xe7N>J"^y,\x99\xc0\xb3\xc1\xd7\x8bCj\n\xe3\xf0X\xfb\xf2\x8b\x10\xc8\xad\xdd\xba&\x8f\xe59\xe6\xd0K\xb1\xc8\x1a', b'\x86B\xa3!\xf1\x8c<\xcc|%\xfc\n5)\xda\x17!e\xcd7\xc4;\xc2\x97\x16\x0f\x14\x8ePx\xcd\xe7\xf4\xcb\xe2G*ExC\x0c\xec+Oh\x1c%RA\x80HE\xe1\xf8:\xa9\xc8\xa2\xbe\x0c)\x13\xb2"']
# Bad pipe message: %s [b'\xa5\x08\x13\xdfj\xc5.S&\x03V\x86\x03\xc8\x07\xd1\x8c\x18x\x07\xb6\xab\xd1\xc8\x12\xc0\xc8\xd1<\xc4m\xb3\x03\x8b\x9aI\xe4xE\x11\x06\xbc\x00r/S\xd2Y\xd8\x88\xafB\x1b\x18\x03\xdcG\xd1\x94\x88\xb9\xaap\x9d\xa6\x02\x86\xab\x1c\xcf\xd3KjVsm\xf7>[e\x9e\xfc4\t\x94\xeaJ\x9c\xd0\xb1E;;\xa6\xe4\xa25\xd2\x08\x8b4RX#<?L\xaa\x1c\x17\x0cx\x07%\x84\x01\x98 *\xb5\xd3\xb6\x125rXc%\x11\x1e@9.\xc1>']
# Bad pipe message: %s [b'\xa8\x11\xea\x02g\x81|\xaf\x16%\r\xac\xa5\xealk\xe5\xb2\x97\xbc`9\xa9ky1\x88Mb\xe1+6\x11\xb2q\xda\x10!\xab>%h\x97\x92\x11;d:U\x86\xd6\x1a\x01Ta\x95\x164\xc08\xc5T\x9a$69I\xe1\x93\xa9\x8a\xb8c\xdcK\x8a\xe1\xab\xa2\x1f\x93 \x8e\xb0<\xf8QM\x85L\x8a-x(4\x83x\xe0\x08\x022Vf)\xba`\xc2\x96]\xe7\xa1\x90\x92\x12\x07\x07\xa9b8\x03\x88\x1b\xcb\x82\x02\x88\xb3$uP\xe1\xe2h\xff\xe3*\\\x92\xc4$\x16\xb3\xa3\x84\xa2f\x00.t\xf2\x94\x8c\xbb]`\x97z\x0e$0\x03v\xabDS\x97\x9d\xd0\xb0p\xe6l\xd0\xc6/\xd5\x8bR\x07\x81PpI&', b'\x17\xa4\xf7D\xbf\xe5N\xe78\x17\xae\x9a\x01\xe2\xd2Vq\xb9\x08\xc4\xd1aC\xf5\x9c<\x00\xb9\xf7\x8cN\xf2\x88\xa5dU\x98Q:\n\xdaxg\x97\xd0\xb1\x8e\x93E\xfa\xb8\x9a\xed\xa96\xeb3(\x83\x08\x1e\xba\xa7\x1c\xfdy\x14%\x86\xaa\xbcXX\x9f\x98f\x9fu\x84\x91)\x8cac\x92\x1d;\xc4\xad\xe5\xa2\xe2<`\x94\xe1R\xa2\x01\x988\xa9\x8c\x91\x86\x9a(B\x98\xc39U\x8fA\x01MR\xa3+\xeb\x18\xcb\x92FS\x97\x8b\xec\xb2st\x9cq\rq\xb0\xe4H\x06\x93\x18j4\xdc\x0f\x03\x1c1\xe4zN\xa7[\xa4P6\xa4\xa1\xda^\xae\xd8\x01.\xdb\x8eIy\xa6\xfc3z\xfa\x05\x07(\x8aI\xa3\xac&I\x02\xbd\xfb\xdb\x83\x8aX\x92u{\x89\xc5r4\xed{T\x853\x14O\xe6"\xd2\x03|\xaeB\x83\xe6\xb4b(\x88I\x84B\xb1\xdc1\xb9\xc5\xf1~\x956\x1f\r\x9c\x16D', b'X\xf9\x87\xafSk\xa5\x8a.\xaf$X\x1a\xb3#\x05\\\xb2\tH\x1b\xf5i\x179\x0ci\x12BV\x91\x00\xd0\xc0v\x94T\x8a[\x08h\x16e\x96\xadg\x8aG\xf4k\xaf\xe7\x9bc\x7f\xaa\x92\xfdu\x1e\x88\xc0\x18\xc3\x16`x\xa7\xc9\xcd\xf8\x02u\xc9/\x0eg\xcd\xe3HmG\x89\xcf\x8e\xb9Jg\xea\xa1\x98\x92<\x1c\x90\xc0\x99\xb4\xc7\xe4\xe5\xa79"\xc2\x91b)B\xf4F\xda\x01\xa7\xe6\xd9\x95\x8f\xdc\xcd\x9f\x05\xcc']
# Bad pipe message: %s [b'\x84\x91;G\xbej`\xd8\x19E\x1c\xd9\x95d\x86\xc0u\x11@\r\x14\xb6\xb3\xd1\x9d\xf9\xc2o\x1493\xcd\xa0\x0c\x03\xb7\x83\xa8\xb9\x08\x10#\x87\x99S\xbb\x7f\xac10b\xab\xf8\xa9,\xc5\xf7\x02\x9d\xe4scVWw\xa3\xac\xaf\xa0J\x87\x95t\x05\xb8`\xd4\n\xb7\x83U\x8a\xd8{%8g\xb0\xb4"', b'X2\x15\xdb\x13o\x07zL\xcc\xb0>\xc0y\xb0\x1b\x9eu\xc7\x19\xe2\xcbB\xda\xd82k\x18CT<3\x0b\x89\x0b#\xb89\x81\xb2\x0bS\\*GC\x06\xc2Y\x9a\xa6\x94\x0e\x88\xf2\xa2\x80)\xa3\x044hq\xbb$\x10\xec\xcer\\\xbc\xb6i\xb7\xc2L\xbc\xe3\xb8j\x9f6\x0f\x05\xf5\xbe\x14(Er']
# Bad pipe message: %s [b'FF\x88\x94\xeaXg\x10\xd4A\x84\xf2\x90\xfe\xb0\x1cmKmF7\xad\n\x81\xb1BY\xc5w\xeb_3&"H\x98\xa2\x95,s\xc5{\x13\xady\xab\x00cw\xb2\x01\x9c6\x03w\x80\x13wvj\x0f/\xec\xb8\xa2%bH\xc5G\x16\x80\xc4\xfe[\xcb"\x87O\xabR\x94\x03rviV\xb4\x00st=Wu#\x966\x90Q&T`/\x9e\xfc9\xd447-\x9c\x83\x9f\xcb2\xa7\xea\x92\xa4z', b'\x10\xbe\xabs\x93rW&\x95W\xc6Y&\x8aat\xc5x\xc6\x18\xa7h}\x05\x0cf\x1e\x00\xc8\xd8r$D\xd093GEd\x95\xf1\xb3\x13\x96\xdb\xc4gK\xd4\x07ZR\x15\x9d\x9ckn*\xc4-`\xba&D\x1a\xd4\xa9\xaf\x83\xb2$\tF\xee\x07\x9a\x01\x03g\xab\x99\xb8\x8b-Nw\xf5g\xf2\x9a\xb4t\xfc\xfc\xcd\xef\xcf\x8e\x06\x00\x1d\x00 \x96\x006\xa5p>E!ik\x06T\xf4\xd8\x91\xdd\xc6-|M!91\xde\xcd\xed\x9f\xc0&X*', b'-\x00\x02\x01\x01\x00+\x00\x07\x06JJ\x03\x04\x03\x03\x00\x1b\x00\x03\x02\x00\x01jj\x00']
# Bad pipe message: %s [b'[\x18\xc6\xc0\x00\xa3`\xb7H\xa6\xf9\x90R1w\x9ak\xa3\xd8S\xb6_)\xc8G\x8cW&\xd2\x12$\xb1[\xa0\xb4\xc6\xffcp\x0fu\x05\xfe\xe5\xa3\xcd;\x06\xb5$PF\\Df\x970WY\xb3\xcc\xe3\xaa?YKy\xb9\x84K\xe28c69\xf2\xf634\x93"/;+J\xba\xc3j9{n8\x00\xc1\x10\xb6\xfd:\xce8\x18\r#\xd8\xcfM\x00\'\xd7\x01~\x98\x1c\x146lQ\xf4\xb3\x9b\xfd\xca\xae\x1a\xe0P\xfd\xe5N\xcck\x94\xbd2\x9f\xceJh\xcbU\xcf\x7f\x1c\x9f_0\xae\xa4\x11\x7f\x1a\xccM\xd2\x83\xa1\x82\xf9\x7fY']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\xe7\x16\x08\xc99\x14\xb1L\xb6\xeb#\xc1Uh\x15t\xc2M\x97\xbas\xc06\x8d\x9d\xdb\xa0', b'\xa7\xb0\xc1\x1a\xd9\x12W\xf2\xb1f"S\x91w\x16\xae\x8bH\x93\xdcs\xb0{K\xa4\xdd[j\xb4\xc7R\x0b\xe9\x89\xbc\xb9\r\xd7"a\xf1\xe2u\xc3\x10_~\xc0b\xd1\xda\x9df\xd8\xce\xeb \xb7\xe4\xc6a\xdc{<Cw\x0c/@\xaf\xde\xa30u\x05\xcd\x1c \xa9X\x04\x96\x95HfWE6\x1b\xf2\xb9|\x83\x95\xf64=\x91\x0c\x11:\xd3\xab2Yv\x99\x06y\xc9\x99q\xf9G)\xed\xba\xb6\rs\xa8(7\xa4\xc9\xc4\x9fl\x06\x11\xda\xd7\xa6\xfe8/\xc2\xea\xaa\xa3s$D', b'/\x05\x7f\x9at\x076\x16zvq\xcft\xea\x80WT\xcbe7\x18\x98\x81\x93&\x19qf\x0c>w\x10X\xbd\xda\x05\xd9\xb7%SH\x12\xd7j\\\xba3\xca\x03\x9a\xb9\xc3\x92n.\x11\xc4\x91\x97\xb7r\x9biT\xd4\xba!X\xb6^\xe1/\xf4\x81\x9a\xd2\xf33\xe1r\xae\xa0\x11D\xbd\xdb\x8f<D\x98\xfdy^4V\rZ\xc2\xbe\nH]7\xd1HX\xd6G\x11\x15D\x93Q']
# Bad pipe message: %s [b'\x04\xc0e', b'pF\x82N\x81\xe8\xfe\xf7\xf2\xf6`;\xc0 y*\xfa\x8c\xd1\xe2!\x07\x030\xd1\x18\xfcq\xc5P\\d>', b'~\x0b\xb5ClaM\xd1U\x99\x90\x00*\xea\xea\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05nzz\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0czz\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01']
# Bad pipe message: %s [b'\xff\x8cY\xeeSA\xb1\x10l\x11\xccl\x96\x7f\xf9\xb5\x94\x1c e\xcc\xb6\x03z\xc1$\x84\xd8\x7fQv\x9c\x1b[\xa1\xb5\xd6\xcc\xf2\x01\x01\xa0\xceq\xb0\x9b\xaa\x94\xae\x0bT\x00,\x9a\x9a\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\xca\xca\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xda\xda\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1', b'\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed', b"\x00\x01\x00\x11\xec\x04\xc0BBm\xefll\xb2U\x8f\x8be\x01E\xf3\xbc\xc3\x8c\xa7\xc8*sS\xf7K#\xe1\x89\xecZ\x8e\xc4\xe0\xba\xee\xc2 \x17FF\xdb\xa1M\x9a\x85\x0e]\x18\x16\x9d\xd2\x96\xbb\x86\x94\x9d\xa4[\x91J\x8eP<Y$\xb6\x1f\xe87#\xd7v\xbe\x86\x99\x87\xdd\x12V\x92\x95\x8f&Vq\xe5U\x0b0Z\x8f\xfe\xf8;\x90\xe3\xb7\xde\x07\xc6\xf5\x95\xb0>\xf5\xb1d\x1b\x89\x1b\xca2\x8c\xf6\x9fu\xd1\x81\x19\xea\xc1\xc8\xe0\xbff\xe43\xce\xd4\xa1\xb9\xe4F\\\xb8D~| \x8b\xfc\x12\x02\x93K\xf6I\xc0\xc90T\xa3ucGb\xb5Z\x81%\xa6C\x00\xe6\xa1L\x8ey\x17\xbcev\x00\x881\xb2@\x83t\x82VQ\xa7=\xe4\xb0 \xa7#\xb6\xc2\x049\x9f\x0c'\x97%\x03\x10\xc77\x10\xe6jqHU\xebC\xc4"]
# Bad pipe message: %s [b"\x81\xfd\xd2\xbc\xaa\xf7\x14hG\xcb~\x84T\x917-\x9aE\x18\xe6RY\xf0l}C;\x86\xc8\x07#\xd3\xe2\x8ef{\x18\xeb`\x83\xa3\xb4\xb7L\xd4`\xcfiX\xd0\xc0`\x1f)\xcf\x0c\x12\x9c\x83\x84\xa8l\xb7\x8e\x10\x88|\xb3\n\x94\xef\x04\x00\xbe\xa4\x0ec{{\xa6\xdb\xc4\xdf\xf7A\xeb\xe0O\x0c'\x94\xfe3\xc8\x94V\xc5z2\x04\x19T\xbb\x18\xf5\xbc\\j$q\xa6.\xf6\xa9\x91\xf6\x84#@j56I~\xc4+\x8f\xe5\xca\x17\x0ft5:FK\xf2A\xaa\xdddn\xda\xd2\x98\xa6\x9bh5z\x04f(\xc5\xb9\xe7\xb6\t5+>cJ\xa8B\x91\x1c\xba\x89\xf3 \xad\xcdB\x86'\x96\xcc\xd6@\x9b\x03u6\xe6\xa3~t\xdb\x13!\x80\xa2g\x11U\xc3\\W\x8f\x12\xa3Ag\x82\xd1\xc9\x13\xda\xf5.\xd3X\x18\xaa3\x05\xf4#];\xe4\x7f?\x90\x98\xa8+\x91\xa4\tw\xb9"]
# Bad pipe message: %s [b'\x80\x10\xcf\xb1*\x0e', b'\xa8\xfaX\xbf\xce\xc9d\xa1\x06Y\xa6F\xa2}\xfa\xc2\xc4p\x0b\x8f9v\xdbr\x91s\xc5*[\x90\xad6\xe5\x9df\xb3V\xba\x04]\xe6!\xb8.K\\7\x84w\x9e\xd6\xcd\xc742X6\x12\x05"Z\xf2P:>\xb7\x1e\xc2\xc9\xa6\xf8\x9ce\x15\xdc\x0es\xba\xc2\xf6 \x7fc\xd4G\x00l+\xc4PW\x8d\xe5\x0cj\xb5\xa4\x8f[\x82#\x16\xba\xeafP\x82\x9b.\xca\xda\x82\xe6\xc4\xb9\xec\xaamRQ\xc99\x03\xb6N@\x07r"8\xcc\x16q\xd8\x08\xc5s":\xcc\x97\x16;\xd6w\x8a\xe6#Z\xd6G\xa5#\xc9\xe2\x83\x8al2\x98\xd9\xa1\xc9\xd9\x85\x81\xabs5\xb9[\x03\xe6\x1bW\x82a3|v\xca\xb3\x119\x9b\xe9\xa5#k\x9f~\xf1\x84\x0cV=\xc8']
# Bad pipe message: %s [b'\x1b\xd5\xaa\x1e\xdc\x9d\xf18\x94I\xfbt\x85\x89M\xd4\x04w\xc4\x85\xc4\x9f\x98\xab\xd6\x03M\xaf\xb7\xb2/X\xba(\x1a\x19\xf1\x9c\\\xf1Z\xa1\xc0k\x88(\xc6L\xaf\'c@\xfab\xed:,\x983*;!*\xf5q\x8e\xe2\xcc\xc6>\x81~\x0c\x9a\x08\xcb\xb1\x87c\xb5\x86\x8e\xf8\xc0\x13g\xcb\x15\x14]\xa6ph\xd9@\x98n#4\x8a\xa2\x95K\xf7\xb8\x9d<\x83Q\xb9t\x1f\xc7:\x0f"\x9b\x8d\xe9\xaeN\xf6(\xc8\xa0\xa8\xab\x12\xaf\xca\xc1J\xc4\x93f\xd7\x95r\x1d\xcb*Y\xcc7\xff\xe7of\xfc~\xfd\x92\xc1\x04\xd0R\xf0\xb0X/K\xb2\x82\x9a\x92\x07L\x04n\x87\xad\xcc\xd4\xa3)\xd1`\x94\xe9\xc5\xd6x\x11\xc4Yt', b'\xcb\xad\x06\xb4c\xd0\x18\xde\xaa^\xcatDA|\x8c\xce\xe2?\x05\x90\xcb.\xdb_\x1fep\x99\x83!t\xc9\x17v\xb7\xb0\x00\xd9\x99\x8a\x90\xa2\xd3B\x06\xdc:\xae!\\\xa0\xdc$\xbft\x18=1e\xc7\xa3J\x16\xa5\x8b?\x98', b'\xe3\xf98\x05\xa7V\\9+\xd5\xd9ok\x1b"\xc1\x88\x08\x0c\x88\x98k\x00a-j', b'\x18\r\x86+\x86H\xea\x19\xd52\xc5\xa7`,\x08(\xa1\xf2\x07BS\xc2\xab\x83\x11\x973\x01y\xc00U\xf1\x855\x94\x8b#p\xc0\x90d\xfc\x89\x04*4\xb1\xb0!\xddc\xa6\x15&\xcc\xed\xe8\xb4\xbak.I8\xce\xf6\xb3\x92\xc5\x1ai\xcf\x00J\xd9B\x15\xfcd\x10\x8b\xaa@t\xb6q\xe6;r\x12\xd4\x87\x1b\xb1\\\xb7J\n\xdf\x9c\x11\xddJ\xb1\x91\x88o~\xd9V\xe0T\x938\x80\x17wW\x02\xc3\\s~\x0b0\xc8\xa4\x11\xce::\xea\xb8:P\xb5\xa3t\x85\xb5']
# Bad pipe message: %s [b'?\xce\xc4\x7f\xaf\xafD\xeb0N\xd1\xcbX\xa9#?"\xb2 \xbbC\xcb\x11\x96=w+\xca\xba,\xdbN\xc2\x91\x84\x8e%\xf9\xef(\xb1\x9f\xb8X\xcbh\x04\xc8\x93Y\x90\x00*\xfa\xfa\x13\x02\x13\x03\x13\x01\xc0', b'+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\xaa\xaa\x00\x00\x00\x17\x00\x00']
# Bad pipe message: %s [b'\x8273a\x16To6; \xd89i\x99M\x19\x1e\x87 p\xce\xac\xda\x84\xcc;\xe9\x12\x80\xbd\xe7\xbeH\x14$\xddf\xbc\xa3\x86eI\x80sJ>Z\x91\x9e\xb5(\x00*::\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05nZZ\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e']
# Bad pipe message: %s [b"\x05\x1a\x0e\xb4\x92jz<\x8aq\x80/\x8e\xee\x1a\x81\xfaw \x0c\xf0\xc3\xb5\xce_'=\xd7\xd9\xce8\xc8\x85\x90\xfa"]
# Bad pipe message: %s [b'g\x8b|\xd6\xec\xcb\xf4X9\xb2X\x14O\xba\x00,**\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\xea\xea\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xea\xea\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\xea\xea\x00\x01\x00\x11\xec\x04\xc0.\xcb\x05q\x998\x80\x02Y0\xa5%\x88\xe8g\xe7\x0cF\x83,\r\xe7\xbcI\xa3\xb0b\xa3R\x06\xc7\x93\x16o\x90o\x88\xb5"~']
# Bad pipe message: %s [b'~\xa7/m\x93\xc1\x83\xa2\x08\xd3,[\x9e)]\xa8\xf1\x80\xf0\xb3\x1c\xa9\xd5$\xd7\xda[\x1f\xa6\x1e\x0eI;\x9f\xe1\xbf~"\xca\x9a\x95\xbc\xb9RN\x91gG\xa54\x1e\x7f$HI\xe2\x0e\xa8\xb0\xb6%K\xc9]z\x13\xff\xfb\x19\xa6\xd6\x07\xcb\x16\x03Xk\xcd5\xdb\xa9\xde\xa3\x8d\x89\xab2J!7\x13c\xaf&\xb2iP\xf4\x8fP,\xb8\xed\x91\xb6\xbf16\x00R\xc9\xed\x99mN\x00\x8d\x0f\xeb\xa2\xef%\xa0\xe4\xe2\xb7\xcd\x15\xc9\x88\x80"w\'g\xb3\xf34\xc1Sa\xd5\xf9\x87N\xf3\x0e']
# Bad pipe message: %s [b'{M"h^\xb4B\xa9\x9b\xa8ui\x84Q\xe0<\xf1$\x85\xbe\x08\x1f\x8b\xfc\x99\xc2\xa7E\xdc\xd4\xb3\xa2\xdb\xb7K\xf0\nna\xa6\xf4\x19\x1dx\xb0\x16\x13\x17\x8d\xfeC\x88\xd9\xb9/8\xb0;t\xa6', b'\xea`1h\x8d|Z=\x7fv\x7f\xf0\xf1N\x02\xe8\x08z\x81\r\xc8\xc5\xb9r\xd3BY\xa2\x90\xb7\\\xb7\xe7b\x01\xaf\xab@\x92\x14\x96\xa8%\x87\xf758\xa52w\x99G~\xe5j\xceRwTV\xb1\xb1O\xe2\xb0\xcc\x99F\x7f\x96\x1e}\xa3', b'\xf7\xb3HG\xab\x92\x86\xa4\xdd\xf2\x97I\xe72\xa4x1\x8dJ\xa99\xf1\x10\x04\xa1/\x00m/\x9a\xa0\x03M\xfa\x0e\xeer\x96\xc4\xc8et\x93)\xa2\x10+i\x8bE\xf00\x9a:', b'\xecU\xc2\x8f\x1a\xa5\xbd\xe3\x94S\x9b\xb4\x058\xc6\x85c\xb52\xa9\x97\xdb\x88\x9ew\x83\x17\xc1\xc9\x0e\xa5U\xbb\xb3\x08\'\xb8d\x1eI\x19>f\xb2x\x027\x85\xce\x88\xce\xe9\x17\xaf&\xe8\xa9\xc6\x10;J\x81\x84E\x824\x8cZ]\xf3\x86TD\xab\x1f7\x9a\x98\xfd\xb8\xb7\x01\xd12\x1f\xfa\xb2\xb2\xc4WR\xb4mc\xfa\xb3\xcb\xdb\x01\xc5\xec\xc9r\x98E"\xf8"0y\xc4\x9c\xa2\x0f\x99cH\xd7\xd8c\xfde\xa7\xfd\x0b\x95\xd7\xac[\xb2Um\x9eZ\x03\x9crj\x8ei\x0c\xbf\xf9A\xdd\xb0\'4\x8ai\xd5\xc0\x89rl6\x91\xc5kR\xa9\xb7\x1a\xd9\xad\xa5+\xc9\xa6\xb9\x16\x8cp\x88r(r\x94\xb9\x8b\xc2\xa0\xa60\x1c\xbf\xc8\xb6\xbf\xb0\x06&\x1f&\xb8"\xf7b$kw\x08Cl{\x1a\x93V k\x96\xd7^\x00(\x11\x1b\xcb/<\xe8\xba\x99y\xa3', b'@Q\xb5\x114A\n\x97\x94eO\x90+\xcf\xb6\xb2\x86\x88\x91\xed\x0c\x0e\xb4\x94F\xe5\x94\x15\x81\xa9\x9d\x94\x06|\x15g\xbb~\xa5I\xca\xd5\xbd\x05\x10I\x0f\xd5\x94\x8922\x91W\xa8\xed\xd1\t\xaf\x83\x14\x04\x8c\xc7\xcc\x95\xbe\x0f\x08\xb4w\xcc`\x92\x13qk\xccE$Tx)8\x8dJU\xc3\xc5\x02Y\xca\x04\x93\xad\x9cW\x9c\xd57zZ\x91.\x90\xa4<Z\x17=5@\xacz\nj\x8c:4\xc6\xb6\x86\x89\x1a\xa9\xa1n\x9a\x0b\xb3\x13\xca\x7f\xe3\x13\x040\xc6\xa7\xcaF', b'\xc8\xbd\xd1J\xb8++o\x02\xe72\\\xc0x\xbe&\xa7twA\xc0J)\xba +\x08', b'\xeb\x82\x05\xa2\x16\x06(kT\x1d\xa3sEaO7z\xc2\xf2\xe4\xa9\xec\xac\xb1\xb5\x1a\xab\x84\xe5\x84<\x10+\x19\xb6~\x1c\xf2L\xcd\xfa\x17{\x08\n\xd2\xc24a\xd3\xc2\xe4\xfa$\xdcp\x12\x814ux\xf8E?1;,L\xc7\xd5\xd7[k\xb4\x06\x9a\xb0\xb3\x90i\x03+\xe0\xa7\xf168', b'!:\x93+\xef\xda\x0b\x88\xbbD\xc1\xf5\xb3\xde\xd7\x94\xe8\nz\xa9\xe5l\x93T\xc8s\xb0\xaaM\xf5d\x044 P\x08\xc0c\xbc\x8a\xb5Z\x02\x8f\xb68\xeeE\n4\xe5\xb9oJN\x97hL\xa7;\x1ee\xb8\x142[/\xa6\xe0\xc1MfC\x7f\xca\x1d\x0f\\V=:\xc7[wE\x15\xf0\x9f\xc8\x9b\xcb\xc3\xf0]\xbc\xab\xce~3\xbe\xf3\xc0UTkG\xd6&\x9e\xe5\x878\x9c\xb6\x0e\xe8v\x7f\xe6\xf0FN\xb99\xc7A_\xc9%\x165\x95\n\xc5+\x0cB\xc6>\xb1\xf5\x8d_\xb3\x1b-\xb3!?\xa7\x9c\xebV`BH\x13\x98\x90\x03\xac\xb7\xcc\xc5\xdc$\x0c\x86P\xab\xe3\xa9\x88\xca\x88\xf5,\x13\x98\xf5D\x9a\x01\x83\x8e\xe64\xd167\xc5S\x16\xde\n\x7f\xcf\xa3\x80\xfc`\xbbLp\x02\x15,B\xdcc\x8f;\x03/\x1a\x91w\x89\xcc\x82\xfb\xf7\x9a\x9a\xf5\x16\xae2\x90\xc5\xa8 \x8a\x11\x9e\xb5']
# Bad pipe message: %s [b']\x10\x8f097\x05\xdf\xd0\xb3\x8ch\x0f\x83\xd4\xe9\xf0h \xff\xbe&\xb8f\x85)<R\xf2\xcbB\xa2\xf3bD\xc8\xb7\x07Q\xc5K8\xbf\x0b`{\x8b\xde\x00d\xa5\x00*\xca\xca\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05njj\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c**\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed**\x00\x01\x00\x11\xec\x04\xc0\x19\xe96b\xc4?R\xdaI\x00+\xce\x05!\xc9F1$3%Qg\xf1)\x0f', b'%\xd6\x1d\xd1\xa9I\xadA\x0fI\xa0X\xbf\xf0f\xa7\x9c\x1e\x9d\x03"-\xf8<;\nB,\xf7\x17\x13\x84I\xbb7A\xb4\x9b7\xc9e\r\xe5|\x17\x8f\x06;$#t{\xa5h\x0b\x98\x14\xd9\xb15\xbfU\x00\x01\x05\x02fW\xc8\xb5\xf4tOp[\n\xa2o\x8e\x8a\xc3\x95\xe5W\x89\xa8\xba\xa0kZ\xb4\\\xa9\xb3\xf4\x99t\x07\xa1\x07\n\xc7E\xcbo\xd8\xfb\'4\xc9\x9cAS D\x86\xca\xef\xf3q\xa1!GV3~\x9bw\xaa\x14\xe96\x96\x07,\x9du\xa4\xe5k!H\x8c\x10\x17\xe5/h\x91\xa6D\x92\xbf\xea\x91\x9f\xb4\x03\x0b\xe5\x10\xb7\xdcA\xb8\xc5\x97L\x8a\x1bq\x92S\xcexT\xbb_\xba\xa6\xd3\xb4Va\xb1~\xe4\x81\xc2\xde<T\xc9w\x80Lcy-Kv']
# Bad pipe message: %s [b'oU\nk\xcf\x16A7CD\x15UD']
# Bad pipe message: %s [b'Z\xe7\xb5XS\x13\x04\xa5a\xb5\xcf\xa5\x9a\xa3"e\xc4Wr\xad\x15\x90\'\xd0\x13f\xab\xa4\xdb\xeb+P\x00V\xc1\xf4xY\xa2\xb7;T\xa6\xe05I\xa5\x8c\xbb\xc56\xbd\xee\x8cGP\x96U\xd0\tn\x8f{U!\xe1,R\x83f\xf1\xdc\xba\x13\xd4\x11~Q\xb7\xbd']
# Bad pipe message: %s [b"\xd9'z\x9c\xc0\x90Gl\xbf\xf0\xe9Z\x10\x1c\xab(S\x0eB\xdaH\x99j\xbf\x12(J\xfd\xe9\xc4\x88\xc8++D\x12\x15\xf3;V\x0c\x108F\x1a/\xe3\xca\x88\xaa\x8bi\x8c\x89\xa1\x82[M\x96\x81B\xe7\xb6\xca\xd3\x1b\xeb\xf1\xad`\xc8\x93\xce\x1a\x06M\x174\xb1\xc1\xb6\xc7a3\x94\x1a2\xccl:\x90{\x16\x05\x10`\xe8\xb0\xbf\xf8K\x8ff\x81\x9dG\xf1\xb3IW\xbbP\x92\x96O\xa2\xb2\xa4\x1ck\r\xa8\xad\t''\xe2\x90\xa7t{\x93k\xaa\x1c\x85\xc8o \x16T\xef\xfa-\x00B.\x8d\xac\x95\xa2\xe6|=\x1c\x04\xa4\x83s\xc8\xf4\x0f\xb5\x94\xc8K\xa9:\x1b\x15\x8e\x0c\x80\xcb\x9f\xe8z\x19\xc42jU=R\xa0\xb9\xe6\x82\x7f&:", b"q\xba\x11\x91?\x88\xe7n\xd1\x97\xb3\x92\x07\xd0\xab\xc3\xb6\x08w~}\xc4\x00{\t\x8a\xe5\xf6\x01\x04\xf9\xb5\x89\xa9YTpD\x12\x8bSH\x95z\xf7\xc5|\xae\xd6\xbcq\x9b\xce\x8b\xd3\x14\xe3\xe4\\\xae\xa2\x06\xe98\x1f\xb18\x84\x9b%\xcdd\xb2u(*5skB\xdaX\xa0\xa4\xb0\x0b\xf2\xd5\x82\xdf\xdb_\xa2%\x18\rw\xb4\x8al\x90\x0b\xa4\n2\xb3\xb6\x85\xc4;(\n%'\xf0J\x02\x16\x90eV\xbb\xf4eb\xbd\xfb\xc8\xf3\xc4\x0e \x98\xb1\xdc"]
# Bad pipe message: %s [b'\x01Km\'\x8aJ\xa8z\xaf,El\')2\x1fFO\x00\x81\x03r\xe4Ux\x95.D\xb2\x8e\xaa\xb3\xad\xa3\xa9\x9c\xf9c\x8a\x1bY\x1fT\xf0x\xe1P\xa7\x8e\x81~\xbb1\x8f\xa4\xb0\x8f2\xa7t\x1f\xc9\x95YT\'\xa1gF\xeap"\x8a\xd8K\xba$3E3\xac\xc4\x8b\xa9$\xfb\x0eN;\xb2\xd7wB\xd1Z\xbb\xb2\xc01K[J\xa0\xe226#']
# Bad pipe message: %s [b'b\x1e\xcd\xbc+\x90x\x0f\x18\xa7\xa1\xd2i\t\xf5\xfc\x91\x92\xbc\xa4\xa3\xa1\xc3m\x07Z|\xc75~\x16_\xa2\xe4\xa3\xd8\x89\x91\xb9\xe8\x89\xfaa\xcd\x8dGh\x88v\x07\xfav\x0b\xaf\x81\xa0?\xdc\xc1\xa3\xe3i?j{\xee\xc0lN\xfaN|P\x1c\x93\xac\x90t\xcc\xb3\xce']
# Bad pipe message: %s [b"k\xe3Q\x06'\xbc;k\x1b\x0c\xb5\xbd\xe6u\x89}(\x10\xd1\xb3\x16y\x15A\xfd\xeb\xb3\xb1\x95t\xa1\xd1\xbc\xfb\x07\xbd5\x9cM\xa8\x00\x83\xaa\x866\x8c8\x07m[\x88)\xc5\x0e(*\xb2K|u\x89Ze\xe9U\x7f}\xc5\x17\x1aC8\xbc\xf0\x9f\x0e\xf73\x01K8i`\x94@U6l,\r\x85\xda\xa4\x0et\x7f\xe9GU\x8b`\ri!b\xf4P\x0e\xd8\x11}\\#\x95J\xa9\xbfMXw=\x94N\xb9\x90\xa8*\xb0]\x93\xfc^\xde\xc7\x92\xbe\x1b\xbb\xb0\x99g\x85\x82\xca\x81V \x94B\x08\xf1r\x15\xd5bz\xafw\x91\xf9\xf9$\xef\x00P\xa7\xe9\x90p\xfb\xc2\xc5\xb6;\xbf\x85gw\xd8\xad"]
# Bad pipe message: %s [b'9D\xfa\xbe/\xc0\xa2T;\x9e9\xc2#0[\\\xd8\x8a\xa0Y$,B\xf4>\x9f\xf2\x03\xdc"V\x80r\xb9\xe9k}{\xe9\x01lR%\xf4W\x8d\x1fl\x94\x1c\'\t.\x91E\x13\xe7\xcd\x106q\x80\x15\x10\xf6aQ\xf4\xb8\x1b\xca\xd4\r']
# Bad pipe message: %s [b"\x1dX{\xb4\xcd\x14|'7&\xd9%8x\xe2I\x9c\xd1wc\xdceg\xc7\x91\x0bS\x01\xf67])Z\\\x1fR\x07\xa0Z\x87\xf8a)\xea\x98\x9f\xcd\xb4\x7f\x8ex\x05\xc2\xd7\xce\xeb\r\xf7\x07\xd3\xb4\xac\x83\x90\xa8J\x03\xdfX\x9f\xe8\xb1\xd1\x90\xc0s\x08 \xd0\x90\xe4z1\x07\xd4\x16\x9ft\xee\x83\xdf\xee\xc04\xe4\ne\xc0\x89\xeb\xc5\xc5\xc7\xfa9R\x81=\x9aB\x00\x1d\x00 \xe0\xcbS\x13=\xbf\x04\x05\x07n\x96\x15\xce05K$Y\xbc\x13\xe9A\xa8\xbbxu\tS\xeb\xd1\xec\n\x00-\x00\x02\x01\x01\x00+\x00\x07\x06**\x03\x04\x03\x03\x00\x1b\x00\x03\x02\x00", b'']
# Bad pipe message: %s [b'\xb3@\xbc45E\xa9\xf2\xcbv\xbf\xf0\x96\xac7\xbd\xe9: \xc6\xb3v\xd1\xe8\x8eflu\x1f\xb2\x11\xc0\x17\xb2\x84\xac\x8e\x13\xa3q\x13/C\xd378u\xe2\xc6\xc0\x14\x00,\xfa\xfa\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n**\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\x9a\x9a\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\x9a\x9a\x00\x01\x00\x11\xec\x04\xc0;\xb9\xb2G\x88=\xbf\xe8\n=\xb0\x9bF\x96\xa57\x95}\x9d\x07\xb2\x94\\']
# Bad pipe message: %s [b'\n\'\x9c\x18f\xe7\xf1r!\x8aQ\xf8\xb5<\x08\xf7\xa9\xce\xd2\x01\xce0]\xe2I{\xe9\xe1om\xb1\xae\xd3u\x19\xa2t\x97\x14\xe8"\xbfhe\x85\xf8\xa6\xae\xe8s\xd8\xa1eW\xe4\xad', b'z71\x9eyF\x91\x1e\x843\x15\x83I\x81k\x1aM\x11 \x82R\x0f\x84\x99\xb62f\x13$\xfcMQ\xc0`\xb1\x82<,"T\x91,_\xe5y{a\x86\x1b[a\xc5\x1d\\y\xb3\xfc\x82%\xe6y\xbdS\'\x9f\x81\x86E\x88O\\,{\x9c\xfb\xcf\xc4t\x93\xfdHc\x8f@\x06S\xea\x03?&\x02\xf9K7h\xe35s6w\xcf)yB\xc1\x8dq\xcan\x1d\x84\x0cob`\xaf\x89_\xc3\xec)\xad\x07%\xb5\xa7o\x01J\x10\x80']
# Bad pipe message: %s [b'\xdap\x15v4M\x142\x87~\x195U\xe9y\xa4u|\xbf\xf5\xbed,O\xfb\x03\x15"\xab\xac\x8cU\x98\x8erH\x87']
# Bad pipe message: %s [b'\xd3\x1ci\x14\x1bC\x1cka\xcel\xc9\xf0\\\x9f\xa7\x08M\xac\xe59\xee\x90\xa3oGaq\xb1u\x0fr$g\x92\x87w\xf7\xba\xa5\x81\x8e\\"$\xa7\x96\x16\x8f\x17?\xde\xc0\x81\x98\x95S\x8e\xc9X\x16\x85oQ:\x82z<\xbd\xa1\x83\xb5F\xc7\x143\xa4T\xdb\x01&\xb0k5x\xc9\x19\xbe\xc7\x8fk\x04\x07xt|=\x85\x01\x82@|\xa3e\x90\xe1\xb5\x07\x89\x81\xcc\xd0\x82\t\x15\x85z\xfc\xf1ft\x95g\xe0\x12yUR!\x8c\\\x06\xbd\x03\x8f\x92\xe7\xc5\x0b\xa1\x94!\xd6\x95\x02\xdc\x16~\xd1?\xce\xf5C(J\x9f\x1ekLR\xb4\x98\xc9\xe05\x87\xd4\x0f\xfaw\xb7?2@\x84\x0cS?b']
# Bad pipe message: %s [b"\xa0\x8f:)\xbf\x1b'*#F\x9b\x8c\x82\x08\xfd\xf6\x07\xea\n=\x81\x936\xb8\xe6\x14"]
# Bad pipe message: %s [b'\xcf^\x11C\xfdv9\x8d<\x7f\xaaT\xbe\xa6\x80\xca\xb2\x0bq\xad\xf9\x89gd>\xf2(W)\xf0\x10P\x9a\x85\xf1iq{$h\xe5\xdb\xb4w4,(3U~\xb6\xce?#L\x97\xa2\xc4\xca\xa5\x1e4)\xb2K\xe0i^\xaa/g\x01e\xf9l\t\xb0\xf8b\xd4\xc8\x06\xb8ld\xf0\xf2\x1e\xad\xf0\nl!\x18H\xb5-\xb8\x98\x9dD\xfas\x87\x85\x9a\xc0F_\xa8\xb1\xcf6\xebh\x802B\x83\x9bv\xa6\xc0\xb7\xaa\xe6\x83lP_\x05dLS\xc6.\xe5$JY\xa4:\xbf`G\xa0k\x0f\x00\xe17\xa1\x14\x8b"\x03\xa7\xed$\xa1\x06Ag\xdf@\xb9\xe8B\x88%\x12*\xfd =\x03s\x03+\x15(\x07\xc8\x0f#']
# Bad pipe message: %s [b"q\xa7B\x95\xa2\xb0qa\x92R:@~\xd0#\xe7c\x17\x12S'\x15y\x99\xc8\xc8(b\\r\xcaH\xc5\xcf5\x89\xbe\xc1\xb4c\x1ctwW\x92\xe7\x14Q\xa4\xa7\xa5\xd7\xb6\xc5\x11\x88)\xde\xe1\xb2\x81\xb7\xbe\xc7\xb4PwVU\x03:D\xceF\xc3v\x17SF\x1c .\x04d\xbc\xa3Bw\xac"]
# Bad pipe message: %s [b"yG\xbfe{\xa32}\xd0K\x9fZ\x9a'\tw\xaauk\xbb\xae\x9a\x12\x1a,6\t\xe8^\xa6\xe6BB|{\xadw\x89\x90\x03n\xc89\xb5q\xabeQ\x9a\xa5\xcc\xf7[\xe7!s\xb2s\x03c*]\x89k\x81z\x01\x9b\xdbH~\x999\xc4c1\xcc\xf6\xd0t\x9e\xd9T\x88\x82Q\x16\xd6\x80\x8a\xd1i'\x17\x9e\xc0`\xc1\xe2\xe5\x99\x84\xd2\xb7U\xc9\x16\xf2\xc9W\xff\xc6", b'\xa9f/\x90\x1c\x9a\x0b\x82\xb1\xfb\x16\x1b\xb9\x80\x9f\x98F\xa2h5\xce\x953\x95\x1c\x19\xa4\x8c\x05\x7f\x80[k\xf7W\xce\xc1\x85\xee5k\x12s\xb4\x07qS\x9c\x90KSQ\x82X\x8c\xba\x0c\x07\t\x1cwI\x85\xc8\x18\xb2j\xaaz|I#t\xac\x0c\x1a\xa8\x0b\xbc\xaa=\xa5\xbf[k']
# Bad pipe message: %s [b"\xb6;\x07\xcb\xb3\xe4\x07Y\xdee\x82!cS:v\x1b\x9d\x85XPl\x8a\xf8\x92\x1b'\xb8[\x9cY\x17;!\xb2L\xd63\xa8K\xa7\xed*@rc\xc0@g\xc8\x93\xf8\x124\xa4\xcb\xd0\x96\x11yp\xa0\x9ei\x10\x06\x9b\x1d&)N+\x9a\x9d~\xe3,\xd4S@XENR7\r\x02\xb1D\xbf\x12A\xb0w\x88\x0439R\xa9\xbd\xcdyS\xc1+\xa7\x8e8\x85x,R\xf79={\n\x9b\xd9\x1a\x9c\xdd!V\xa5\x18\x04\xcd((H\x97\xce", b'D\xda,1%\xf62-\x0cL\xad\x07\xb9\xc1u\xae\x81\xba\x05u!\x01\xbc;L\xb5\xfa\x94\\\xb6Y\xd6IB\xb1\x01q\xbd\'T\x1b\xd6,\xbc\x05\x9cEv\xb0\xc7\xb2{\x03\x11\x80\xe2\xd2P\xd7b\x80\x1a\x05\xcb\xdb|\x19Ig*p\x06Y\x94\xdb\xb3\xeb\xbe\x89|q\x03\x01\x92\xc4>\xe6\xbf)\xe9d\xbf9\x89\xa7^\xd3\\nI\xbf\x1c\xaeZ\xe5\xb4\xb1\xe6\xd5G\xe7\xec\x8cB\x14\xc8\xdf\x8c ,\xce\xe2~.\xd3,\x88H\x96\xc9\xf6vI\x91,qe\x00\x1d\x00 )\x129\xf9\xdfw\xe0\x06\xca\r"\x82\xf0\n;\x8f\x111\x87\xe5\xd7z2i\xe8\x92z\xeb\xd9\xc2l\x17\x00-\x00\x02\x01\x01\x00+\x00\x07\x06']
# Bad pipe message: %s [b'G\x1bwM\xd8\x88/\x87\xa2\xdau\xc5\xdf\xe6\xf5{x\xa2 \xc9\xcce\x7f\x8e\xbajv7\x14\x19\xcd\x9c#\x01\xb3\x92F/\xa4\x90\t\n#\x06\xa7e\xcf\x1d\xa2\xfe\x1d\x00*\x8a\x8a\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08']
# Bad pipe message: %s [b'\x00\n\x01\x00\x05n**\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\x8a\x8a\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\x8a\x8a\x00\x01\x00\x11\xec\x04\xc0\xa9\xe4\x9el\xc4\x1f\xb9\xcc\xbf\x9c\xf63u\x0b\xcbY\xd8\x11\xb6S &\x0bL\xa7\xf2r\xb7\xda\x0b\xce)DV1r\xcd` -\x8c\xc5h\xf6\x0c\x95\x86\xb5W\x96\x13\x00\x18\x1d\xe0R3yk\xaa\x9c\xc2\xae_\x9baKR\xc0L\x11c\x99A\x04\xd1']
# Bad pipe message: %s [b'\xf5\x91\x13N:\x8f\x02\xb37\x82B=@\x98C`\xbb\x04/\xdb\xa1{\xb3\xb11\x00s\xbd1X6)/zIL\xdb\xb7p\x9fF\x82y\x86\tN\x8a\x05x\x14O\'\xd04k\x1c\x90\x9e\x16\xbe\x89\xe4\xa6\x88\x15w\x1eI\x87\x83\xf2l\xc1\n\xa3\x9cE\x19\xed\xa4jt6J7\xe0\x8d\xca7A\x1aw#\x0fX\xa0\xab\xe1a\xaar}\xb8\xe5\xc0Wcg\xb5Z\\\xaa\xfa\x16\x80\xfa\x1c,\xc75\x96#\xbe\xe90+P\xc54Q\x81\x14\xd0 OUH\xcb\x9f\xf8\t\x88\xd4\x1b8w<\x07Y\x13k\xf4(\xd9l0fD\x8b\x85\xc5xD\xb1\xbd\xb0C\xc1\xf4,S[7\x05%"\xafv\xd3\xcd\'(\xca\x15\x18']
# Bad pipe message: %s [b'QeO\xa8K]\xec\x8b\x83\x17v\xbb\x90&\xbe\xc1Z\xef\xf1\x87\x88{\x88\xf4@I\x94[\x87\x1a\xf3Iy\xea\x17|\xcb \xdfj*]\xfb\x83\xa9#Z\xfa', b'}\x87)\x80\x910.WE\xb4\x05H\xf5\x8a\xab\x87f\x96\x9d\x8c\x8f\x84\xb6C\xfc\xe06\xdbP\xbf\xc4@D1\x92@\x8e\x01\x97\xa2\xb9\xb6\x04v\xbceI\x1f\xacuaK\xa0\xc3\xb7\x8b>\xa6\x17\xc0I\xfb\x19U04\xc4\x1aQ\xfe\xf4f\xe7qe\x1e2J\x15\x08\t\xcfA\xa8\xc5U\xcbI\x92q\xd4\xba|\x19l[\x05i\xc7\xb4D\t\x92\xaaF"\x92=iS\xa0\xb8\xd6[C\x95\x9b\xb4\xb7\xc3\x0e\xf2$\xc4X\xb1\x01\xea\'\xe7gy\xe2d', b'\xa7:E\x95\xbbx[\x12\x03\xc6;)\xe4\xbfi\x95r\xdb\xe8Y\x14dO\xe0qnG\x10>\xefG.\xb8\xa9\x0f\x8a\x8c\xcb\xbb\x9a\x88\xcf\'He\xc31\xfd\x06\x9c\xc7\xe0\xb5\x94\xd6\xb4m\xd8\xb3 \xf5p\r\xb1\x8d\xf1R\x03\x0e\xebW\x03\xa3\x9f\x13\x01\xaaA\xa9\xb7F\xd0z\xf2LE3d\x84y\xf2\xc1az\x02\xe5Z\x1ah\x96\x89\r\xab#@\xd4\xcc\x91\xb0\xb3\xcaX\x07\xf1\xf3\x05\xcf\xab}\xea\x90\x03\xc6\xd8V\xd7,6\xa8\xca\x17\xfbz\xc3\xf8 \x1b\xd7\x11~\xbe\xacO\xed\xa6\n\xa4\t\xb3\x8a\x0b\xc6\xb3\xf0"\x1c\xcbeh', b'\xb0\x84\x04Vb?)K1e\xe4\x120\xeav&s/-uZ\x8e \x94\xa9\x1b\x08i\xd9\xc91PE[;\xc3\xc2\xaa\x19Tq\x15\x8a\x89\x92\xb9\x80&\x96!\x85\xb8\xfc\xc6\x1f<P\xaa\x94P\xc0\xc9\xb7X\x90\xc6\xd2\xe2\xac\x14\xe4,r\x1bL\xdb\xf5C\xe5\xd3Y\x9cV\x1e\x96\xa9\xa3W\xf4\x07\x0c9\xb6\xe7\x03 +\xf4]t\xe6\xb41\xe4-\x01" \x8a\xab\x976\xb123\x9b[d\xb7\x12\xac \xb4\x1c{CA\xa3@\x13\xb5\xb4\xacZ0\xadgt\xc4\xec\x9e\r\x94WA\x06', b'h\x99,\xb5\xb2\xe8\xa7I\x87d^:|cv49n\x88\x9d1w+\x13\x1b`\xec\x88&\xc3\x82\x02\x19\xb9\xa9^V\x89\x93\xf5\xc5pJ&\xd7tQ\xfak\x16\xf3\xb4\xbd}\xb1\xa7|\xc4e\x8b\xc5>\x03\xc5\x16\xbd8\x84M`\xbb\xeaU\x9dlWi\x075ku\xba\t8\x000w2\xa21g"\x029\x98#\xbc\xa77L?S\xc2>\x0bq]VbL\x06\xe7T\xb5w\x95F\xda\x86(\x11\xb6i\xe4\x9a\xdaAD@+\x1d\xa3\xf8\x83/\x8cb]\x14X\xedi\xa1\xd4l']
# Bad pipe message: %s [b'\x9e\xa7\xdf\xa8{j\x7f%\xc3\xee\xdeEd\xaf`\xbcej \x13\xd4\xd7}\x05+8X\xac+99Zz\xc7\xef\xde\x8eUuZ"0\xceq\xa4\xcd\x88\x0eBP\xf4\x00,**\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05nZZ\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0cZZ\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xedZZ\x00\x01\x00\x11\xec\x04\xc0r\xb4L\xb7\x08\xcc\x8e\xca\x18\xd6Q\x006d\xac\xc4S\x180\xb8i3\x05=C"\xc2\xa4x\x98\xbcSi\xd1\xabqcS8\xb1\xe7@\x16', b'\xc6\xa7>\x1f\x04t\x1e\xe6\x16\x97;\x0b"+\x18\xc4c\xbe\x08Q\xbfbh\xa4a\xc96\xf1\x8b\x02W\xa8\xc7?\x80\xb1']
# Bad pipe message: %s [b'S\x00\xda\xabWJ\xa4\xe6f\x15\x18\n\x19\x9e\xcc']
# Bad pipe message: %s [b'Z\xba\x8a\xe7i|3\xcb\x19\xc8\x9c_8\xc9\xd8))\xe6\xaa\x17j\x95G\x84"n,0}5%\xa14{L< _\x93\xb1\xbf\xd0\x0c?i\xf6\x92\xc2\x96\x89x\xbcG,+\xc5\x89\x8c\x07G\x85\xba\xce\xb8\x86t\xc9<\n\xe1pH\xc7\xb1Z\xa0\'\xbc\xd7[\x1ap,\xd6\x8br\xd8\xe67\xb0\xa1\xc0K\x8a\x9c/\xbbg~*V\xa0Ja}3&W\xb4o\xf5x\xcf\x99\xe3yY\xc3|\xec;O_<1\xe5B/`A>\xfb\xc1\xc7\xfe"\x06rF\xb5\xd7\xb9.\x19\xa99\x88aVa\x0b\xce\x8e\xd0\xa1Q|\x98\x1fZB\x93|yNg\xac\xc4\xe4r\xad\x90\x82\x89', b'\x00=[\xb6\x97\x10\xb5V\xcdd\xe7\x17\x8b\xe3\x109k/\x1e\x02\xb6hQwh\xbb{\x98\xec[IQ\xab\xed\xd7\xb7\xd9\xb4\x8fi\xa5\xa2]\x07\x1d\xe4S\x7f\xc8k(RA:\'\x80\'\xdd,\xb1:\x0cSE\xf1\x92\xbdL\x9e\xd3\x17^\x06\xcc\x13\x16\xc7\r"\xecX\xd76+>p;\x91Q\x1b\x9e\x9bg\x19\x11Xn\xaal\x80\xa7S\xc7q&O\xa9\xb6\\y_Hd\x94z\x10\xbdt@{g4\r\xe4\xfcH\x8fX%\xe8\xabI\x945\x0f\xd0r\x11W\xd3\x003 \xb4\x10\x91\xa8\xa3\xc9\x1d\x1f;\x9bhy\x1d\xbf\xaa\x7f!\xd3\x82b\x1bY]\xd4\x88\xd8k\x9dm\xe5yMl\xc9"!\xb1', b"B\xf2d'\xffJ?\xad\x87\x9b\xe2Jy \x83\xb1\xa9\x96_\xddf&\xbcea D\xb4>K\xc1\x08\xea\xa0\xd9 ;\\\x8a\xc2\x85\xc3\xbe\xb3\x98L\x96\x84\xb2\x88\xdb\x1e\x811\x15\x13\xf3\xb7\xa2#\x9a/\x13V\xde\xb8\xae\x01\xb9\xa4\xb8E\\\x0f\xd6-7\xfa\x1f2\xd3&\x8c\xc7%\xf81\x93y\xcc\x80\x05yz$YJ\xb4k\x9e\xef\xd3\xa7f\xd5iO\x8a\x86b\xf8J\x19L\xc4\xe72\x92\x14\xbc\x15\x8d1+\xf14&m\x83:\x88<\x17\x08\x87h\xab\xb7\x07\xc3\xf2\xa4x\xa9\x9f.d$\xda\xf8\x12\x8fr\xc8\x85\xc6U\x17\xc3\xb8\x96\xea\\\xbc\xb4|\x90(8\x83"]
# Bad pipe message: %s [b'\x07G\xadI\x17\x83\xe9\xa1\x06\x06\xa5\xb3\xbd\xa3%C@;\xae[;\xd0\xea\xc0\xfc\xbcV\xb8\xd1\xbee\xe7\x12LIv\xa6\x89S\xfb\x00', b'$l\xa5\x82\x80\xbf\xea\x84}\x96h+\xf4\x06\xfd\xa7V\x1e\xa3\xbf9\x03O\xf50,\xdc\x04E\xb7\xf6@Qu\x00\xe2\xb0\xcbIt8\xdc\xda\x8d\x05\x8b\x1clIpm\xb7\x10\x1ec\x9ddq\x86$s*\xe8\xb3s[L\xbd\xae\xcbO:\xf0\x90\xb2a\x9bj|\x17\x9d\x94t\xab\x84\xa4\xba\xfb}\xb2\xb6\xae\xdf!\x18$\xf9\xb4\x9f\xdc?\xe2\xc6l\xaa\x08\xa4\xe7\xd7\xadR\xf1\xc5K\x92g(R,w\x8c)\tZ\x0c\xb8\xa6\xa2\xcf\x97@9\\\xa5=\x91j\xb8j\xcf\x8a2\t\xfc2\xbcR\xf8\xa0\xca\x00<\x9d\x9a3n\xb6\xb2\x13C\x03\xd5\x06(Y\xe2dU\xf8\xc7\xc0s\x05\x1d(\x81nJ\x04\xaf\xeb\xaf\xd7\xc9\x99t3+hQJ\xed\x9c\x03\x98\x83\xc4@\xf3QE\xf08\x19\xb9']
# Bad pipe message: %s [b'\xd8\xca\x820;\xe2F\xc5G\xb11\xda\xf1\xcc}\x055\x1bx$\xdcf8\x9ca\xba;\x83\xa0\xe5\x80\x1a\xa0\x19:\x9dl\\]2V\x88\xeaQ\x99\xe9b\x88\x80@\xb4D1\xe29\x88\x07\xd0l\xea\xd6S\x15\xf6\x06\x14j1\xfc\xe3\xc4\x01\x91\xa0U<\x11Qd^\xce\xd1\xc7\xa65\xb2M\xf5\ndt\xa3j\xc6\xb2\xfaJ\t\xc3\x1b\x03\\&\xa9o\xb7\r\x86\xca\n\xc5\x1b^?\xa6\x91K\xfa>AG \xbeKu\x1e\xe51\x04i\x84\xe6,\xa8w&g"8\x88?\x85e3\x83_Op|@F:\xf9Y\xa2o\xe3\x00:\xf0\x7f\x98\xbc\x8d\xb70\x02\xf4\x06\x90']

# %% [markdown]
# Simulate from fitted parameters.

# %%
# either load or perform model simulations

sim_path = os.path.join(
    product_dirs["simulations"], f"{data_tag}_{model_name}_{run_tag}.h5"
)
print(sim_path)

rng, rng_iter = random.split(rng)
params = {key: jnp.array(val) for key, val in results["fits"].items()}  # type: ignore

if os.path.exists(sim_path) and not redo_sims and not redo_fits:
    sim = load_data(sim_path)
    print(f"Loaded from {sim_path}")

else:
    sim = simulate_h5_from_h5(
        model_factory,
        data,
        modeling_features,
        params,
        trial_mask,
        experiment_count,
        rng_iter,
        simulate_trial_fn=simulate_trial_fn,
    )

    save_dict_to_hdf5(sim, sim_path)  # type: ignore
    print(f"Saved to {sim_path}")

if filter_repeated_recalls:
    sim["recalls"] = repetition.filter_repeated_recalls(sim["recalls"])

# %% [markdown]
# Figures

# %%
#|code-summary: single-dataset views

for analysis_cfg in single_analyses:
    analysis_fn = analysis_cfg['target']
    figure_str = f"{data_tag}_{model_name}_{run_tag}_{analysis_cfg['figure_suffix']}.png"
    figure_path = os.path.join(product_dirs["figures"], figure_str)

    if os.path.exists(figure_path) and not redo_figures:
        display(Image(filename=figure_path))
        continue

    trial_mask = generate_trial_mask(data, trial_query)
    sim_trial_mask = generate_trial_mask(sim, trial_query)

    for (dataset, trial_mask) in zip([data, sim], [trial_mask, sim_trial_mask]):

        if analysis_cfg.get('color_cycle') is None:
            color_cycle = [each["color"] for each in rcParams["axes.prop_cycle"]]
        else:
            color_cycle = analysis_cfg['color_cycle'].copy()

        base_kwargs = {
            "datasets": dataset,
            "trial_masks": np.array(trial_mask),
            "color_cycle": color_cycle,
            "labels": list(analysis_cfg['labels']),
            "contrast_name": analysis_cfg['contrast_name'],
            "axis": None,
        }
        base_kwargs |= analysis_cfg['kwargs']

        signature = inspect.signature(analysis_fn)
        filtered_kwargs = {
            name: value
            for name, value in base_kwargs.items()
            if name in signature.parameters
        }

        axis = analysis_fn(**filtered_kwargs)

        if analysis_cfg['ylim'] is not None:
            plt.ylim(analysis_cfg['ylim'])
        plt.savefig(figure_path, bbox_inches="tight", dpi=600)
        plt.show()

    print(f"![]({figure_path})")

# %%
# generate figures comparing model and data
for analysis_cfg in comparison_analyses:
    analysis_fn = analysis_cfg['target']
    figure_str = f"{data_tag}_{model_name}_{run_tag}_{analysis_cfg['figure_suffix']}.png"
    figure_path = os.path.join(product_dirs["figures"], figure_str)
    print(f"![]({figure_path})")

    if os.path.exists(figure_path) and not redo_figures:
        display(Image(filename=figure_path))
        continue

    if analysis_cfg.get('color_cycle') is None:
        color_cycle = [each["color"] for each in rcParams["axes.prop_cycle"]]
    else:
        color_cycle = analysis_cfg['color_cycle'].copy()

    trial_mask = generate_trial_mask(data, trial_query)
    sim_trial_mask = generate_trial_mask(sim, trial_query)

    base_kwargs = {
        "datasets": [sim, data],
        "trial_masks": [np.array(sim_trial_mask), np.array(trial_mask)],
        "color_cycle": color_cycle,
        "labels": list(analysis_cfg['labels']),
        "contrast_name": analysis_cfg['contrast_name'],
        "axis": None,
    }
    base_kwargs |= analysis_cfg['kwargs']

    signature = inspect.signature(analysis_fn)
    print(analysis_fn.__name__)
    filtered_kwargs = {
        name: value
        for name, value in base_kwargs.items()
        if name in signature.parameters
    }

    axis = analysis_fn(**filtered_kwargs)

    if analysis_cfg.get('ylim') is not None:
        axis.set_ylim(analysis_cfg['ylim'])
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()
