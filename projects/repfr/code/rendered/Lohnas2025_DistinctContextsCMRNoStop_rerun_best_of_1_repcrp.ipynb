# %% [markdown]
# Compare repetition-centered lag-CRP curves for observed data and a matched control dataset.
#
# Adjust `control_trial_query` to define alternative control populations.
#
# Set `repetition_index` to 0 or 1 to focus on specific presentations.

# %%
import matplotlib.pyplot as plt
import os

from jaxcmr.analyses.repcrp import (
    plot_rep_crp,
    subject_rep_crp,
    test_first_second_bias,
    test_rep_crp_vs_control,
)
from jaxcmr.helpers import find_project_root, generate_trial_mask, load_data
from jaxcmr.repetition import make_control_dataset
def save_figure(figure_dir, figure_str, suffix=None):
    plt.tight_layout()
    if not figure_str:
        plt.show()
        return
    os.makedirs(figure_dir, exist_ok=True)
    suffix_str = f"_{suffix}" if suffix else ""
    figure_path = os.path.join(figure_dir, f"{figure_str}{suffix_str}.png")
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()

# %%
data_path = "data/LohnasKahana2014.h5"
figure_dir = "results/figures"
figure_str = ""
ylim = None
mixed_trial_query = "data['list_type'] > 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 10
min_lag = 4
max_lag = 5
size = 2

# %%
# Parameters
data_path = "projects/repfr/results/simulations/Lohnas2025_DistinctContextsCMRNoStop_rerun_best_of_1.h5"
figure_dir = "projects/repfr/results/figures/fitting"
figure_str = "Lohnas2025_DistinctContextsCMRNoStop_rerun_best_of_1_repcrp.png"
mixed_trial_query = "data['list_type'] == 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 1
ylim = [0.05, 0.32]

# %%
project_root = find_project_root()
figure_dir = os.path.join(project_root, figure_dir)
data_path = os.path.join(project_root, data_path)
data = load_data(data_path)
trial_mask = generate_trial_mask(data, mixed_trial_query)
control_dataset = make_control_dataset(data, mixed_trial_query, control_trial_query, control_shuffles)
control_mask = generate_trial_mask(control_dataset, mixed_trial_query)
datasets = [data, control_dataset]
masks = [trial_mask, control_mask]

# %%
plot_rep_crp(
    datasets=data,
    trial_masks=trial_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="mixed")
plot_rep_crp(
    datasets=control_dataset,
    trial_masks=control_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="control")
# Out:
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)

# %%
observed_crp = subject_rep_crp(data, trial_mask, min_lag, max_lag, size)
control_crp = subject_rep_crp(control_dataset, control_mask, min_lag, max_lag, size)

results = test_rep_crp_vs_control(observed_crp, control_crp, max_lag)
for label, result in results.items():
    print(f"\n{'='*60}")
    print(f"Statistical Tests: {label}")
    print(f"{'='*60}")
    print(result)
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b"#\xa6\x85\xd5\xf3<:\xa0\xa9\xe0,\xf5\xac7\x05\xd0\x99\xf1 eh\x94,\xfa\x9c\x8d\x87o\x11*ILfA!\x8d$\xe1\x85O\xae:\x92'\xd4\xe8M\x0f\x88\x94\xf8\x00*jj\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\n\n\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xfa\xfa\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\xfa\xfa\x00\x01\x00\x11\xec\x04\xc0"]
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\x98s\xb4x\xe0\xd5}\x03\x06Y\xbb\xcb\x070K[Y\x11\x93#C\xc9\x06T\x81\x0e7l\xcd\xbcFJ\xacW`\x04\x0b\xb0\t\x98\x9a\xd1\xce\x9e\xc9\xc6\xbb\x02\xbba\xac\xb9"\xcc\xb1\xd6K=vj\xcb\xd1\xf5Y\\\x9b"k\xc2~\xc3\x13\x84\xf3\xd07iZe\xe0\xe10\xabl:\xcb\x8b\xc2\xdc\x81\x1a%\x11\xae9\xc0_\xe5a6\xc9\x90\x87-', b"\xb4AO\x9e\xc1Q\x16\xf28\xff6DUb\x9b\xa0\x9a\t\x03\x82?Z\xf2\x8c\xbd\x11DE@\xc9\xcc<y\xb0@\x0b^\x17\xb7.4k\xb7\x9b\rS\xc6\xb8\xfb0)*\xe4%\x04p\x1d'\x8a\xa5\\\x02Mb\xe6G\xee\xc7\x00q\xdc\x8ca\x8ad\x1ecQ8\x98\x0fH\xd1g\xa3\xc9\x17\xbc[\x13\x1etd\xae\xd7<B\x15$\x0e\xaa;<Kr\x1f0N\x16\xfc?\x18\x97\x10\xf7C|\xe2\xaa!bi\xc6C4,AA", b'\'\x8c\xc6el\xaf\xc7\xa1\xca\xaa\xcf\xa9\xcc\xc5\x12\x16C(\xd1\xbaw\x89\xa9Wz\x10 \xb9\x98\x0b$+\x84B3Y\x00\x08\xbb\x8a\xb0\xcd\xe0/h59nJ/\xb7X\xb1\xe9\xe4\x8a)\xe0\x8d|\xa8\xae\x82\xf2?\xd2\xdc\xa4\x824\xc6\xd3\xba\xafUx\x9a\x92\x97\x8e\x97"\xabK\xf0\x17\xe0#<&\'Y`\x98\xc2\xe9\xf8\x92\xb4f?\xa4\xa5W\'\xd5:J\x10?$\x00>/\x80\x90\x99\xb6\x07\xc8\x8622\x92h', b'\x1a\x91\x029<\x1bi\n*\x13e\xf2+5\x988\xd6\x0274\xb12\xd8\x83:\xce\xe9E\xf7\xdbyV\xe2k\xb0\xe0]\x9c\xa0\x7fM6\x94K\xbb\xc9\x86\x97\x86Y\xa5|\xeeS\xc7\xdfT\xbf`\x19B1goY\xa5)\xe25\x93n9L\xe0\xa6A\x16\x00,s\xa5q\xe84\x1c\\FK\xbd\xb0\xb6U\x93\xc3f\x01o\xd3U)\x06\xca\xc0~\xc0e\xe8YZ/|n\xe6\xa6\xaf\xbd\x17/\xae\x13\x9f}9D"Fx\xa1\xc8*\x89\x1a\x93\xe8$>@', b"\x1c\x03\xbe+\x03nU\xc5\x94?f\x9e\xc0\x026\x87\xc3\x8f'VH\xae\xb0\x13=\xeb\x89\xdc\xd9\x18\x96iX\x17\x9cM\xf4!", b"5\xc0\x8e\xb4dD\x15\x9a\x91\x8a\xa5\x03DL\xdb\xabI\x0e\xa8m\x0fr>\xf8\xb6\x02\xce\x85ob\xd5\x8d\x19\x8c\x1e5\xd1.\xcf\x00%\xe0\x10C\x19\xe4'", b"\xba\xb38\x95\x1e\xc4\x044\xc1U#\x80R\x7f1h1\x01\x85\xe7\xe1nKA\x0f\n\xa3\x02G\xc7\x08\xa4\xb4\xa3ES-Gv`\x1ehr\xab\x93\x90\x9a|\xb1#\x1c\x94X\xa0\xcd\xbe%ZEH`\xd8X\x8d\x97\xa4\x9e\x057\xca\xcc\xd3o\xf2\x12\x9f\xe3PZX\x01 @\xe6\x86\xd1R 7EY\xc2\xe5\x9f\x16X4\xaeFfmkn\xd8\xa7\x8f`\xccI\xc9\x9b4\x0c\x97*e35'\xf0k\xf2&\x18F\xbbP\xb8\n\n\x0bUu\x04\xc2b\xfe\xe2\xc0N\xa1\xc7\x9d3\xbcBy\n\x93\xe1\x12\xb4\x1a\\\x0b\xb7\xb8/\xc2\xb1n\x83)\x95\xf5\t\x96*~\x92\xeb\xcd\x93\xe7S=i\xca\xb2WJ", b'\xc8j\xebi/\x89\x83\x04\x1cb\x80\x80L\x19<_H\x15\xb8s#V\x98\xf7\xb8`\x03\x82X\x863\x0e\x95\x00)\xd31\x1f\x16\x82Q{nul\n\xee\x14\xae\x04\xe3\'\x0c\x91\\*\x946\x1d\xa9"\x84\x97\x9d\x95\x13w\x0b\x91\x91\x05\xf1zdE\x98\xb5\xa5 \xc8\xe5}\xddf\x00\xc6\xd1]\x96JR\x1b\xfb\x97\x1f\xf5xl\x16\x1a\x13\x8b\xc7\xa7\x98\x15\xfc\x19B3\xc0"e\x85U\xf2\t6\xceF\xa5,*s\xaf:\x7f\xc6i@\xf3+\x0b!4\xac\'\xb8\x99\xd2\xfc\x97\xc4b\x0fHwAA\xdb\x84\x81ZY\x9e\xa0s\xf4i\x8bj\xc6*\xea\xd2#\xfdZu.\xd5?W\x048N\xc5g\xc2\xdc\x04eZ\x9a\x17\x05\xbe\xc8,\x98\xd3\xab\xb9\xd8"\xa1\x98\x92U\x96$"Xi{\xbb\x08']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\x92\x80\xb4f\x84\xa6\n\xc0B\xf1\xa7Ex=|F\xbaN\x12\xc9O\x82\x8b\x9c\x11\x8a\xb8\x88\xce\xf3\xa8\xb4x\xfa\x93\x88\xf4\x1c\xe8\x8a\xc5\xbbk\xcb&\xc2@\xe1\xacvfS\x1bJ\x01>\xc7\xf9\x99\x83Z\x97\x16l\x9d\xaed\xb7n\xd0#\xc5x\xc2\xc8;_!2-bYx\x1dtK\xb0L\x06\xa8\x0cX\x937\x9a\xef!R\x10\xa58\x19*dd9\xb8+aM\xa5\x04\x9b\xd9\xc4(\x0f\x01-\x9d\xaa\xc6\xa0Pv/&Do\xa6(\x1a$5\xdb\xa9]\xb9\xf4\x16#\x0c\x19_C\x9a\x91|[TV/\xe7a\xbcv\xdb^\x8b\xa3\x0fK\x99\x1b\xa3\x01\x1e\xda\xc38H:(\xc6\xceQ\xa4\x1a\xd4\xae\x0f\xa2B\t\xb9y\xb5a\xc1l\xbc\xeb']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'"X\xd1\x89\xf8W\x91ht7k\x82\\\xf0\xa3/\xea\xe7 -z\xffD\xa6\xfc\xb7\x86\xd4W\x96\tfp.|\xb8\x0b\x02S{\xd8z\x92\xe5\xd8\x17\x13\x89\xd4\x99p\x00,\xaa\xaa\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\x1a\x1a\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c**\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed**\x00\x01\x00\x11\xec\x04\xc0\xe4\x85\xbb\x81\xe0([\xfcT^x\x94\xb9\xca\xc5', b'\x92\x0f\xfb\xa80\xa3F\x97\xa4"\x93e\rwd\xc27\x0c\xbf\xf0\xf9\x9a\xa6dn7\xdau\xf0\xf5*\x07\x0b\xaf9g\x86\x89\t&\xac\xf2l\xbd\x13\x08\x92t\xbbk\xc3Zel\x11i\n\x19\x01\xbb;\x0cB\xb9a9\xbb\xba\xab\x10\x19X\x92\x1c\xca\xa9\xfeH5\x1b\xbcU\x80\n\x1c\x80\xd8\xc8\xa5\xe4d\xe4\x99\x02%\x99\x9bj\xe1\x04L\xd5\xbf,\x8c3\xd9G\xa0\xcd\xb3\x1cx\xfbt`h\x18\xe0\xaa\x83p\xb8\x89\x86\xb6\x0b\x02\xc1\xafp\xe6S\xa3\xf6\xb9&d\xb0']
# Bad pipe message: %s [b'\xa2\x87\x02\x0c\xbdQAvdc\x00\x9d\x99@\xb7\x87\xb7\t\x95q\xb7x\xb9Q\xbf@6\xb1\x03`[\xf7c\n\xb7\xc0=y\x15\xc3.<\x1c\x95!\xc9Y\x87\xc7\x16 \x98\xae$\x8e\xd1s/\xf7\xdb\xb7Bto\x1c4\x13\x97|\xb2\x88\xbb\x9eG\xf3\x04!C\x11\x00\x0bT%\xba\x98\xa4lIF\x86\x02\xc4\x0c\x93\x07Qp\x9fI?\xc1t\xccJ\xf2\x86\xc2f\x83\x8e\x07{!\xc8\x13\xe0A\xab\xde\xe8\xb3\xa9\xc6\xae\x17\xbaW|I&\xe1(\xb0J\x8c\x17\xee\\w\x06\xf37B\xe6SPLlR\xe3\x17\x938\x88NP]g\xc9\x04\x0b"\xa2\xf7\xf2-[\xf4>n4>\x15\xb44\\&\xc1\xb2\xc0&R\xe7_\x91\xc0\xa4\x03v\x17\xc8\xa9\xb8jb\x01&\x88J\x9c\x16\x8e\xcb\x8cY\x1cx', b'\x10x\xe1\xb6', b'\x90\xb7\xb5\x1a=\xd0a\x8c\x82j\xa8\x81{]x#\xb4\x93\xbc]\xe7\xd9_\x85\x13?\x82\x8b\x89\x1ef(\x8b\x99.\r\x88\xc6\xf7\xb90\x17\xab<\x91\xe8\x14\x9a\xc3q\xefg\xc5\x82t\x05\x8e\xf3\x9b9\xc5&\xae$\x04\x1fAp\n3\x17\xad\xcb\xa5Ke']
# Bad pipe message: %s [b'\x84\x16\x06\x100\xc8P\x8a\x8c\xd7\x01\xe1$$\x00Qv?\x0bl\xe9s\xc3}\x03\x97p\xe9/\x1f8Q\x7f\xc3\xa3\xbd\x0b\x9cb00\x83\x169\xf8py\xb7a\x0cM;92zOP\xd0xY\xd2\xc2\xf3KhE@}\x1a\x86\x98\x84B\xc5\xa8\xc57\x083\xba\x1f\x814k\x84\x1f\xc5\xa2\x87\xf7+H\xd3\x04\xc2$e\xc0h\t5\x9e\xba\xa2\xb3\x94t"#\x84A\xd7,\xc3\xf0 &\x92t"\xd8\x06cU9x\xe0\x02\xf8\xb8\x82\xaduP\x81\xbb\x82\x83c\x89]\xd7>\xe0\xe6\xac\xb1h\xb2t&\x9a\x1e\xd3!\x12:\x88\xa7h\x94&\xf5\xa2\xf8i<6\x88\x8d\x88L\x11q\x82"\xa8ui\xf0znW\x15\xb0F\x10t\x93\xaa\x82w\x97RKr\x04:\xccN\xd5\xe1']
# Bad pipe message: %s [b'\xe9*\x06&\xc4\xb2e\x832\xe1\x88\xec3+\x9aFv\x10\xe26P7\xa0\xd8,%\x9a\x1b\xcdk\x16\xac>']
# Bad pipe message: %s [b"\xbe7A)\xbc#\xd6\xf0F\xc8\xb5\x9c\xa3')\x8c\x83\xa8\xe3\x11m\xe3H\xb9\xea\x98\xa9E\x11F\xba|J\xd6\xf7Sg\x89\x919ry\x07E\xa1\xee\xf4@\x0b\xc5\xa3\x01\x85\xa2\xa5+>J\x87\x97\x12\xd8w~wg\x9c\x12'\xcd\xea]\x8e\xc5\x01\x95\xd1\xc6\x97\x035\x13\xd1o\x9f\xa05\x1dFM\x1e\xbc\xc9\x9c\xf1\x18\xe4v\x9e\x1f\n\xabV\xfc0@\xc2\x8b\x1f\x1cAb\xf1\xc2^kmR\xe8\xb9.\x19\x01\xf5\xb1*\xf2\xc5\t/\xe0\x0bf\xd6!\xf8\xb1h\xd6\x067\xad\xe1\xac\x03&x\xb2\xcb;\xb3\x96K\x141\x92\xa8\x08\x9co\x99+9X\xba\x98\xf9\n\x85*8g 6\xdd\xdc;\xcbH\x98\xf9\x12\x05\xa3b\x9c\x06\x00\xb9E\xf3\xbcC\xcc\xadM\x8an\x14\x83"]
# Bad pipe message: %s [b'\xcau\xbd\xdc2\xbc\xe8\x94f\xfb:\xc55j\xfd\xca\x01Q\x95\x7fO\xb60\xf9\x96^\x8a\xe0h\xbdWJD\x99\x01\xdd\xa0\x08\xce!\nKQ\x1b\xc2\x94`a\xf7\xb1W\x86\xc4j2\\\x12\x1bPDk\x82\xa8\xeav\xa4,d\x04;\xc0i\xe81}\xe6\xc1wE\x12K\xa7\xc0c\xe10]\xc3\xc68pv\xc0Hg\xb5fQv\x87\x0b\xecPl\xd4\xc7\xb4L\t\x0ek\xa6\xcd%"\xb7,b>\xd01w\xaegS\xb5\xa9^)k_\xe5\x84\x1c\xc9+\x92"\xf1*Ms\x1du\xd1S\xd3hk\xe3\x97\ni|,\x04[1\x1f"\x92E\xab!\xed6d\xb4\x8b}9ir\x1e\xe4\xa1R\xc7\xa8?&zoU\x05=1\x02R\xd8\xa3f\xfb\xbcV\x82A?C\x82p\x82\x8c\xc3']
# Bad pipe message: %s [b'\xf0\xf16Y\x05\x1c[g\xb7p\xf1i\xb5\x88\x06\xee\xb9\x97tg\xc3\x8d\x18sq5L\x83\xf9\xa8a\xc3\x91\xf2T\x83\x10\xa670\xea\x1ec\xe6\x07W!\xc2u\x0c\x93\x98\xdb,\x08w\xb4NqD\x1a\x1eT\xf9\x04k\xff\xe4\xdfT]\x05\x99\xc6\x1b\x83E\xe6\x01\xb9\xd7\x9a\xa0\xfc\xd7W\xf3\xadbO\x95c\xaa\n\x05X/!\x9f4\xdb\xc2\xe5\n/\xc6\xde\xf2ms\xbb\x8a\r\xfcX\x087C\x00\x1d\x00 \xcdAw\x01\xa9\x91']
# ============================================================
# Statistical Tests: First Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |   -0.619     0.5363 |  26549.0     0.3698 |    -0.0009
#    -4 |    0.408     0.6839 |  27833.0     0.8626 |     0.0005
#    -3 |   -1.189     0.2353 |  26437.0     0.3371 |    -0.0015
#    -2 |    0.592     0.5539 |  27110.0     0.4452 |     0.0008
#    -1 |    1.622     0.1058 |  25640.0     0.1130 |     0.0028
#     0 |      nan        nan |      nan        nan |        nan
#     1 |   -3.442     0.0007 |  22540.0     0.0009 |    -0.0084
#     2 |   -1.761     0.0792 |  26336.0     0.2684 |    -0.0023
#     3 |   -0.992     0.3218 |  27715.0     0.6705 |    -0.0012
#     4 |   -0.572     0.5674 |  27813.0     0.7109 |    -0.0007
#     5 |    0.520     0.6034 |  26563.0     0.2850 |     0.0008
#
# ============================================================
# Statistical Tests: Second Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |   -3.026     0.0027 |  23753.0     0.0083 |    -0.0074
#    -4 |   -1.788     0.0747 |  26851.0     0.3638 |    -0.0024
#    -3 |   -0.454     0.6501 |  27727.0     0.7444 |    -0.0005
#    -2 |   -0.263     0.7927 |  27397.0     0.6092 |    -0.0003
#    -1 |   -0.322     0.7479 |  26207.0     0.2048 |    -0.0006
#     0 |      nan        nan |      nan        nan |        nan
#     1 |    1.015     0.3106 |  25150.0     0.0631 |     0.0021
#     2 |    0.991     0.3223 |  26051.0     0.2053 |     0.0012
#     3 |    2.089     0.0375 |  24555.0     0.0352 |     0.0022
#     4 |   -0.653     0.5139 |  27743.0     0.6819 |    -0.0008
#     5 |   -1.184     0.2374 |  28255.0     0.9015 |    -0.0022
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:507: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_col, ctrl_col, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:518: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff)

# %%
bias_result = test_first_second_bias(observed_crp, control_crp, max_lag)
print(f"\n{'='*70}")
print("Test: First-Second Bias (Observed) vs First-Second Bias (Control)")
print(f"{'='*70}")
print("H0: The preference for first-presentation neighbors over second-presentation")
print("    neighbors is the same in observed data as in the shuffled control.")
print()
print(bias_result)
# Out:
# ======================================================================
# Test: First-Second Bias (Observed) vs First-Second Bias (Control)
# ======================================================================
# H0: The preference for first-presentation neighbors over second-presentation
#     neighbors is the same in observed data as in the shuffled control.
#
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    2.197     0.0287 |  25155.0     0.0768 |     0.0063
#    -4 |    1.652     0.0995 |  26432.0     0.3356 |     0.0027
#    -3 |   -0.538     0.5907 |  28284.0     0.9144 |    -0.0010
#    -2 |    0.609     0.5429 |  27874.0     0.7364 |     0.0011
#    -1 |    1.182     0.2380 |  27875.0     0.7368 |     0.0034
#     0 |      nan        nan |      nan        nan |        nan
#     1 |   -2.900     0.0040 |  22064.0     0.0003 |    -0.0105
#     2 |   -1.887     0.0600 |  24764.0     0.0467 |    -0.0036
#     3 |   -1.970     0.0496 |  24738.0     0.0367 |    -0.0034
#     4 |    0.056     0.9553 |  26671.0     0.3131 |     0.0001
#     5 |    1.221     0.2231 |  26420.0     0.2506 |     0.0029
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:576: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_d, ctrl_d, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:587: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff_of_diff)
