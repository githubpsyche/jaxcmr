# %% [markdown]
# Compare repetition-centered lag-CRP curves for observed data and a matched control dataset.
#
# Adjust `control_trial_query` to define alternative control populations.
#
# Set `repetition_index` to 0 or 1 to focus on specific presentations.

# %%
import matplotlib.pyplot as plt
import os

from jaxcmr.analyses.repcrp import (
    plot_rep_crp,
    subject_rep_crp,
    test_first_second_bias,
    test_rep_crp_vs_control,
)
from jaxcmr.helpers import find_project_root, generate_trial_mask, load_data
from jaxcmr.repetition import make_control_dataset
def save_figure(figure_dir, figure_str, suffix=None):
    plt.tight_layout()
    if not figure_str:
        plt.show()
        return
    os.makedirs(figure_dir, exist_ok=True)
    suffix_str = f"_{suffix}" if suffix else ""
    figure_path = os.path.join(figure_dir, f"{figure_str}{suffix_str}.png")
    plt.savefig(figure_path, bbox_inches="tight", dpi=600)
    plt.show()

# %%
data_path = "data/LohnasKahana2014.h5"
figure_dir = "results/figures"
figure_str = ""
ylim = None
mixed_trial_query = "data['list_type'] > 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 10
min_lag = 4
max_lag = 5
size = 2

# %%
# Parameters
data_path = "projects/repfr/results/simulations/Lohnas2025_BasePositionalCMRNoStop_rerun_best_of_1.h5"
figure_dir = "projects/repfr/results/figures/fitting"
figure_str = "Lohnas2025_BasePositionalCMRNoStop_rerun_best_of_1_repcrp.png"
mixed_trial_query = "data['list_type'] == 2"
control_trial_query = "data['list_type'] == 1"
control_shuffles = 1
ylim = [0.05, 0.32]

# %%
project_root = find_project_root()
figure_dir = os.path.join(project_root, figure_dir)
data_path = os.path.join(project_root, data_path)
data = load_data(data_path)
trial_mask = generate_trial_mask(data, mixed_trial_query)
control_dataset = make_control_dataset(data, mixed_trial_query, control_trial_query, control_shuffles)
control_mask = generate_trial_mask(control_dataset, mixed_trial_query)
datasets = [data, control_dataset]
masks = [trial_mask, control_mask]

# %%
plot_rep_crp(
    datasets=data,
    trial_masks=trial_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="mixed")
plot_rep_crp(
    datasets=control_dataset,
    trial_masks=control_mask,
    max_lag=max_lag,
    min_lag=min_lag,
    size=size,
    labels=("First", "Second"),
    contrast_name="Repetition Index",
)
if ylim is not None:
    for ax in plt.gcf().axes:
        ax.set_ylim(ylim)
save_figure(figure_dir, figure_str, suffix="control")
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'.\x81\x9f!Y\xa7\x0c\x97m\x91\x1d\x9c#\xf3\xbc\x8d\x8dg \xff\xf3\x03\x9d\xb1ij\xdf_\xc2\x8c\x0e\xa3\xe8\xaaBH\xb4\xf6\xf6x\xf9\xdb\x1f\x1f\xc0Md(\x04\xf2U\x00*ZZ\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\n\x01\x00\x05n\xea\xea\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0c\xda\xda\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00\x12\x00\x00\x003\x04\xef\x04\xed\xda\xda\x00\x01\x00\x11\xec\x04\xc0\xd2\x97Lt\x9bf\xd0Bj\xcf\xb9\t\xf2a\x0b1\x1c\x12\xe4\x14\xbc\xf1\x07+\xd3\xcaA\xbfP\xa0\xb9\xabx"\xec\x88\x95\xa0\xb2\xd3\xe6\xc65\x99', b')\xcc\xc0<\x18\xe3\x8a\x92\xd1\xba\xad&\x81\x86N\x89>6qK\xf3[b\xe5gF0\xa2kx\xb4\xb6\x08\xb2\xca\xf3\xdb\x93\xc1\\1\xef|QQ\xf0C\xde\x07\x7f\x8d\xf4\x9eqC\xc4\x85\xb2\xb7\xbe\x13.\'\xb88h*K\x9dLIH6\x05v9\x0bg\xc2\x00:\x84\xa0XSrfs\x97z\x9c\xb9\xf6C%8\x043\x0fj\x87\x04$\t\x11\x91uP"~\x91\x90\xab\xe9LY\xd6\x92\x0f\x11\x138\xffin\xd0Q\xcfV+\xa8XE\xc6\xcdCb\x17\x06\xaa]\xaa\x8f\x8dv\x00\xb6\x04\x8dJ(\x97\xe3\xa7']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\xa2\xae\x0bVA8UK\xc3\xfc\xb0\xb9\xa1%.+\x9b\xa4r_\x06br\x19\x12K\xa8\x83-\xe0H\xb6s\x99W\x0c\xf4\x94\xbe\x08U\xbd\x9b]/\xe8OU!PD\xf0\xa5\x17\x9am.\x08\xb3\xf0\xbc\xc2/\xf5]\x88\x8a\xba\x7fl', b'[F\xbe\x9b\xc6\x08\x17\x8f\x81\xc9\xa0y\xdb \xd4\xac\x90\xaa\x99\xc5\x8fY\xb2\x97\xfc\x9c_Z\xcd\x80i5\x04\xec,\x04\xe9L\xb8rc2\xc8\xa2wGkH\xcc\x03sA\xc6\x19\xdb\xc3\xd9\x18W\xa8\x91\x12\xfb\x8c\x17\xfaY7\xb5"U', b'\xbbu\x97i\xecYW\x91\xdc\x91\xa7C! h4\x8f\x161o\xccV\xf5\x89\xb5`x\xa5\\\xd0/\x89\xd1^PG\xc3\x1b$\xbf\xf22\xb0\x8b\x0b+\x9a\xc4^4\xc9#\x0f\x1c\xc4\xb0\xfb\n\x81\xcc(\xff\x00\xac\x02\xa2\x16\xdd\x10\x07\xb2\x04\x1dl\x92\xbf\xce\xc3=\x18\x1c\xcd\x81\xf9/\xb9%\x14\xef\x1c}0\x08#\xbbJ/\x0c\x1b\xc4,\xcc\xbco\x1c!Z1\x14\xac7\x16\\\x07\xc1.\xe0\xa2^\xfa+\x8d\x89e\x88V\xa9\xfby}\xba|F\xb8\x96\xbdcy\x930\xa4\x9fPX\x13\x1d\xa7\x16x', b'@Hj\x95\x84\x13\x0bY\x88\xfa<\xa6\xea\x04S{h\x82Us:\xfc\xd4\xb0\xc5Y\x812\x86W\xdf|]8\xe6\x15X\xb3X\xc7\x10aC\xe6\xa5\xbf\x9a\xaf\xa5\xd5\n\xb3\x8b\x12y Fy\xb6\rT\xe3\x1f\xbb\xbcK\xfb\x05c\x0c,QwZ\x17\x8fg\xa6\x0f\xbb\xbc7\xec\x18\xf8Kn\x0b\xe6\xb8>x\x95\xd1Q\x87\x9fC)\xd1\x91P\xa5\xca|\xd8\x90\x87\x0b\x9b\x08\xb1\xb3\xa0\xf1x\x1b\xa9\x19\x01K\xa8\x8b\n\xc8\xbd}\xd2ln\xf78\xf76\xa7\xa6\xe2M\\I"\x80\x84\x8e\xced,\x9b\xac)\x96k\xa0Mbh\xdb4\x1b"\xebX\xa1\xa4:\xd7\xa4>}\xeb4\xa4\xbb3\xbe\x0c*\x16\xe3\xc3\x977?L\xf7\xa2\x84']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'\xd0k\x8c', b'u\xd2A\x86\x07\xb8\xbf\xb1\xe5wO\xa4\x01\xe5 W:\x91B\x80\xb3:=\xc1:b\xebu\xe5@Z\x06\x12X\n\xab\x06\xec\x08D\xc7U\xab\xc7wj\xd1\xe4\xa15\xe4\xaf\xc8\x16\xc1\xc8\xe5\xbfJlSN\x03\x13:9']
# Bad pipe message: %s ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [b"\x86\x18'6\xb3\x8c\x899\xb48l\xdf\x81\x98", b'\xa2\xfb \x91f\x8d\xc9_q\x04\xf0\x1c9\x87\xdd\x98\x8e\xd6xoq\xd8\xdc\xd8\xca\xfe\x9a\xe9\xe0i`A\xbe\xf05\x00,\xea\xea\x13\x02\x13\x03\x13\x01\xc0,\xc0+\xcc\xa9\xc00\xc0/\xcc\xa8\xc0\n\xc0\t\xc0\x14\xc0\x13\x00\x9d\x00\x9c\x005\x00/\xc0\x08\xc0\x12\x00\nV\x00\x01\x00\x05n\xaa\xaa\x00\x00\x00\x17\x00\x00\xff\x01\x00\x01\x00\x00\n\x00\x0e\x00\x0cJJ\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\x0b\x00\x02\x01\x00\x00\x10\x00\x0e\x00\x0c\x02h2\x08http/1.1\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\r\x00\x16\x00\x14\x04\x03\x08\x04\x04\x01\x05\x03\x08\x05\x08\x05\x05\x01\x08\x06\x06\x01\x02\x01\x00', b'\x00\x003\x04\xef\x04\xedJJ\x00\x01\x00\x11\xec\x04\xc0n']
# Bad pipe message: %s [b'K\x9ezZ\x899Y\x97\x06\x06.E\xfaK8\x8bl\x00\xf8\x08u\x93K\xbaC}\xbc\x05<\x82 \x93\x17K\x9e\x1b\x06\x0e/ \x0b\x9b\xf8{', b"J/\xd8?\xf4\xb8J\x9b'A\xf6\x90\xa5\x97\xb0P\xcf\x93\x80\xf50\\\xae\xc2`\xee)l\x84\xf4\xa2\xa2@QHHEb\xd3A\xa0\xc5F\xaa\xb50.\xb0\xa7R\x99#\xcb\xe4A\xc2\xf9\x91\x1f:\xb2\x08u\x02\xf4\xbb:\xb0\x14\x0es;B<\xe4\x8cG\xd8a=&<\xf5&=\x9f(\x04\x9e\x03\x14\xc4q#\xb1\x87\x8a_0F\x1c@-", b'\xcd"\x13\x80\x91Q\x87\x1d\xe5bG\xf0\xa0-\xc5\x89}\xf4F\x1avr\x0c\xd1\xb6\xa7\x94rY#\xb3N\x1b\xa7\x1e7\xaau\x07\x90\xb1R0\x1d\xd3.I`\xb4]\x96?\xae`\xa4\xb9hZ\x8e\xfb9E\x07\xbc\xc2']
# Bad pipe message: %s [b'\xd0Bg[S\x9eSJ 3\xd2\x1d\x8a\xb9\xae\xf6\xe8\xa0\x98\x18V\xf4\xe7"\x8d\xbb\x93Z\x95a$\x00u\x90\xb0\x0eeKx.\x9c\x04\x1b\xf6\x99oB\r]\xcalY\x10A\xb8Y\x0cE\xb3t ;\xbb\x94']
# Bad pipe message: %s ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 341, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 993, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [b'\xdd\xb3E\xe6i\x14\x91&v\xf18L\xfaf\x07~\xf3\xbf04V\x9cf\x07p\\\x15fU\xc5\x04:S\x1fu\xa1\xb2\x9cnS\xf6v\x94I>\n:\n\x1fT/\xcej\x80 \t\x06\xee\x16t\x0f\x1a\x13\xfb\xc5\xa1@\x96\xac\x9aGEP\t\xa0\xb1s\xae\xe1\x12"']
# Bad pipe message: %s [b'\xc0y\xc8\xa0)?ZSkh\x02\xaf\xc7\x021G\xc5JF\x18\xcc.\xc2\xb6\xb8U\xba/\xf0S\x14\xc9\xb8\x07q']
# Bad pipe message: %s [b'\xb8.ks\x8c\xfc\x95Y\x17\x81{Q\x98\n\x18=\x1e\xf3\x170\xba\x16\xc1aF\xe7J(K\xb1J\xb67\xbb\xa2"\x17\x085Rh\x11l\x8c\xac\xa5[\xc0\xb7', b'\x9c1u\x1dR\xd5(\xdb\xa7\xc0\x08\x0bT\xa8\x97\x9e\rC\xb9\xc3t$\xb3\xb6#\x17\xc4F\xe2\xc8\xc8J{\xa2\x94Y\x08Z\xa1-8-`\x10eP}\xfff\xc9{\x19afu\xfe\x90\xbe\xae\xde3W\xf7\x0b\x00\x0f-\xf1\xe3\xccJ?3SYW\xfe\x95h~}=\x8b\xc4\xb9/\x06\x83\x05\xd2\x85\xf0\x92{H@\xea\x99\x88b_\xf0\xf8I\x00\x1d\x00 \xf32\x16\xeb\xbcw\xa6\xf0Zwt%\xcd\xec\xfdi\x10\xa0\xe1X\xddV\t\x1bA\xda6}\xd3B\xcb\x0e\x00-\x00\x02']
# Bad pipe message: %s [b'&\xb8\xeb\xd3x\xa3\xe3\t\x1b\x96\xad0\xb0W\xac\x16\x80\xf6\xc8{<\xfaC\xc4\xb3]\x07\x87}\x11%\xa2d\xcca\xa4\x06\x00\xdf\xb4.\x9baoKur\x12bPL\xd7?p\xf2\xc3\x88\xd5w\xdd\x02\xb9\x03\xb2[', b'\x80_\xa3{#Zd:s\r\xdf\xf1\xa8\xaa%u\x07aOX\xd0\x97\xe2\x16\xc99\x13\x01\x01),N\x16\xb8#\x9a\xcb""a_\xa7C\xc5\x10vf\xda\x87\xd6\x1a\xab \x94\x9b=\xc5\n\x06\xf5\x9aN\xc5]\x9f2S\xba\x1a\xae\t\xb9*\x81\xe3)w \x90f4\x8e\xb3\xc2\x19\xc4:!D\x91\x87\xbeE\xb5\x9a\x97\xb8\xcc[\'\x1a\x11k\x05vB\x80T\x0f\xea\x9c{\xce\xe1q3\x91\xc4\xf8\\h\x96\xdc\x19\xa6\xabV@\x1bk|\xe4\xbd\xe92\xb6^\x92]-\xfc\xba\xfa\xa0\x94j\x1a\x8e\xf9\x13Sl)4\xf0\x85EP\x00\xb4i\x03\xaf\x83\n\x94\x84Ko\x8d\x00%\xb7j\x0f#\xe5*$\xe1\xa5\xed\x030\x9e\xebhb\xeb\x03E\xfclf#\xb989\\\x8e:\x9a(\xeb\x0f\xbd\x04Bk\xc0F\x96\xeb\xb6']
# Bad pipe message: %s [b't\xe7c\xa9\xca\x99`xz\xa8\x07\xa1\x8f-#(\xb8Pn\xcd\xf8\x93\x9e*\x05\xc7\x95\xbbSU\x03\xa66}\x13\xf6bQ\x8c\xc6\x0b\xda\t\x9as', b'C:4j\xbc\xa1[\xa6\xe1\xfc\xb7\x86\xf4\x84\xcc\xba&\x92\xb4\xad\x1e!\xcd|*&\x83\x8a^v\xe3\x8a\x981\xab\xbd,\xc2}\x125\xf3\xe75']
# Bad pipe message: %s [b'd\xcd\x18\rSz#\x9a\xe6x\xb2klJ\xa9\x18\xd6,Tul', b'x*\xaa:8\x10\xcc\x92\xc5\xd5\x96/\x80MOfLq\xd2\x968\xc2\x8bx\x85\xb9\x8d\x11c\x8c\xb3\x8f&\xc8\xbbT\xa2\t\xf9\x14UC\xc0\x95ZGQ\xa0\x89\x8aUVT\xcf\xcaI\\w\tuzj\xa2\x8b\x8eU\xcc\x181\xf7\xb4qU\x80\xf2T\xa2\x92\xf9\xcc\x88\xd1N|\xd4\x06\xcc\xa6?h\x0b7~"\xaf)\x98\x94\xe5t\x8a\xc3U\xb1l\xf9\xa1+\x96\xa1\x84\x02\x9f\x07p\xb6\xd29\xcf\xcaDo\xc2\xf0\x9e\n:1\xc2\x1b\xb4O\x05I9\xe9P\x14kA\x9fV\x16\xfc`\xc3\xa7\xcapc\x97\x12y\xc2\x91\xaf\xf0\x8f9*\x91H6U:\x93\xb7^Gm\xfb\x19b\xabb\x0b\xb8d\xa2|\xbb\xa7\x13!\x18m|S\xc2\xac\x8f\x04\xfbpJ)']
# Bad pipe message: %s [b'b\xa8\x1f\xb9\x0c\xb6\xa0VLw\x8f\xa0\x87\x8a\xba)-\xe8\x18\x15\x02{\x03\xe0Q\x8b5,X\x11\xca\x80o\xec\xa9.\xc5*\xf6\x9a\x88u\x17\x8e\xf2Dg\xea{GqTh\xb2\xb8\xae\xce\xd5\x17mx\xc8\xa2\xb3k\x1d\xf2b\x0e\x8bv\x91\xa4L\x7f\xa1X~`\x07\xc9\xa0C\r\x94\xb1\xaa\xe0a\xae\xccW\x9f\xe0\x9d\x9f\xf8c\xd3\x9a\xc0#,\x15@\xb2w\xb5\xa3O\x82;1\x98sv\xb3U3\xcb\xbc\xa6\xc9\x92G\xe6sd\x93T?v\x14T\xf1\xcb\xb5\xef\xb7<Q\x14e\xc7crX\xf0\x98\xbc\x87d\xb3\xabu\xe1\x11\x01>\x07\xc9\x10\x03\x80\xf6\\d\xe9) 2*\xb4\x88\xd3z-w:\x0eUg3\x80\x1d\x7f\xe4?\xe7\xca\xacXf\xb2\x80\x85', b'\xf7D\xc7\x85\'\xd58LY\xf6\x11#\xc0;J\xe6_]\x8cz\xe6;\x8a,d#\xe5T\x9e\x8c"\x88\x92hJ\xa4\xac$\x871\x14\xe2\xc6\x01\x107Mr\x89\x90\x07H\x1e\xd2\xe3K\x8eGv\x96\x19\x8a\xf7\xb4\x7f\x1c%{(vH<i\x82\xdb\xf7Q\xcbij\xaa\xd2 \x140\x9c\x90f\xb4\x9a$\x13\xd4\xfb\xba\x81\x97f\xa9\xf3\x07\xb2\xe0\xc2\x1c:\x8b\x94b\x84\xe8\xd7q\xc1\x93\xca!G`\xe2\xc5z\xde\'\xb09\x9ac\n&g\'\xfa\xb0.9\xb8\xaa3\xa2t\xa8\x86y5p\x17I\x89]\x92b\x95\xf5}\x04G\'\x9cb\x92;\x05\x1e\xb7\xc2\x82']
# Bad pipe message: %s [b'\x9c\xf7\x16a\x9c\x06\x84\xb7\x94\x9d\x10\xccs\xca\xa0;\xe2\xc3_\xa4\x95\x10|\xea\xa6\x87h\x1e\xc8;\xc0w\x89\x95\x84,\x84\xc3\x0b}\x14\xbctLG,\xbfl\x99p\xda\xa0\xbb\xa4\x0e\xfa\x12\x95\xe9\xa0\xb9\xd4\x00\xa9p\x87\x9f\xeeA\x96\x9f\x8a2ap\xba\xf6\x96\x1eH\x84q!']
# Bad pipe message: %s [b'^kG\xd9\n\xf0\xbb\xe4\x08\x962\xd0\xb3Te\xb9\x9c\xe1\xe5s*\x94\xa2\xf9\x987\xb8\xe9\xbf\xf11U\xef\xbe\x8c\xf1\xb5Y\x8f\xfb\xaeMV\xad\xe9\x06{\xd2\xfd-\x8fZ\x8d&:O}cZ\xf8:\x00\x1d\x00 \x83\xf5n\xb8\xb6\x93\xc9\x01\x95\xc2a$\x9b\xd7"\xca(J\x03\xfb\x1b\xfc^Jr\xfe8,\xcb\n.\x12\x00-\x00\x02\x01\x01\x00+\x00\x07']
# Bad pipe message: %s [b'\xfa\x03\x04\x03\x03']
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)
# /Users/jordangunn/jaxcmr/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:440: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   return fun(*args, **kwargs)

# %%
observed_crp = subject_rep_crp(data, trial_mask, min_lag, max_lag, size)
control_crp = subject_rep_crp(control_dataset, control_mask, min_lag, max_lag, size)

results = test_rep_crp_vs_control(observed_crp, control_crp, max_lag)
for label, result in results.items():
    print(f"\n{'='*60}")
    print(f"Statistical Tests: {label}")
    print(f"{'='*60}")
    print(result)
# Out:
# ============================================================
# Statistical Tests: First Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    1.714     0.0874 |  22708.0     0.0048 |     0.0027
#    -4 |    2.357     0.0190 |  23692.0     0.0096 |     0.0025
#    -3 |   -0.036     0.9714 |  27474.0     0.7073 |    -0.0000
#    -2 |    1.899     0.0584 |  24323.0     0.0253 |     0.0020
#    -1 |    1.354     0.1766 |  26259.0     0.2890 |     0.0021
#     0 |      nan        nan |      nan        nan |        nan
#     1 |   -1.799     0.0729 |  24514.0     0.0410 |    -0.0033
#     2 |    2.053     0.0408 |  25444.0     0.0902 |     0.0028
#     3 |    2.126     0.0342 |  24142.0     0.0154 |     0.0025
#     4 |    2.093     0.0371 |  23826.0     0.0119 |     0.0028
#     5 |   -0.315     0.7527 |  27803.0     0.7769 |    -0.0006
#
# ============================================================
# Statistical Tests: Second Presentation
# ============================================================
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |   -1.040     0.2993 |  26272.0     0.2532 |    -0.0025
#    -4 |    1.501     0.1343 |  25273.0     0.0735 |     0.0020
#    -3 |    2.086     0.0378 |  23601.0     0.0065 |     0.0026
#    -2 |    1.845     0.0659 |  24906.5     0.0461 |     0.0023
#    -1 |   -0.974     0.3305 |  28171.0     0.9387 |    -0.0029
#     0 |      nan        nan |      nan        nan |        nan
#     1 |   -1.709     0.0884 |  26035.0     0.2021 |    -0.0031
#     2 |    1.127     0.2605 |  26866.0     0.3682 |     0.0014
#     3 |    2.415     0.0163 |  23351.0     0.0054 |     0.0029
#     4 |    0.692     0.4892 |  27073.0     0.4883 |     0.0009
#     5 |    2.046     0.0416 |  24062.0     0.0136 |     0.0024
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:507: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_col, ctrl_col, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:518: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff)

# %%
bias_result = test_first_second_bias(observed_crp, control_crp, max_lag)
print(f"\n{'='*70}")
print("Test: First-Second Bias (Observed) vs First-Second Bias (Control)")
print(f"{'='*70}")
print("H0: The preference for first-presentation neighbors over second-presentation")
print("    neighbors is the same in observed data as in the shuffled control.")
print()
print(bias_result)
# Out:
# ======================================================================
# Test: First-Second Bias (Observed) vs First-Second Bias (Control)
# ======================================================================
# H0: The preference for first-presentation neighbors over second-presentation
#     neighbors is the same in observed data as in the shuffled control.
#
#   Lag |   t-stat    t p-val |   W-stat    W p-val |  Mean Diff
# ------+----------------------+----------------------+------------
#    -5 |    1.832     0.0678 |  24150.0     0.0196 |     0.0051
#    -4 |    0.329     0.7426 |  26741.0     0.3792 |     0.0006
#    -3 |   -1.511     0.1317 |  25673.0     0.1173 |    -0.0027
#    -2 |   -0.177     0.8595 |  27739.0     0.6803 |    -0.0003
#    -1 |    1.380     0.1684 |  27778.0     0.6963 |     0.0050
#     0 |      nan        nan |      nan        nan |        nan
#     1 |   -0.084     0.9332 |  27380.0     0.6025 |    -0.0002
#     2 |    0.785     0.4331 |  26732.0     0.3297 |     0.0014
#     3 |   -0.245     0.8063 |  28376.0     0.9552 |    -0.0004
#     4 |    1.066     0.2872 |  26460.0     0.2599 |     0.0019
#     5 |   -1.343     0.1802 |  25672.0     0.1171 |    -0.0031
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:576: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, t_pval = stats.ttest_rel(obs_d, ctrl_d, nan_policy="omit")
# /Users/jordangunn/jaxcmr/jaxcmr/analyses/repcrp.py:587: RuntimeWarning: Mean of empty slice
#   mean_diffs[lag_idx] = np.nanmean(diff_of_diff)
