# %% [markdown]
# # Cues at Test
#
# Some paradigms (VIT-style) present film cues during the test phase.
# Film cues reinstate trauma context via item-to-context retrieval, partially overriding the retrieval-control mechanisms from the retrieval control simulation.
# This explains inconsistency in the selective interference literature across cued vs uncued paradigms.
#
# *Implementation pending VIT-style cue protocol.*
