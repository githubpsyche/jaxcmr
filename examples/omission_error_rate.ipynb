# %% [markdown]
# # Omission error rate

# %% [markdown]
# Compute omission error rates for serial recall.

# %% [markdown]
# Omission error rates quantify how often studied items fail to be recalled. They highlight position-specific forgetting and help compare datasets or models.

# %%
import jax.numpy as jnp
from jaxcmr.analyses.omission_error_rate import (
    trial_omission_error_rate,
    omission_error_rate,
    plot_omission_error_rate,
)

# %%
recalls = jnp.array([[1, 2, 0], [1, 0, 3]])
presentations = jnp.array([[1, 2, 3], [1, 2, 3]])
size = 3
dataset = {
    "recalls": recalls,
    "pres_itemnos": presentations,
    "subject": jnp.array([[1], [1]]),
    "listLength": jnp.array([[3], [3]]),
}
trial_mask = jnp.array([True, True])

# %%
omission_rates = omission_error_rate(recalls, presentations, list_length=3, size=size)
omission_rates

# %%
plot_omission_error_rate(dataset, trial_mask, labels=["Example"])
